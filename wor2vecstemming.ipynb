# %%
import math

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#start arabic test
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.stem.porter import *
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
import codecs
import sys

# %%
import os
from nltk.parse import stanford as SParse
from nltk.tag import stanford as STag
from nltk.tokenize import StanfordSegmenter

from polyglot.text import Text
from rake_nltk import Rake

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

os.environ['STANFORD_MODELS'] = 'stanford-segmenter-2018-10-16/data/;stanford-postagger-full-2018-10-16/models/'
os.environ['STANFORD_PARSER'] = 'stanford-parser-full-2018-10-17'
os.environ['CLASSPATH'] = 'stanford-parser-full-2018-10-17'
os.environ['JAVAHOME'] = 'C:/Program Files/Java/jdk1.8.0_60'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Maya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#readind and preparing data ( text , label )
data=pd.read_excel('incident13types.xlsx', header=None) ## read le file
data.columns=['label','text']
print(data[2:3])
# Out:
#    label                                               text
# 2      4  اقدم المدعو وليد عدنان مرعي على شتم و اهانة ال...

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9ا-ي #+_]')
STOPWORDS = set(stopwords.words('arabic'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing. 
    text = text.replace('x', '')
#    text = re.sub(r'\W+', '', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    return text

# %%
subData = data['text']
#subData = subData[1:10]
singleTextWithPips = '|'.join(subData)
#print(singleTextWithPips)
f = open("samplePips.txt", "w",  encoding='utf-8')
f.write(singleTextWithPips)
f.close()

# %%
segmenter = StanfordSegmenter('stanford-segmenter-2018-10-16/stanford-segmenter-3.9.2.jar')
segmenter.default_config('ar')
textseg = segmenter.segment_file('samplePips.txt')
print(textseg[1:20])
# Out:
# C:\Users\Maya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.parse.corenlp.CoreNLPTokenizer instead.'
#   """Entry point for launching an IPython kernel.
# لساعة 8.15 من تاريخ

# %%
texts=textseg.split('|')
print(texts[1:3])
# Out:
# [' عند التاسعة من مساء يوم 29/9/2018 و في محلة الطريق الجديدة / ارض جلول / اوقفت دورية من مكتب معلومات بيروت الرابعة المدعو خالد عسكر بعد الاشتباه ب ه بترويج المخدرات حيث عثرت ب حوزة ه على كمية من المخدرات على الشكل التالي :\r\n50 حبة من نوع ب نزكسول\r\n80 × 1/2 حبة من نوع ب نزكسول موضبين داخل ثلاثة اكياس صغيرة\r\n9 حبات و نصف من نوع ترامال\r\n19 حبة من نوع MELEXITE المخدرة ل الاعصاب\r\n49 حبة مجهولة الصنف لون اصفر داخل حنجور\r\nب الاضافة الى 13 كارت نوع تيليكارت مغلفين ', ' اقدم المدعو وليد عدنان مرعي على شتم و اهانة المدعوة رينا حافظ لبنانية و هي زوجة ه السابقة اي طليقة ه اثناء وجود ها في محلة راس النبع شارع محمد الحوت ']

# %% [markdown]
# from nltk.stem import ISRIStemmer
# st=ISRIStemmer()
# sw=STOPWORDS
# collection_new=[]
# for  doc in texts:
#     new_doc=[]
#     for i in doc.split():
#         if not i in sw:
#             i=st.stem(i)
#             i=''.join(i)
#             new_doc.append(i)
#     collection_new.append(new_doc)
# collection=collection_new

# %%
texts=collection
print(collection[1])
# Out:
# ['اسع'  'مساء'  'يوم'  '  '  'و'  'حلة'  'طرق'  'جدد'  ' '  'ارض'  'جلل'  ' '  'وقف'  'دور'  'كتب'  'علم'  'يرو'  'ربع'  'دعو'  'خلد'  'عسكر'  'شبه'  'ب'  'ه'  'روج'  'خدر'  'عثر'  'ب'  'حوز'  'ه'  'كمة'  'خدر'  'شكل'  'تلي'  ' '  ''  'حبة'  'نوع'  'ب'  'زكسول'  ''  '×'  ' '  'حبة'  'نوع'  'ب'  'زكسول'  'وضب'  'دخل'  'ثلث'  'كيس'  'صغر'  ''  'حبت'  'و'  'نصف'  'نوع'  'رامال'  ''  'حبة'  'نوع'  '        '  'خدر'  'ل'  'عصب'  ''  'حبة'  'جهل'  'صنف'  'لون'  'صفر'  'دخل'  'حنجور'  'ب'  'ضفة'  'الى'  ''  'كرت'  'نوع'  'تيليكارت'  'غلف']

# %%
import re
print(collection[1])
for i in range(len(collection)):
    collection[i] = re.sub(r'\d+', '', str(collection[i]))
print(collection[1])
# Out:
# ['اسع'  'مساء'  'يوم'  '  '  'و'  'حلة'  'طرق'  'جدد'  ' '  'ارض'  'جلل'  ' '  'وقف'  'دور'  'كتب'  'علم'  'يرو'  'ربع'  'دعو'  'خلد'  'عسكر'  'شبه'  'ب'  'ه'  'روج'  'خدر'  'عثر'  'ب'  'حوز'  'ه'  'كمة'  'خدر'  'شكل'  'تلي'  ' '  ''  'حبة'  'نوع'  'ب'  'زكسول'  ''  '×'  ' '  'حبة'  'نوع'  'ب'  'زكسول'  'وضب'  'دخل'  'ثلث'  'كيس'  'صغر'  ''  'حبت'  'و'  'نصف'  'نوع'  'رامال'  ''  'حبة'  'نوع'  '        '  'خدر'  'ل'  'عصب'  ''  'حبة'  'جهل'  'صنف'  'لون'  'صفر'  'دخل'  'حنجور'  'ب'  'ضفة'  'الى'  ''  'كرت'  'نوع'  'تيليكارت'  'غلف']
# ['اسع'  'مساء'  'يوم'  '  '  'و'  'حلة'  'طرق'  'جدد'  ' '  'ارض'  'جلل'  ' '  'وقف'  'دور'  'كتب'  'علم'  'يرو'  'ربع'  'دعو'  'خلد'  'عسكر'  'شبه'  'ب'  'ه'  'روج'  'خدر'  'عثر'  'ب'  'حوز'  'ه'  'كمة'  'خدر'  'شكل'  'تلي'  ' '  ''  'حبة'  'نوع'  'ب'  'زكسول'  ''  '×'  ' '  'حبة'  'نوع'  'ب'  'زكسول'  'وضب'  'دخل'  'ثلث'  'كيس'  'صغر'  ''  'حبت'  'و'  'نصف'  'نوع'  'رامال'  ''  'حبة'  'نوع'  '        '  'خدر'  'ل'  'عصب'  ''  'حبة'  'جهل'  'صنف'  'لون'  'صفر'  'دخل'  'حنجور'  'ب'  'ضفة'  'الى'  ''  'كرت'  'نوع'  'تيليكارت'  'غلف']

# %%
table=str.maketrans("+=_-<>~/!*%?:;,)&1234567890@$qwertyuioplkjhgfdsamnbvcxz(QWERTYUIOPLKJHGFDSAZXCVBNM",82*" ")
for i in range(len(collection)):
    collection[i] = collection[i].translate(table)
print(collection[1])
# Out:
# ['اسع'  'مساء'  'يوم'  '  '  'و'  'حلة'  'طرق'  'جدد'  ' '  'ارض'  'جلل'  ' '  'وقف'  'دور'  'كتب'  'علم'  'يرو'  'ربع'  'دعو'  'خلد'  'عسكر'  'شبه'  'ب'  'ه'  'روج'  'خدر'  'عثر'  'ب'  'حوز'  'ه'  'كمة'  'خدر'  'شكل'  'تلي'  ' '  ''  'حبة'  'نوع'  'ب'  'زكسول'  ''  '×'  ' '  'حبة'  'نوع'  'ب'  'زكسول'  'وضب'  'دخل'  'ثلث'  'كيس'  'صغر'  ''  'حبت'  'و'  'نصف'  'نوع'  'رامال'  ''  'حبة'  'نوع'  '        '  'خدر'  'ل'  'عصب'  ''  'حبة'  'جهل'  'صنف'  'لون'  'صفر'  'دخل'  'حنجور'  'ب'  'ضفة'  'الى'  ''  'كرت'  'نوع'  'تيليكارت'  'غلف']

# %%
#import os, sys
#import pandas as pd
#import numpy as np
#from sklearn.metrics.pairwise import cosine_similarity
#from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.model_selection import train_test_split
#from sklearn.naive_bayes import BernoulliNB
#from sklearn.ensemble import RandomForestClassifier
##from sklearn.metrics import roc_curve, auc
#from sklearn import svm
#from sklearn.metrics import classification_report, confusion_matrix
#from sklearn.model_selection import GridSearchCV
from gensim.models import KeyedVectors
#from scipy import spatial
#import matplotlib.pyplot as plt
#from sklearn.neural_network import MLPClassifier
from nltk import bigrams
import nltk
import re
#import spacy
###FUNCTIONS
def avg_feature_vector(sentence, model, num_features, index2word_set):
        words = sentence.split()
        feature_vec = np.zeros((num_features, ), dtype='float32')
        n_words = 0
        for word in words:
            if word in index2word_set:
                n_words += 1
                feature_vec = np.add(feature_vec, model[word])
        if (n_words > 0):
            feature_vec = np.divide(feature_vec, n_words)
        return feature_vec

def convert_word2vec(sentences,num_features):
        vectors_matrix = np.zeros((len(sentences),num_features))
        i = 0
        for sent in sentences:
            temp = avg_feature_vector(sent,word2vec_vectors,num_features,index2word_set)
            vectors_matrix[i,:] = temp
            i = i+1
        return vectors_matrix
def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    #txt = [token for token in doc ]
    words=str(doc).strip().split()
    #words=[st.stem(w) for w in words ]
    return ' '.join(words)
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    #if len(txt) > 2:
      #return ' '.join(txt)
#from gensim.models.phrases import Phrases, Phraser
#data=pd.read_excel('ml2.xlsx', header=None) ## read le file
#data.columns=['text','label']
#def prep(doc):
 #   words=str(doc).strip().split()
  #  return ' '.join(words)
#Xt=Xt.apply(prep)
#sentences = Xt
data=collection
#data = data[data['Semantic_Type']!='DISREGARD']
#from gensim.models.phrases import Phrases, Phraser
#from nltk.stem import ISRIStemmer
#st=ISRIStemmer()
brief_cleaning = (re.sub("[^ا-ي']+", ' ', str(row)).lower() for row in data)
txt = [cleaning(doc) for doc in data]
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
sent = [row.split() for row in df_clean['clean']]
sentences = sent
print(sentences[1])
from gensim.models import Word2Vec
word2vec_vectors = Word2Vec(min_count=2,window=5,size=200,sample=6e-5,alpha=0.03,min_alpha=0.0007,negative=20)
word2vec_vectors.build_vocab(sentences)
word2vec_vectors.train(sentences, total_examples=word2vec_vectors.corpus_count, epochs=30, report_delay=1)
word2vec_vectors.init_sims(replace=True)
index2word_set = set(word2vec_vectors.wv.index2word)
###vectorizing the sentences
#vectors_matrix = convert_word2vec(data['Sentence'],200)
#np.random.seed(10)
#labels=data['label']
#train,test,ltrain,ltest =train_test_split(vectors_matrix, labels,test_size=0.2)#,random_state=8)
# Out:
# ["['اسع'", "'مساء'", "'يوم'", "'", "'", "'و'", "'حلة'", "'طرق'", "'جدد'", "'", "'", "'ارض'", "'جلل'", "'", "'", "'وقف'", "'دور'", "'كتب'", "'علم'", "'يرو'", "'ربع'", "'دعو'", "'خلد'", "'عسكر'", "'شبه'", "'ب'", "'ه'", "'روج'", "'خدر'", "'عثر'", "'ب'", "'حوز'", "'ه'", "'كمة'", "'خدر'", "'شكل'", "'تلي'", "'", "'", "''", "'حبة'", "'نوع'", "'ب'", "'زكسول'", "''", "'×'", "'", "'", "'حبة'", "'نوع'", "'ب'", "'زكسول'", "'وضب'", "'دخل'", "'ثلث'", "'كيس'", "'صغر'", "''", "'حبت'", "'و'", "'نصف'", "'نوع'", "'رامال'", "''", "'حبة'", "'نوع'", "'", "'", "'خدر'", "'ل'", "'عصب'", "''", "'حبة'", "'جهل'", "'صنف'", "'لون'", "'صفر'", "'دخل'", "'حنجور'", "'ب'", "'ضفة'", "'الى'", "''", "'كرت'", "'نوع'", "'تيليكارت'", "'غلف']"]
# C:\Users\Maya\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "

# %%
def clean_str(text):
    search = ["أ","إ","آ","ة","_","-","/",".","،"," و "," يا ",'"',"ـ","'","ى","\\",'\n', '\t','&quot;','?','؟','!']
    replace = ["ا","ا","ا","ه"," "," ","","",""," و"," يا","","","","ي","",' ', ' ',' ',' ? ',' ؟ ',' ! ']
    
    #remove tashkeel
    p_tashkeel = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    text = re.sub(p_tashkeel,"", text)
    
    #remove longation
    p_longation = re.compile(r'(.)\1+')
    subst = r"\1\1"
    text = re.sub(p_longation, subst, text)
    
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    
    for i in range(0, len(search)):
        text = text.replace(search[i], replace[i])
    
    #trim    
    text = text.strip()

    return text
def get_vec(n_model,dim, token):
    vec = np.zeros(dim)
    is_vec = False
    if token not in n_model.wv:
        _count = 0
        is_vec = True
        for w in token.split("_"):
            if w in n_model.wv:
                _count += 1
                vec += n_model.wv[w]
        if _count > 0:
            vec = vec / _count
    else:
        vec = n_model.wv[token]
    return vec

def calc_vec(pos_tokens, neg_tokens, n_model, dim):
    vec = np.zeros(dim)
    for p in pos_tokens:
        vec += get_vec(n_model,dim,p)
    for n in neg_tokens:
        vec -= get_vec(n_model,dim,n)
    
    return vec

# %%
t_model = word2vec_vectors
pos_tokens=[ clean_str(t.strip()).replace(" ", "_") for t in ['خالد عسكر', 'مخدرات'] if t.strip() != ""]
neg_tokens=[ clean_str(t.strip()).replace(" ", "_") for t in ['سوري'] if t.strip() != ""]

vec = calc_vec(pos_tokens=pos_tokens, neg_tokens=neg_tokens, n_model=t_model, dim=t_model.vector_size)

most_sims = t_model.wv.similar_by_vector(vec, topn=10)
for term, score in most_sims:
    if term not in pos_tokens+neg_tokens:
        print(term, score)
# Out:
# 'شحم' 0.0
# 'شتل' 0.0
# 'افل' 0.0
# 'شمص' 0.0
# 'دمت' 0.0
# 'فقط' 0.0
# 'جيس' 0.0
# 'قشع' 0.0
# 'كاديل' 0.0
# 'قرح' 0.0

# %%
 word2vec_vectors.wv.vocab
# Out:
# {"['سعة'": <gensim.models.keyedvectors.Vocab at 0x1e20e850ac8>,
#  "'.'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2d30>,
#  "'ارخ'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2cf8>,
#  "'ه'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2cc0>,
#  "'و'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2e48>,
#  "'حلة'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2e80>,
#  "'زرع'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2eb8>,
#  "'قطع'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2ef0>,
#  "'ابي'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2f28>,
#  "'حيدر'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2f60>,
#  "'سلم'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2f98>,
#  "'صدم'": <gensim.models.keyedvectors.Vocab at 0x1e210ab2fd0>,
#  "'سير'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9048>,
#  "'نوع'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9080>,
#  "'نيس'": <gensim.models.keyedvectors.Vocab at 0x1e210ae90b8>,
#  "'يكر'": <gensim.models.keyedvectors.Vocab at 0x1e210ae90f0>,
#  "'لون'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9128>,
#  "'رمد'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9160>,
#  "'صنع'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9198>,
#  "''": <gensim.models.keyedvectors.Vocab at 0x1e210ae91d0>,
#  "'رقم'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9208>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9240>,
#  "'ب'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9278>,
#  "'قيد'": <gensim.models.keyedvectors.Vocab at 0x1e210ae92b0>,
#  "'كرم'": <gensim.models.keyedvectors.Vocab at 0x1e210ae92e8>,
#  "'خلد'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9320>,
#  "'دندشل'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9358>,
#  "'بدع'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9390>,
#  "'لبن'": <gensim.models.keyedvectors.Vocab at 0x1e210ae93c8>,
#  "'عرف'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9400>,
#  "'جوزيف'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9438>,
#  "'شلهوب'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9470>,
#  "'احد'": <gensim.models.keyedvectors.Vocab at 0x1e210ae94a8>,
#  "'عنصر'": <gensim.models.keyedvectors.Vocab at 0x1e210ae94e0>,
#  "'فرز'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9518>,
#  "'يرو'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9550>,
#  "'ثني'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9588>,
#  "'نقل'": <gensim.models.keyedvectors.Vocab at 0x1e210ae95c0>,
#  "'الى'": <gensim.models.keyedvectors.Vocab at 0x1e210ae95f8>,
#  "'شفى'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9630>,
#  "'حدد'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9668>,
#  "'ل'": <gensim.models.keyedvectors.Vocab at 0x1e210ae96a0>,
#  "'علج'": <gensim.models.keyedvectors.Vocab at 0x1e210ae96d8>,
#  "'تول'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9710>,
#  "'جرء'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9748>,
#  "'حقق'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9780>,
#  "'وجب'": <gensim.models.keyedvectors.Vocab at 0x1e210ae97b8>,
#  "'حضر'": <gensim.models.keyedvectors.Vocab at 0x1e210ae97f0>,
#  "'.']": <gensim.models.keyedvectors.Vocab at 0x1e210ae9828>,
#  "['اسع'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9860>,
#  "'مساء'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9898>,
#  "'يوم'": <gensim.models.keyedvectors.Vocab at 0x1e210ae98d0>,
#  "'طرق'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9908>,
#  "'جدد'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9940>,
#  "'ارض'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9978>,
#  "'جلل'": <gensim.models.keyedvectors.Vocab at 0x1e210ae99b0>,
#  "'وقف'": <gensim.models.keyedvectors.Vocab at 0x1e210ae99e8>,
#  "'دور'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9a20>,
#  "'كتب'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9a58>,
#  "'علم'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9a90>,
#  "'ربع'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9ac8>,
#  "'دعو'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9b00>,
#  "'عسكر'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9b38>,
#  "'شبه'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9b70>,
#  "'روج'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9ba8>,
#  "'خدر'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9be0>,
#  "'عثر'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9c18>,
#  "'حوز'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9c50>,
#  "'كمة'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9c88>,
#  "'شكل'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9cc0>,
#  "'تلي'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9cf8>,
#  "'حبة'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9d30>,
#  "'زكسول'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9d68>,
#  "'وضب'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9da0>,
#  "'دخل'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9dd8>,
#  "'ثلث'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9e10>,
#  "'كيس'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9e48>,
#  "'صغر'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9e80>,
#  "'حبت'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9eb8>,
#  "'نصف'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9ef0>,
#  "'رامال'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9f28>,
#  "'عصب'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9f60>,
#  "'جهل'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9f98>,
#  "'صفر'": <gensim.models.keyedvectors.Vocab at 0x1e210ae9fd0>,
#  "'حنجور'": <gensim.models.keyedvectors.Vocab at 0x1e210aec048>,
#  "'ضفة'": <gensim.models.keyedvectors.Vocab at 0x1e210aec080>,
#  "['قدم'": <gensim.models.keyedvectors.Vocab at 0x1e210aec0b8>,
#  "'ولد'": <gensim.models.keyedvectors.Vocab at 0x1e210aec0f0>,
#  "'عدن'": <gensim.models.keyedvectors.Vocab at 0x1e210aec128>,
#  "'رعي'": <gensim.models.keyedvectors.Vocab at 0x1e210aec160>,
#  "'شتم'": <gensim.models.keyedvectors.Vocab at 0x1e210aec198>,
#  "'هنة'": <gensim.models.keyedvectors.Vocab at 0x1e210aec1d0>,
#  "'دعة'": <gensim.models.keyedvectors.Vocab at 0x1e210aec208>,
#  "'رين'": <gensim.models.keyedvectors.Vocab at 0x1e210aec240>,
#  "'حفظ'": <gensim.models.keyedvectors.Vocab at 0x1e210aec278>,
#  "'زوج'": <gensim.models.keyedvectors.Vocab at 0x1e210aec2b0>,
#  "'سبق'": <gensim.models.keyedvectors.Vocab at 0x1e210aec2e8>,
#  "'اي'": <gensim.models.keyedvectors.Vocab at 0x1e210aec320>,
#  "'طلق'": <gensim.models.keyedvectors.Vocab at 0x1e210aec358>,
#  "'ثنء'": <gensim.models.keyedvectors.Vocab at 0x1e210aec390>,
#  "'وجد'": <gensim.models.keyedvectors.Vocab at 0x1e210aec3c8>,
#  "'راس'": <gensim.models.keyedvectors.Vocab at 0x1e210aec400>,
#  "'نبع'": <gensim.models.keyedvectors.Vocab at 0x1e210aec438>,
#  "'شرع'": <gensim.models.keyedvectors.Vocab at 0x1e210aec470>,
#  "'حمد'": <gensim.models.keyedvectors.Vocab at 0x1e210aec4a8>,
#  "'نصر'": <gensim.models.keyedvectors.Vocab at 0x1e210aec4e0>,
#  "'رضا'": <gensim.models.keyedvectors.Vocab at 0x1e210aec518>,
#  "'صدر'": <gensim.models.keyedvectors.Vocab at 0x1e210aec550>,
#  "'شك'": <gensim.models.keyedvectors.Vocab at 0x1e210aec588>,
#  "'صلح'": <gensim.models.keyedvectors.Vocab at 0x1e210aec5c0>,
#  "'حسن'": <gensim.models.keyedvectors.Vocab at 0x1e210aec5f8>,
#  "'عبد'": <gensim.models.keyedvectors.Vocab at 0x1e210aec630>,
#  "'تبن'": <gensim.models.keyedvectors.Vocab at 0x1e210aec668>,
#  "'ان'": <gensim.models.keyedvectors.Vocab at 0x1e210aec6a0>,
#  "'رصد']": <gensim.models.keyedvectors.Vocab at 0x1e210aec6d8>,
#  "'فرد'": <gensim.models.keyedvectors.Vocab at 0x1e210aec710>,
#  "'بنك'": <gensim.models.keyedvectors.Vocab at 0x1e210aec748>,
#  "'بحر'": <gensim.models.keyedvectors.Vocab at 0x1e210aec780>,
#  "'توسط'": <gensim.models.keyedvectors.Vocab at 0x1e210aec7b8>,
#  "'عرض'": <gensim.models.keyedvectors.Vocab at 0x1e210aec7f0>,
#  "'عمر'": <gensim.models.keyedvectors.Vocab at 0x1e210aec828>,
#  "'الد'": <gensim.models.keyedvectors.Vocab at 0x1e210aec860>,
#  "'وهب'": <gensim.models.keyedvectors.Vocab at 0x1e210aec898>,
#  "'حدث'": <gensim.models.keyedvectors.Vocab at 0x1e210aec8d0>,
#  "'قبل'": <gensim.models.keyedvectors.Vocab at 0x1e210aec908>,
#  "'ازد'": <gensim.models.keyedvectors.Vocab at 0x1e210aec940>,
#  "'فضي'": <gensim.models.keyedvectors.Vocab at 0x1e210aec978>,
#  "'ج'": <gensim.models.keyedvectors.Vocab at 0x1e210aec9b0>,
#  "'حية'": <gensim.models.keyedvectors.Vocab at 0x1e210aec9e8>,
#  "'رحم'": <gensim.models.keyedvectors.Vocab at 0x1e210aeca20>,
#  "'قيس'": <gensim.models.keyedvectors.Vocab at 0x1e210aeca58>,
#  "'ميس'": <gensim.models.keyedvectors.Vocab at 0x1e210aeca90>,
#  "'نتج'": <gensim.models.keyedvectors.Vocab at 0x1e210aecac8>,
#  "'صبة'": <gensim.models.keyedvectors.Vocab at 0x1e210aecb00>,
#  "'شعر'": <gensim.models.keyedvectors.Vocab at 0x1e210aecb38>,
#  "'كتف'": <gensim.models.keyedvectors.Vocab at 0x1e210aecb70>,
#  "'يسر'": <gensim.models.keyedvectors.Vocab at 0x1e210aecba8>,
#  "'طرد'": <gensim.models.keyedvectors.Vocab at 0x1e210aecbe0>,
#  "'عاج'": <gensim.models.keyedvectors.Vocab at 0x1e210aecc18>,
#  "['عرض'": <gensim.models.keyedvectors.Vocab at 0x1e210aecc50>,
#  "'مير'": <gensim.models.keyedvectors.Vocab at 0x1e210aecc88>,
#  "'سيم'": <gensim.models.keyedvectors.Vocab at 0x1e210aeccc0>,
#  "'يلى'": <gensim.models.keyedvectors.Vocab at 0x1e210aeccf8>,
#  "'توو'": <gensim.models.keyedvectors.Vocab at 0x1e210aecd30>,
#  "'اسد'": <gensim.models.keyedvectors.Vocab at 0x1e210aecd68>,
#  "'دلا'": <gensim.models.keyedvectors.Vocab at 0x1e210aecda0>,
#  "'فوز'": <gensim.models.keyedvectors.Vocab at 0x1e210aecdd8>,
#  "'يطر'": <gensim.models.keyedvectors.Vocab at 0x1e210aece10>,
#  "'منى'": <gensim.models.keyedvectors.Vocab at 0x1e210aece48>,
#  "'برض'": <gensim.models.keyedvectors.Vocab at 0x1e210aece80>,
#  "'يد'": <gensim.models.keyedvectors.Vocab at 0x1e210aeceb8>,
#  "'عولج'": <gensim.models.keyedvectors.Vocab at 0x1e210aecef0>,
#  "'نظم'": <gensim.models.keyedvectors.Vocab at 0x1e210aecf28>,
#  "['صدم'": <gensim.models.keyedvectors.Vocab at 0x1e210aecf60>,
#  "'كيا'": <gensim.models.keyedvectors.Vocab at 0x1e210aecf98>,
#  "'كانتو'": <gensim.models.keyedvectors.Vocab at 0x1e210aecfd0>,
#  "'جردو'": <gensim.models.keyedvectors.Vocab at 0x1e210aef048>,
#  "'م'": <gensim.models.keyedvectors.Vocab at 0x1e210aef080>,
#  "'عيش'": <gensim.models.keyedvectors.Vocab at 0x1e210aef0b8>,
#  "'ريم'": <gensim.models.keyedvectors.Vocab at 0x1e210aef0f0>,
#  "'حفكاو'": <gensim.models.keyedvectors.Vocab at 0x1e210aef128>,
#  "'نعم'": <gensim.models.keyedvectors.Vocab at 0x1e210aef160>,
#  "'سور'": <gensim.models.keyedvectors.Vocab at 0x1e210aef198>,
#  "'رضض'": <gensim.models.keyedvectors.Vocab at 0x1e210aef1d0>,
#  "'حاء'": <gensim.models.keyedvectors.Vocab at 0x1e210aef208>,
#  "'جسد'": <gensim.models.keyedvectors.Vocab at 0x1e210aef240>,
#  "'حرر'": <gensim.models.keyedvectors.Vocab at 0x1e210aef278>,
#  "'حكم'": <gensim.models.keyedvectors.Vocab at 0x1e210aef2b0>,
#  "'وضع'": <gensim.models.keyedvectors.Vocab at 0x1e210aef2e8>,
#  "'سقر'": <gensim.models.keyedvectors.Vocab at 0x1e210aef320>,
#  "'ولى'": <gensim.models.keyedvectors.Vocab at 0x1e210aef358>,
#  "'عئل'": <gensim.models.keyedvectors.Vocab at 0x1e210aef390>,
#  "'ندى'": <gensim.models.keyedvectors.Vocab at 0x1e210aef3c8>,
#  "'صطفى'": <gensim.models.keyedvectors.Vocab at 0x1e210aef400>,
#  "'ابن'": <gensim.models.keyedvectors.Vocab at 0x1e210aef438>,
#  "'قبا'": <gensim.models.keyedvectors.Vocab at 0x1e210aef470>,
#  "'تم'": <gensim.models.keyedvectors.Vocab at 0x1e210aef4a8>,
#  "'طلب'": <gensim.models.keyedvectors.Vocab at 0x1e210aef4e0>,
#  "'شكي'": <gensim.models.keyedvectors.Vocab at 0x1e210aef518>,
#  "'توج'": <gensim.models.keyedvectors.Vocab at 0x1e210aef550>,
#  "'فصل'": <gensim.models.keyedvectors.Vocab at 0x1e210aef588>,
#  "'صيطب'": <gensim.models.keyedvectors.Vocab at 0x1e210aef5c0>,
#  "'قدم'": <gensim.models.keyedvectors.Vocab at 0x1e210aef5f8>,
#  "'شكى'": <gensim.models.keyedvectors.Vocab at 0x1e210aef630>,
#  "'حال'": <gensim.models.keyedvectors.Vocab at 0x1e210aef668>,
#  "'رغب'": <gensim.models.keyedvectors.Vocab at 0x1e210aef6a0>,
#  "'سرق'": <gensim.models.keyedvectors.Vocab at 0x1e210aef6d8>,
#  "'درج'": <gensim.models.keyedvectors.Vocab at 0x1e210aef710>,
#  "'نري'": <gensim.models.keyedvectors.Vocab at 0x1e210aef748>,
#  "'عئد'": <gensim.models.keyedvectors.Vocab at 0x1e210aef780>,
#  "'زينب'": <gensim.models.keyedvectors.Vocab at 0x1e210aef7b8>,
#  "'سكف'": <gensim.models.keyedvectors.Vocab at 0x1e210aef7f0>,
#  "'كان'": <gensim.models.keyedvectors.Vocab at 0x1e210aef828>,
#  "'ركن'": <gensim.models.keyedvectors.Vocab at 0x1e210aef860>,
#  "'كورنيش'": <gensim.models.keyedvectors.Vocab at 0x1e210aef898>,
#  "['عة'": <gensim.models.keyedvectors.Vocab at 0x1e210aef8d0>,
#  "'ادع'": <gensim.models.keyedvectors.Vocab at 0x1e210aef908>,
#  "'امم'": <gensim.models.keyedvectors.Vocab at 0x1e210aef940>,
#  "'نهر'": <gensim.models.keyedvectors.Vocab at 0x1e210aef978>,
#  "'خور'": <gensim.models.keyedvectors.Vocab at 0x1e210aef9b0>,
#  "'متن'": <gensim.models.keyedvectors.Vocab at 0x1e210aef9e8>,
#  "'حجم'": <gensim.models.keyedvectors.Vocab at 0x1e210aefa20>,
#  "'بقي'": <gensim.models.keyedvectors.Vocab at 0x1e210aefa58>,
#  "'وصف'": <gensim.models.keyedvectors.Vocab at 0x1e210aefa90>,
#  "'سعة'": <gensim.models.keyedvectors.Vocab at 0x1e210aefac8>,
#  "'نشل'": <gensim.models.keyedvectors.Vocab at 0x1e210aefb00>,
#  "'هتف'": <gensim.models.keyedvectors.Vocab at 0x1e210aefb38>,
#  "'خلو'": <gensim.models.keyedvectors.Vocab at 0x1e210aefb70>,
#  "'رصف'": <gensim.models.keyedvectors.Vocab at 0x1e210aefba8>,
#  "'جنب'": <gensim.models.keyedvectors.Vocab at 0x1e210aefbe0>,
#  "'ورم'": <gensim.models.keyedvectors.Vocab at 0x1e210aefc18>,
#  "'دو'": <gensim.models.keyedvectors.Vocab at 0x1e210aefc50>,
#  "'فر'": <gensim.models.keyedvectors.Vocab at 0x1e210aefc88>,
#  "'جهة'": <gensim.models.keyedvectors.Vocab at 0x1e210aefcc0>,
#  "'تجه'": <gensim.models.keyedvectors.Vocab at 0x1e210aefcf8>,
#  "'عكس'": <gensim.models.keyedvectors.Vocab at 0x1e210aefd30>,
#  "'نزل'": <gensim.models.keyedvectors.Vocab at 0x1e210aefd68>,
#  "'محل'": <gensim.models.keyedvectors.Vocab at 0x1e210aefda0>,
#  "'يحى'": <gensim.models.keyedvectors.Vocab at 0x1e210aefdd8>,
#  "'راكيل'": <gensim.models.keyedvectors.Vocab at 0x1e210aefe10>,
#  "'قئم'": <gensim.models.keyedvectors.Vocab at 0x1e210aefe48>,
#  "'دعى'": <gensim.models.keyedvectors.Vocab at 0x1e210aefe80>,
#  "'شام'": <gensim.models.keyedvectors.Vocab at 0x1e210aefeb8>,
#  "'سبت'": <gensim.models.keyedvectors.Vocab at 0x1e210aefef0>,
#  "'ايم'": <gensim.models.keyedvectors.Vocab at 0x1e210aeff28>,
#  "'ضد'": <gensim.models.keyedvectors.Vocab at 0x1e210aeff60>,
#  "'اقد'": <gensim.models.keyedvectors.Vocab at 0x1e210aeff98>,
#  "'نفس'": <gensim.models.keyedvectors.Vocab at 0x1e210aeffd0>,
#  "'خلي'": <gensim.models.keyedvectors.Vocab at 0x1e210af2048>,
#  "'ايف'": <gensim.models.keyedvectors.Vocab at 0x1e210af2080>,
#  "'حمل'": <gensim.models.keyedvectors.Vocab at 0x1e210af20b8>,
#  "'شرح'": <gensim.models.keyedvectors.Vocab at 0x1e210af20f0>,
#  "'طين'": <gensim.models.keyedvectors.Vocab at 0x1e210af2128>,
#  "'اول'": <gensim.models.keyedvectors.Vocab at 0x1e210af2160>,
#  "'اوتوستراد'": <gensim.models.keyedvectors.Vocab at 0x1e210af2198>,
#  "'سيد'": <gensim.models.keyedvectors.Vocab at 0x1e210af21d0>,
#  "'هدي'": <gensim.models.keyedvectors.Vocab at 0x1e210af2208>,
#  "'صرلل'": <gensim.models.keyedvectors.Vocab at 0x1e210af2240>,
#  "'وفر'": <gensim.models.keyedvectors.Vocab at 0x1e210af2278>,
#  ".']": <gensim.models.keyedvectors.Vocab at 0x1e210af22b0>,
#  "'ظلم'": <gensim.models.keyedvectors.Vocab at 0x1e210af22e8>,
#  "'وسط'": <gensim.models.keyedvectors.Vocab at 0x1e210af2320>,
#  "'لنب'": <gensim.models.keyedvectors.Vocab at 0x1e210af2358>,
#  "'حيز'": <gensim.models.keyedvectors.Vocab at 0x1e210af2390>,
#  "'حشش'": <gensim.models.keyedvectors.Vocab at 0x1e210af23c8>,
#  "'كيف'": <gensim.models.keyedvectors.Vocab at 0x1e210af2400>,
#  "'قدر'": <gensim.models.keyedvectors.Vocab at 0x1e210af2438>,
#  "'حمص'": <gensim.models.keyedvectors.Vocab at 0x1e210af2470>,
#  "'ورق'": <gensim.models.keyedvectors.Vocab at 0x1e210af24a8>,
#  "'نقد'": <gensim.models.keyedvectors.Vocab at 0x1e210af24e0>,
#  "'فئة'": <gensim.models.keyedvectors.Vocab at 0x1e210af2518>,
#  "'مئة'": <gensim.models.keyedvectors.Vocab at 0x1e210af2550>,
#  "'دولار'": <gensim.models.keyedvectors.Vocab at 0x1e210af2588>,
#  "'امر'": <gensim.models.keyedvectors.Vocab at 0x1e210af25c0>,
#  "'زور'": <gensim.models.keyedvectors.Vocab at 0x1e210af25f8>,
#  "'قمت'": <gensim.models.keyedvectors.Vocab at 0x1e210af2630>,
#  "'نهي'": <gensim.models.keyedvectors.Vocab at 0x1e210af2668>,
#  "'مها'": <gensim.models.keyedvectors.Vocab at 0x1e210af26a0>,
#  "'ندم'": <gensim.models.keyedvectors.Vocab at 0x1e210af26d8>,
#  "'طير'": <gensim.models.keyedvectors.Vocab at 0x1e210af2710>,
#  "'اري'": <gensim.models.keyedvectors.Vocab at 0x1e210af2748>,
#  "'اود'": <gensim.models.keyedvectors.Vocab at 0x1e210af2780>,
#  "'ابض'": <gensim.models.keyedvectors.Vocab at 0x1e210af27b8>,
#  "'يرا'": <gensim.models.keyedvectors.Vocab at 0x1e210af27f0>,
#  "'راهيم'": <gensim.models.keyedvectors.Vocab at 0x1e210af2828>,
#  "'نحل'": <gensim.models.keyedvectors.Vocab at 0x1e210af2860>,
#  "'ديم'": <gensim.models.keyedvectors.Vocab at 0x1e210af2898>,
#  "'جمع'": <gensim.models.keyedvectors.Vocab at 0x1e210af28d0>,
#  "'طفف'": <gensim.models.keyedvectors.Vocab at 0x1e210af2908>,
#  "']": <gensim.models.keyedvectors.Vocab at 0x1e210af2940>,
#  "'فدي'": <gensim.models.keyedvectors.Vocab at 0x1e210af2978>,
#  "'صحب'": <gensim.models.keyedvectors.Vocab at 0x1e210af29b0>,
#  "'ؤسس'": <gensim.models.keyedvectors.Vocab at 0x1e210af29e8>,
#  "'عدة'": <gensim.models.keyedvectors.Vocab at 0x1e210af2a20>,
#  "'بيع'": <gensim.models.keyedvectors.Vocab at 0x1e210af2a58>,
#  "'لحم'": <gensim.models.keyedvectors.Vocab at 0x1e210af2a90>,
#  "'عمل'": <gensim.models.keyedvectors.Vocab at 0x1e210af2ac8>,
#  "'وسف'": <gensim.models.keyedvectors.Vocab at 0x1e210af2b00>,
#  "'عيسى'": <gensim.models.keyedvectors.Vocab at 0x1e210af2b38>,
#  "'ناد'": <gensim.models.keyedvectors.Vocab at 0x1e210af2b70>,
#  "'جرم'": <gensim.models.keyedvectors.Vocab at 0x1e210af2ba8>,
#  "'برد'": <gensim.models.keyedvectors.Vocab at 0x1e210af2be0>,
#  "'يمل'": <gensim.models.keyedvectors.Vocab at 0x1e210af2c18>,
#  "'مرة'": <gensim.models.keyedvectors.Vocab at 0x1e210af2c50>,
#  "'جسم'": <gensim.models.keyedvectors.Vocab at 0x1e210af2c88>,
#  "'ايض'": <gensim.models.keyedvectors.Vocab at 0x1e210af2cc0>,
#  "'جرح'": <gensim.models.keyedvectors.Vocab at 0x1e210af2cf8>,
#  "'باب'": <gensim.models.keyedvectors.Vocab at 0x1e210af2d30>,
#  "'علي'": <gensim.models.keyedvectors.Vocab at 0x1e210af2d68>,
#  "'عوض'": <gensim.models.keyedvectors.Vocab at 0x1e210af2da0>,
#  "'مزق'": <gensim.models.keyedvectors.Vocab at 0x1e210af2dd8>,
#  "'اطر'": <gensim.models.keyedvectors.Vocab at 0x1e210af2e10>,
#  "'بيل'": <gensim.models.keyedvectors.Vocab at 0x1e210af2e48>,
#  "'حصل'": <gensim.models.keyedvectors.Vocab at 0x1e210af2e80>,
#  "'ينغ'": <gensim.models.keyedvectors.Vocab at 0x1e210af2eb8>,
#  "'لوح'": <gensim.models.keyedvectors.Vocab at 0x1e210af2ef0>,
#  "'فتح'": <gensim.models.keyedvectors.Vocab at 0x1e210af2f28>,
#  "'شحن'": <gensim.models.keyedvectors.Vocab at 0x1e210af2f60>,
#  "'خصص'": <gensim.models.keyedvectors.Vocab at 0x1e210af2f98>,
#  "'فطم'": <gensim.models.keyedvectors.Vocab at 0x1e210af2fd0>,
#  "'سئق'": <gensim.models.keyedvectors.Vocab at 0x1e210af5048>,
#  "'جعيتاو'": <gensim.models.keyedvectors.Vocab at 0x1e210af5080>,
#  "'تلق'": <gensim.models.keyedvectors.Vocab at 0x1e210af50b8>,
#  "'غدر'": <gensim.models.keyedvectors.Vocab at 0x1e210af50f0>,
#  "['ب'": <gensim.models.keyedvectors.Vocab at 0x1e210af5128>,
#  "'دعء'": <gensim.models.keyedvectors.Vocab at 0x1e210af5160>,
#  "'زقق'": <gensim.models.keyedvectors.Vocab at 0x1e210af5198>,
#  "'بلط'": <gensim.models.keyedvectors.Vocab at 0x1e210af51d0>,
#  "'وعد'": <gensim.models.keyedvectors.Vocab at 0x1e210af5208>,
#  "'دعي'": <gensim.models.keyedvectors.Vocab at 0x1e210af5240>,
#  "'اكد'": <gensim.models.keyedvectors.Vocab at 0x1e210af5278>,
#  "'تخذ'": <gensim.models.keyedvectors.Vocab at 0x1e210af52b0>,
#  "'ختم'": <gensim.models.keyedvectors.Vocab at 0x1e210af52e8>,
#  "'قضي']": <gensim.models.keyedvectors.Vocab at 0x1e210af5320>,
#  "'هني'": <gensim.models.keyedvectors.Vocab at 0x1e210af5358>,
#  "'نبل'": <gensim.models.keyedvectors.Vocab at 0x1e210af5390>,
#  "'جمل'": <gensim.models.keyedvectors.Vocab at 0x1e210af53c8>,
#  "'يهب'": <gensim.models.keyedvectors.Vocab at 0x1e210af5400>,
#  "'شرب'": <gensim.models.keyedvectors.Vocab at 0x1e210af5438>,
#  "'شيك'": <gensim.models.keyedvectors.Vocab at 0x1e210af5470>,
#  "'عمم'": <gensim.models.keyedvectors.Vocab at 0x1e210af54a8>,
#  "'بلغ'": <gensim.models.keyedvectors.Vocab at 0x1e210af54e0>,
#  "'بحث'": <gensim.models.keyedvectors.Vocab at 0x1e210af5518>,
#  "'تحر'": <gensim.models.keyedvectors.Vocab at 0x1e210af5550>,
#  "'مدة'": <gensim.models.keyedvectors.Vocab at 0x1e210af5588>,
#  "'شهر'": <gensim.models.keyedvectors.Vocab at 0x1e210af55c0>,
#  "'حق'": <gensim.models.keyedvectors.Vocab at 0x1e210af55f8>,
#  "'حضر']": <gensim.models.keyedvectors.Vocab at 0x1e210af5630>,
#  "['صطدم'": <gensim.models.keyedvectors.Vocab at 0x1e210af5668>,
#  "'امن'": <gensim.models.keyedvectors.Vocab at 0x1e210af56a0>,
#  "'حلم'": <gensim.models.keyedvectors.Vocab at 0x1e210af56d8>,
#  "'قسم'": <gensim.models.keyedvectors.Vocab at 0x1e210af5710>,
#  "'اعل'": <gensim.models.keyedvectors.Vocab at 0x1e210af5748>,
#  "'جنس'": <gensim.models.keyedvectors.Vocab at 0x1e210af5780>,
#  "'قوة'": <gensim.models.keyedvectors.Vocab at 0x1e210af57b8>,
#  "'رجل'": <gensim.models.keyedvectors.Vocab at 0x1e210af57f0>,
#  "'رمل'": <gensim.models.keyedvectors.Vocab at 0x1e210af5828>,
#  "'يضء'": <gensim.models.keyedvectors.Vocab at 0x1e210af5860>,
#  "'عصم'": <gensim.models.keyedvectors.Vocab at 0x1e210af5898>,
#  "'قانصو'": <gensim.models.keyedvectors.Vocab at 0x1e210af58d0>,
#  "'شرى'": <gensim.models.keyedvectors.Vocab at 0x1e210af5908>,
#  "'عسر'": <gensim.models.keyedvectors.Vocab at 0x1e210af5940>,
#  "'رصص'": <gensim.models.keyedvectors.Vocab at 0x1e210af5978>,
#  "'طرز'": <gensim.models.keyedvectors.Vocab at 0x1e210af59b0>,
#  "'هيكل'": <gensim.models.keyedvectors.Vocab at 0x1e210af59e8>,
#  "'محرك'": <gensim.models.keyedvectors.Vocab at 0x1e210af5a20>,
#  "'كانت'": <gensim.models.keyedvectors.Vocab at 0x1e210af5a58>,
#  "'توقف'": <gensim.models.keyedvectors.Vocab at 0x1e210af5a90>,
#  "'بني'": <gensim.models.keyedvectors.Vocab at 0x1e210af5ac8>,
#  "'سكن'": <gensim.models.keyedvectors.Vocab at 0x1e210af5b00>,
#  "['وقف'": <gensim.models.keyedvectors.Vocab at 0x1e210af5b38>,
#  "'عزز'": <gensim.models.keyedvectors.Vocab at 0x1e210af5b70>,
#  "'مرسيدس'": <gensim.models.keyedvectors.Vocab at 0x1e210af5ba8>,
#  "'موف'": <gensim.models.keyedvectors.Vocab at 0x1e210af5be0>,
#  "'ص'": <gensim.models.keyedvectors.Vocab at 0x1e210af5c18>,
#  "'رفق'": <gensim.models.keyedvectors.Vocab at 0x1e210af5c50>,
#  "'ياس'": <gensim.models.keyedvectors.Vocab at 0x1e210af5c88>,
#  "'وسى'": <gensim.models.keyedvectors.Vocab at 0x1e210af5cc0>,
#  "'ضبط'": <gensim.models.keyedvectors.Vocab at 0x1e210af5cf8>,
#  "'اخر'": <gensim.models.keyedvectors.Vocab at 0x1e210af5d30>,
#  "'نيل'": <gensim.models.keyedvectors.Vocab at 0x1e210af5d68>,
#  "'جرى'": <gensim.models.keyedvectors.Vocab at 0x1e210af5da0>,
#  "'الي'": <gensim.models.keyedvectors.Vocab at 0x1e210af5dd8>,
#  "'نا'": <gensim.models.keyedvectors.Vocab at 0x1e210af5e10>,
#  "'لزم'": <gensim.models.keyedvectors.Vocab at 0x1e210af5e48>,
#  "'حق']": <gensim.models.keyedvectors.Vocab at 0x1e210af5e80>,
#  "'جبر'": <gensim.models.keyedvectors.Vocab at 0x1e210af5eb8>,
#  "'خلف'": <gensim.models.keyedvectors.Vocab at 0x1e210af5ef0>,
#  "'سبب'": <gensim.models.keyedvectors.Vocab at 0x1e210af5f28>,
#  "'ضرر'": <gensim.models.keyedvectors.Vocab at 0x1e210af5f60>,
#  "'جهل']": <gensim.models.keyedvectors.Vocab at 0x1e210af5f98>,
#  "['حضر'": <gensim.models.keyedvectors.Vocab at 0x1e210af5fd0>,
#  "'ايا'": <gensim.models.keyedvectors.Vocab at 0x1e210af8048>,
#  "'نطو'": <gensim.models.keyedvectors.Vocab at 0x1e210af8080>,
#  "'حاج'": <gensim.models.keyedvectors.Vocab at 0x1e210af80b8>,
#  "'كسر'": <gensim.models.keyedvectors.Vocab at 0x1e210af80f0>,
#  "'ساح'": <gensim.models.keyedvectors.Vocab at 0x1e210af8128>,
#  "'ممي'": <gensim.models.keyedvectors.Vocab at 0x1e210af8160>,
#  '"\'"': <gensim.models.keyedvectors.Vocab at 0x1e210af8198>,
#  "'شرف'": <gensim.models.keyedvectors.Vocab at 0x1e210af81d0>,
#  "'وسل'": <gensim.models.keyedvectors.Vocab at 0x1e210af8208>,
#  "'يمت'": <gensim.models.keyedvectors.Vocab at 0x1e210af8240>,
#  "'دير'": <gensim.models.keyedvectors.Vocab at 0x1e210af8278>,
#  "'شكب'": <gensim.models.keyedvectors.Vocab at 0x1e210af82b0>,
#  "'رسل'": <gensim.models.keyedvectors.Vocab at 0x1e210af82e8>,
#  "'رسم'": <gensim.models.keyedvectors.Vocab at 0x1e210af8320>,
#  "'فجر'": <gensim.models.keyedvectors.Vocab at 0x1e210af8358>,
#  "'اليوم'": <gensim.models.keyedvectors.Vocab at 0x1e210af8390>,
#  "'عبر'": <gensim.models.keyedvectors.Vocab at 0x1e210af83c8>,
#  "'سيئ'": <gensim.models.keyedvectors.Vocab at 0x1e210af8400>,
#  "'ثني']": <gensim.models.keyedvectors.Vocab at 0x1e210af8438>,
#  "'اهر'": <gensim.models.keyedvectors.Vocab at 0x1e210af8470>,
#  "'سؤل'": <gensim.models.keyedvectors.Vocab at 0x1e210af84a8>,
#  "'وظف'": <gensim.models.keyedvectors.Vocab at 0x1e210af84e0>,
#  "'ويل'": <gensim.models.keyedvectors.Vocab at 0x1e210af8518>,
#  "'كستر'": <gensim.models.keyedvectors.Vocab at 0x1e210af8550>,
#  "'ايد'": <gensim.models.keyedvectors.Vocab at 0x1e210af8588>,
#  "'صرح'": <gensim.models.keyedvectors.Vocab at 0x1e210af85c0>,
#  "'ذكر'": <gensim.models.keyedvectors.Vocab at 0x1e210af85f8>,
#  "'كشف'": <gensim.models.keyedvectors.Vocab at 0x1e210af8630>,
#  "'فعل'": <gensim.models.keyedvectors.Vocab at 0x1e210af8668>,
#  "'بلل'": <gensim.models.keyedvectors.Vocab at 0x1e210af86a0>,
#  "'الن'": <gensim.models.keyedvectors.Vocab at 0x1e210af86d8>,
#  "'شرك'": <gensim.models.keyedvectors.Vocab at 0x1e210af8710>,
#  "'سمر'": <gensim.models.keyedvectors.Vocab at 0x1e210af8748>,
#  "'كول'": <gensim.models.keyedvectors.Vocab at 0x1e210af8780>,
#  "'رول'": <gensim.models.keyedvectors.Vocab at 0x1e210af87b8>,
#  "'جدة'": <gensim.models.keyedvectors.Vocab at 0x1e210af87f0>,
#  "'صطدام'": <gensim.models.keyedvectors.Vocab at 0x1e210af8828>,
#  "'ف'": <gensim.models.keyedvectors.Vocab at 0x1e210af8860>,
#  "'دني'": <gensim.models.keyedvectors.Vocab at 0x1e210af8898>,
#  "'زعيتر'": <gensim.models.keyedvectors.Vocab at 0x1e210af88d0>,
#  "'جيب'": <gensim.models.keyedvectors.Vocab at 0x1e210af8908>,
#  "'هوند'": <gensim.models.keyedvectors.Vocab at 0x1e210af8940>,
#  "'ط'": <gensim.models.keyedvectors.Vocab at 0x1e210af8978>,
#  "'فرق'": <gensim.models.keyedvectors.Vocab at 0x1e210af89b0>,
#  "'عثم'": <gensim.models.keyedvectors.Vocab at 0x1e210af89e8>,
#  "'جذب'": <gensim.models.keyedvectors.Vocab at 0x1e210af8a20>,
#  "'صدق'": <gensim.models.keyedvectors.Vocab at 0x1e210af8a58>,
#  "'ادة'": <gensim.models.keyedvectors.Vocab at 0x1e210af8a90>,
#  "'قصد'": <gensim.models.keyedvectors.Vocab at 0x1e210af8ac8>,
#  "'خرج'": <gensim.models.keyedvectors.Vocab at 0x1e210af8b00>,
#  "['حلة'": <gensim.models.keyedvectors.Vocab at 0x1e210af8b38>,
#  "'قريطم'": <gensim.models.keyedvectors.Vocab at 0x1e210af8b70>,
#  "'شحد'": <gensim.models.keyedvectors.Vocab at 0x1e210af8ba8>,
#  "'شهب'": <gensim.models.keyedvectors.Vocab at 0x1e210af8be0>,
#  "'زكي'": <gensim.models.keyedvectors.Vocab at 0x1e210af8c18>,
#  "'زرق'": <gensim.models.keyedvectors.Vocab at 0x1e210af8c50>,
#  "'بدر'": <gensim.models.keyedvectors.Vocab at 0x1e210af8c88>,
#  "'شاتيل'": <gensim.models.keyedvectors.Vocab at 0x1e210af8cc0>,
#  "'عئش'": <gensim.models.keyedvectors.Vocab at 0x1e210af8cf8>,
#  "'بشر'": <gensim.models.keyedvectors.Vocab at 0x1e210af8d30>,
#  "'هيوند'": <gensim.models.keyedvectors.Vocab at 0x1e210af8d68>,
#  "'خضر'": <gensim.models.keyedvectors.Vocab at 0x1e210af8da0>,
#  "'صفو'": <gensim.models.keyedvectors.Vocab at 0x1e210af8dd8>,
#  "'صين'": <gensim.models.keyedvectors.Vocab at 0x1e210af8e10>,
#  "'عسف'": <gensim.models.keyedvectors.Vocab at 0x1e210af8e48>,
#  "'هدى'": <gensim.models.keyedvectors.Vocab at 0x1e210af8e80>,
#  "'حجر'": <gensim.models.keyedvectors.Vocab at 0x1e210af8eb8>,
#  "'خدج'": <gensim.models.keyedvectors.Vocab at 0x1e210af8ef0>,
#  "'قرة'": <gensim.models.keyedvectors.Vocab at 0x1e210af8f28>,
#  "['شكى'": <gensim.models.keyedvectors.Vocab at 0x1e210af8f60>,
#  "'جار'": <gensim.models.keyedvectors.Vocab at 0x1e210af8f98>,
#  "'ش'": <gensim.models.keyedvectors.Vocab at 0x1e210af8fd0>,
#  "'شور'": <gensim.models.keyedvectors.Vocab at 0x1e210afc048>,
#  "'حيل']": <gensim.models.keyedvectors.Vocab at 0x1e210afc080>,
#  "'عيدو'": <gensim.models.keyedvectors.Vocab at 0x1e210afc0b8>,
#  "'وكل'": <gensim.models.keyedvectors.Vocab at 0x1e210afc0f0>,
#  "'حمي'": <gensim.models.keyedvectors.Vocab at 0x1e210afc128>,
#  "'خرو'": <gensim.models.keyedvectors.Vocab at 0x1e210afc160>,
#  "'فخر'": <gensim.models.keyedvectors.Vocab at 0x1e210afc198>,
#  "'قدح'": <gensim.models.keyedvectors.Vocab at 0x1e210afc1d0>,
#  "'ذم'": <gensim.models.keyedvectors.Vocab at 0x1e210afc208>,
#  "'هدد'": <gensim.models.keyedvectors.Vocab at 0x1e210afc240>,
#  "'رجع'": <gensim.models.keyedvectors.Vocab at 0x1e210afc278>,
#  "'قضء'": <gensim.models.keyedvectors.Vocab at 0x1e210afc2b0>,
#  "'اشر'": <gensim.models.keyedvectors.Vocab at 0x1e210afc2e8>,
#  "'ترك'": <gensim.models.keyedvectors.Vocab at 0x1e210afc320>,
#  "'لقء'": <gensim.models.keyedvectors.Vocab at 0x1e210afc358>,
#  "'سند'": <gensim.models.keyedvectors.Vocab at 0x1e210afc390>,
#  "'قمة'": <gensim.models.keyedvectors.Vocab at 0x1e210afc3c8>,
#  "'بين'": <gensim.models.keyedvectors.Vocab at 0x1e210afc400>,
#  "'كمل'": <gensim.models.keyedvectors.Vocab at 0x1e210afc438>,
#  "'هوة'": <gensim.models.keyedvectors.Vocab at 0x1e210afc470>,
#  "'هند'": <gensim.models.keyedvectors.Vocab at 0x1e210afc4a8>,
#  "'درس'": <gensim.models.keyedvectors.Vocab at 0x1e210afc4e0>,
#  "'عود'": <gensim.models.keyedvectors.Vocab at 0x1e210afc518>,
#  "'لمذ'": <gensim.models.keyedvectors.Vocab at 0x1e210afc550>,
#  "'توم'": <gensim.models.keyedvectors.Vocab at 0x1e210afc588>,
#  "'لذم'": <gensim.models.keyedvectors.Vocab at 0x1e210afc5c0>,
#  "'كلم'": <gensim.models.keyedvectors.Vocab at 0x1e210afc5f8>,
#  "'حول'": <gensim.models.keyedvectors.Vocab at 0x1e210afc630>,
#  "'مسك'": <gensim.models.keyedvectors.Vocab at 0x1e210afc668>,
#  "'غرض'": <gensim.models.keyedvectors.Vocab at 0x1e210afc6a0>,
#  "'ضرب'": <gensim.models.keyedvectors.Vocab at 0x1e210afc6d8>,
#  "'بهج'": <gensim.models.keyedvectors.Vocab at 0x1e210afc710>,
#  "'احتيالية'": <gensim.models.keyedvectors.Vocab at 0x1e210afc748>,
#  "'مطر'": <gensim.models.keyedvectors.Vocab at 0x1e210afc780>,
#  "'بضع'": <gensim.models.keyedvectors.Vocab at 0x1e210afc7b8>,
#  "'خرى'": <gensim.models.keyedvectors.Vocab at 0x1e210afc7f0>,
#  "'فرا'": <gensim.models.keyedvectors.Vocab at 0x1e210afc828>,
#  "'حيل'": <gensim.models.keyedvectors.Vocab at 0x1e210afc860>,
#  "'قيم'": <gensim.models.keyedvectors.Vocab at 0x1e210afc898>,
#  "'امر']": <gensim.models.keyedvectors.Vocab at 0x1e210afc8d0>,
#  "'زهر'": <gensim.models.keyedvectors.Vocab at 0x1e210afc908>,
#  "'دين'": <gensim.models.keyedvectors.Vocab at 0x1e210afc940>,
#  "'قفل'": <gensim.models.keyedvectors.Vocab at 0x1e210afc978>,
#  "'اذن'": <gensim.models.keyedvectors.Vocab at 0x1e210afc9b0>,
#  "'سبق']": <gensim.models.keyedvectors.Vocab at 0x1e210afc9e8>,
#  "'روش'": <gensim.models.keyedvectors.Vocab at 0x1e210afca20>,
#  "'عمد'": <gensim.models.keyedvectors.Vocab at 0x1e210afca58>,
#  "'قاعد'": <gensim.models.keyedvectors.Vocab at 0x1e210afca90>,
#  "'جيش'": <gensim.models.keyedvectors.Vocab at 0x1e210afcac8>,
#  "'هشم'": <gensim.models.keyedvectors.Vocab at 0x1e210afcb00>,
#  "'فيد'": <gensim.models.keyedvectors.Vocab at 0x1e210afcb38>,
#  "'جول'": <gensim.models.keyedvectors.Vocab at 0x1e210afcb70>,
#  "'حلي'": <gensim.models.keyedvectors.Vocab at 0x1e210afcba8>,
#  "'ثيب'": <gensim.models.keyedvectors.Vocab at 0x1e210afcbe0>,
#  "'كئن'": <gensim.models.keyedvectors.Vocab at 0x1e210afcc18>,
#  "'صلب'": <gensim.models.keyedvectors.Vocab at 0x1e210afcc50>,
#  "'طبق'": <gensim.models.keyedvectors.Vocab at 0x1e210afcc88>,
#  "'لسل'": <gensim.models.keyedvectors.Vocab at 0x1e210afccc0>,
#  "'ذهب'": <gensim.models.keyedvectors.Vocab at 0x1e210afccf8>,
#  "['حدث'": <gensim.models.keyedvectors.Vocab at 0x1e210afcd30>,
#  "'همم'": <gensim.models.keyedvectors.Vocab at 0x1e210afcd68>,
#  "'شاه'": <gensim.models.keyedvectors.Vocab at 0x1e210afcda0>,
#  "'يما'": <gensim.models.keyedvectors.Vocab at 0x1e210afcdd8>,
#  "'برو'": <gensim.models.keyedvectors.Vocab at 0x1e210afce10>,
#  "'صعب'": <gensim.models.keyedvectors.Vocab at 0x1e210afce48>,
#  "'فؤد'": <gensim.models.keyedvectors.Vocab at 0x1e210afce80>,
#  "'طبر'": <gensim.models.keyedvectors.Vocab at 0x1e210afceb8>,
#  "'صبح'": <gensim.models.keyedvectors.Vocab at 0x1e210afcef0>,
#  "'حقب'": <gensim.models.keyedvectors.Vocab at 0x1e210afcf28>,
#  "'ثبت'": <gensim.models.keyedvectors.Vocab at 0x1e210afcf60>,
#  "'خصة'": <gensim.models.keyedvectors.Vocab at 0x1e210afcf98>,
#  "'ظرف'": <gensim.models.keyedvectors.Vocab at 0x1e210afcfd0>,
#  "'عقب'": <gensim.models.keyedvectors.Vocab at 0x1e210b00048>,
#  "'صرف'": <gensim.models.keyedvectors.Vocab at 0x1e210b00080>,
#  "'ازم'": <gensim.models.keyedvectors.Vocab at 0x1e210b000b8>,
#  "'تمم'": <gensim.models.keyedvectors.Vocab at 0x1e210b000f0>,
#  "'تولد'": <gensim.models.keyedvectors.Vocab at 0x1e210b00128>,
#  "'رابيد'": <gensim.models.keyedvectors.Vocab at 0x1e210b00160>,
#  "'كونغو'": <gensim.models.keyedvectors.Vocab at 0x1e210b00198>,
#  "'عبدالناصر'": <gensim.models.keyedvectors.Vocab at 0x1e210b001d0>,
#  "'حطة'": <gensim.models.keyedvectors.Vocab at 0x1e210b00208>,
#  "'قدد'": <gensim.models.keyedvectors.Vocab at 0x1e210b00240>,
#  "'ه']": <gensim.models.keyedvectors.Vocab at 0x1e210b00278>,
#  "'لسط'": <gensim.models.keyedvectors.Vocab at 0x1e210b002b0>,
#  "'بلس'": <gensim.models.keyedvectors.Vocab at 0x1e210b002e8>,
#  "'فتن'": <gensim.models.keyedvectors.Vocab at 0x1e210b00320>,
#  "'بئر'": <gensim.models.keyedvectors.Vocab at 0x1e210b00358>,
#  "'نطق'": <gensim.models.keyedvectors.Vocab at 0x1e210b00390>,
#  "'شرط'": <gensim.models.keyedvectors.Vocab at 0x1e210b003c8>,
#  "['ورد'": <gensim.models.keyedvectors.Vocab at 0x1e210b00400>,
#  "'تصل'": <gensim.models.keyedvectors.Vocab at 0x1e210b00438>,
#  "'خط'": <gensim.models.keyedvectors.Vocab at 0x1e210b00470>,
#  "'نجد'": <gensim.models.keyedvectors.Vocab at 0x1e210b004a8>,
#  "'فاد'": <gensim.models.keyedvectors.Vocab at 0x1e210b004e0>,
#  "'حمراء'": <gensim.models.keyedvectors.Vocab at 0x1e210b00518>,
#  "'حسب'": <gensim.models.keyedvectors.Vocab at 0x1e210b00550>,
#  "'فدة'": <gensim.models.keyedvectors.Vocab at 0x1e210b00588>,
#  "'زلة'": <gensim.models.keyedvectors.Vocab at 0x1e210b005c0>,
#  "'دعء']": <gensim.models.keyedvectors.Vocab at 0x1e210b005f8>,
#  "'بسم'": <gensim.models.keyedvectors.Vocab at 0x1e210b00630>,
#  "'امل'": <gensim.models.keyedvectors.Vocab at 0x1e210b00668>,
#  "'تود'": <gensim.models.keyedvectors.Vocab at 0x1e210b006a0>,
#  "'قوف'": <gensim.models.keyedvectors.Vocab at 0x1e210b006d8>,
#  "'تيد'": <gensim.models.keyedvectors.Vocab at 0x1e210b00710>,
#  "'وحة'": <gensim.models.keyedvectors.Vocab at 0x1e210b00748>,
#  "'تحف'": <gensim.models.keyedvectors.Vocab at 0x1e210b00780>,
#  "'كنس'": <gensim.models.keyedvectors.Vocab at 0x1e210b007b8>,
#  "'شخص'": <gensim.models.keyedvectors.Vocab at 0x1e210b007f0>,
#  "'جسر'": <gensim.models.keyedvectors.Vocab at 0x1e210b00828>,
#  "'عدل'": <gensim.models.keyedvectors.Vocab at 0x1e210b00860>,
#  "'ردو'": <gensim.models.keyedvectors.Vocab at 0x1e210b00898>,
#  "'باج'": <gensim.models.keyedvectors.Vocab at 0x1e210b008d0>,
#  "'نبذ'": <gensim.models.keyedvectors.Vocab at 0x1e210b00908>,
#  "'حمز'": <gensim.models.keyedvectors.Vocab at 0x1e210b00940>,
#  "'حرك'": <gensim.models.keyedvectors.Vocab at 0x1e210b00978>,
#  "'اصب'": <gensim.models.keyedvectors.Vocab at 0x1e210b009b0>,
#  "'غسن'": <gensim.models.keyedvectors.Vocab at 0x1e210b009e8>,
#  "'خلص'": <gensim.models.keyedvectors.Vocab at 0x1e210b00a20>,
#  "'تبت'": <gensim.models.keyedvectors.Vocab at 0x1e210b00a58>,
#  "'بحة'": <gensim.models.keyedvectors.Vocab at 0x1e210b00a90>,
#  "'جعفر'": <gensim.models.keyedvectors.Vocab at 0x1e210b00ac8>,
#  "'غية'": <gensim.models.keyedvectors.Vocab at 0x1e210b00b00>,
#  "'سوق'": <gensim.models.keyedvectors.Vocab at 0x1e210b00b38>,
#  "'يغن'": <gensim.models.keyedvectors.Vocab at 0x1e210b00b70>,
#  "'راب'": <gensim.models.keyedvectors.Vocab at 0x1e210b00ba8>,
#  "'رون'": <gensim.models.keyedvectors.Vocab at 0x1e210b00be0>,
#  "'ستة'": <gensim.models.keyedvectors.Vocab at 0x1e210b00c18>,
#  "'طقت'": <gensim.models.keyedvectors.Vocab at 0x1e210b00c50>,
#  "'غصن'": <gensim.models.keyedvectors.Vocab at 0x1e210b00c88>,
#  "'عبس'": <gensim.models.keyedvectors.Vocab at 0x1e210b00cc0>,
#  "'غربل'": <gensim.models.keyedvectors.Vocab at 0x1e210b00cf8>,
#  "'س'": <gensim.models.keyedvectors.Vocab at 0x1e210b00d30>,
#  "'عدم'": <gensim.models.keyedvectors.Vocab at 0x1e210b00d68>,
#  "'سجل'": <gensim.models.keyedvectors.Vocab at 0x1e210b00da0>,
#  "['سلم'": <gensim.models.keyedvectors.Vocab at 0x1e210b00dd8>,
#  "'الك'": <gensim.models.keyedvectors.Vocab at 0x1e210b00e10>,
#  "'روم'": <gensim.models.keyedvectors.Vocab at 0x1e210b00e48>,
#  "'معا'": <gensim.models.keyedvectors.Vocab at 0x1e210b00e80>,
#  "'حرق'": <gensim.models.keyedvectors.Vocab at 0x1e210b00eb8>,
#  "'رتباء'": <gensim.models.keyedvectors.Vocab at 0x1e210b00ef0>,
#  "'اثر'": <gensim.models.keyedvectors.Vocab at 0x1e210b00f28>,
#  "'صيد'": <gensim.models.keyedvectors.Vocab at 0x1e210b00f60>,
#  "'وحد'": <gensim.models.keyedvectors.Vocab at 0x1e210b00f98>,
#  "'كرس'": <gensim.models.keyedvectors.Vocab at 0x1e210b00fd0>,
#  "'كور'": <gensim.models.keyedvectors.Vocab at 0x1e210b03048>,
#  "'فيض'": <gensim.models.keyedvectors.Vocab at 0x1e210b03080>,
#  "'سرى'": <gensim.models.keyedvectors.Vocab at 0x1e210b030b8>,
#  "'اجر'": <gensim.models.keyedvectors.Vocab at 0x1e210b030f0>,
#  "'سعف'": <gensim.models.keyedvectors.Vocab at 0x1e210b03128>,
#  "'ولي'": <gensim.models.keyedvectors.Vocab at 0x1e210b03160>,
#  "'فتش'": <gensim.models.keyedvectors.Vocab at 0x1e210b03198>,
#  "'كهرباء'": <gensim.models.keyedvectors.Vocab at 0x1e210b031d0>,
#  "'ديب'": <gensim.models.keyedvectors.Vocab at 0x1e210b03208>,
#  "'جبن'": <gensim.models.keyedvectors.Vocab at 0x1e210b03240>,
#  "'ديكو'": <gensim.models.keyedvectors.Vocab at 0x1e210b03278>,
#  "'قلل'": <gensim.models.keyedvectors.Vocab at 0x1e210b032b0>,
#  "'همة'": <gensim.models.keyedvectors.Vocab at 0x1e210b032e8>,
#  "'نفذ'": <gensim.models.keyedvectors.Vocab at 0x1e210b03320>,
#  "'تير'": <gensim.models.keyedvectors.Vocab at 0x1e210b03358>,
#  "'كهربائ'": <gensim.models.keyedvectors.Vocab at 0x1e210b03390>,
#  "'دفع'": <gensim.models.keyedvectors.Vocab at 0x1e210b033c8>,
#  "'صفع'": <gensim.models.keyedvectors.Vocab at 0x1e210b03400>,
#  "'وجه'": <gensim.models.keyedvectors.Vocab at 0x1e210b03438>,
#  "'كلد'": <gensim.models.keyedvectors.Vocab at 0x1e210b03470>,
#  "'اضي'": <gensim.models.keyedvectors.Vocab at 0x1e210b034a8>,
#  "'قرب'": <gensim.models.keyedvectors.Vocab at 0x1e210b034e0>,
#  "'بوظ'": <gensim.models.keyedvectors.Vocab at 0x1e210b03518>,
#  "'ردي'": <gensim.models.keyedvectors.Vocab at 0x1e210b03550>,
#  "'هوي'": <gensim.models.keyedvectors.Vocab at 0x1e210b03588>,
#  "'عنة'": <gensim.models.keyedvectors.Vocab at 0x1e210b035c0>,
#  "'لفو'": <gensim.models.keyedvectors.Vocab at 0x1e210b035f8>,
#  "'رمز'": <gensim.models.keyedvectors.Vocab at 0x1e210b03630>,
#  "'شيخو'": <gensim.models.keyedvectors.Vocab at 0x1e210b03668>,
#  "'هاوجيو'": <gensim.models.keyedvectors.Vocab at 0x1e210b036a0>,
#  "'رتقال'": <gensim.models.keyedvectors.Vocab at 0x1e210b036d8>,
#  "'نور'": <gensim.models.keyedvectors.Vocab at 0x1e210b03710>,
#  "'مرو'": <gensim.models.keyedvectors.Vocab at 0x1e210b03748>,
#  "'هنا'": <gensim.models.keyedvectors.Vocab at 0x1e210b03780>,
#  "'رضى'": <gensim.models.keyedvectors.Vocab at 0x1e210b037b8>,
#  "'همن'": <gensim.models.keyedvectors.Vocab at 0x1e210b037f0>,
#  "'بيب'": <gensim.models.keyedvectors.Vocab at 0x1e210b03828>,
#  "'نظر'": <gensim.models.keyedvectors.Vocab at 0x1e210b03860>,
#  "'هرل'": <gensim.models.keyedvectors.Vocab at 0x1e210b03898>,
#  "'حصرو'": <gensim.models.keyedvectors.Vocab at 0x1e210b038d0>,
#  "'علء'": <gensim.models.keyedvectors.Vocab at 0x1e210b03908>,
#  "'عيص'": <gensim.models.keyedvectors.Vocab at 0x1e210b03940>,
#  "'ران'": <gensim.models.keyedvectors.Vocab at 0x1e210b03978>,
#  "'تحت'": <gensim.models.keyedvectors.Vocab at 0x1e210b039b0>,
#  "'اكس'": <gensim.models.keyedvectors.Vocab at 0x1e210b039e8>,
#  "'كسف'": <gensim.models.keyedvectors.Vocab at 0x1e210b03a20>,
#  "'تلا'": <gensim.models.keyedvectors.Vocab at 0x1e210b03a58>,
#  "'سنء'": <gensim.models.keyedvectors.Vocab at 0x1e210b03a90>,
#  "'ريض'": <gensim.models.keyedvectors.Vocab at 0x1e210b03ac8>,
#  "'رفع'": <gensim.models.keyedvectors.Vocab at 0x1e210b03b00>,
#  "'رزق'": <gensim.models.keyedvectors.Vocab at 0x1e210b03b38>,
#  "'نزل']": <gensim.models.keyedvectors.Vocab at 0x1e210b03b70>,
#  "'محي'": <gensim.models.keyedvectors.Vocab at 0x1e210b03ba8>,
#  "'عام'": <gensim.models.keyedvectors.Vocab at 0x1e210b03be0>,
#  "'بنى'": <gensim.models.keyedvectors.Vocab at 0x1e210b03c18>,
#  "'حفر'": <gensim.models.keyedvectors.Vocab at 0x1e210b03c50>,
#  "'فرر'": <gensim.models.keyedvectors.Vocab at 0x1e210b03c88>,
#  "'يمن'": <gensim.models.keyedvectors.Vocab at 0x1e210b03cc0>,
#  "'شلح'": <gensim.models.keyedvectors.Vocab at 0x1e210b03cf8>,
#  "'سيل'": <gensim.models.keyedvectors.Vocab at 0x1e210b03d30>,
#  "'نجى'": <gensim.models.keyedvectors.Vocab at 0x1e210b03d68>,
#  "'خير'": <gensim.models.keyedvectors.Vocab at 0x1e210b03da0>,
#  "'سنة'": <gensim.models.keyedvectors.Vocab at 0x1e210b03dd8>,
#  "'زهراء'": <gensim.models.keyedvectors.Vocab at 0x1e210b03e10>,
#  "'نجي'": <gensim.models.keyedvectors.Vocab at 0x1e210b03e48>,
#  "'رشد'": <gensim.models.keyedvectors.Vocab at 0x1e210b03e80>,
#  "'عطي'": <gensim.models.keyedvectors.Vocab at 0x1e210b03eb8>,
#  "'ششة'": <gensim.models.keyedvectors.Vocab at 0x1e210b03ef0>,
#  "'حسم'": <gensim.models.keyedvectors.Vocab at 0x1e210b03f28>,
#  "'كية'": <gensim.models.keyedvectors.Vocab at 0x1e210b03f60>,
#  "'جدد']": <gensim.models.keyedvectors.Vocab at 0x1e210b03f98>,
#  "'يدس'": <gensim.models.keyedvectors.Vocab at 0x1e210b03fd0>,
#  "'مثل'": <gensim.models.keyedvectors.Vocab at 0x1e210b07048>,
#  "'فوض'": <gensim.models.keyedvectors.Vocab at 0x1e210b07080>,
#  "'وقع'": <gensim.models.keyedvectors.Vocab at 0x1e210b070b8>,
#  "'طون'": <gensim.models.keyedvectors.Vocab at 0x1e210b070f0>,
#  "'ملك'": <gensim.models.keyedvectors.Vocab at 0x1e210b07128>,
#  "'دقج'": <gensim.models.keyedvectors.Vocab at 0x1e210b07160>,
#  "['خلل'": <gensim.models.keyedvectors.Vocab at 0x1e210b07198>,
#  "'ليل'": <gensim.models.keyedvectors.Vocab at 0x1e210b071d0>,
#  "'صرم'": <gensim.models.keyedvectors.Vocab at 0x1e210b07208>,
#  "'ينه'": <gensim.models.keyedvectors.Vocab at 0x1e210b07240>,
#  "'م']": <gensim.models.keyedvectors.Vocab at 0x1e210b07278>,
#  "['افد'": <gensim.models.keyedvectors.Vocab at 0x1e210b072b0>,
#  "'رتب'": <gensim.models.keyedvectors.Vocab at 0x1e210b072e8>,
#  "'وصل'": <gensim.models.keyedvectors.Vocab at 0x1e210b07320>,
#  "'دكتور'": <gensim.models.keyedvectors.Vocab at 0x1e210b07358>,
#  "'رقي'": <gensim.models.keyedvectors.Vocab at 0x1e210b07390>,
#  "'ركز'": <gensim.models.keyedvectors.Vocab at 0x1e210b073c8>,
#  "'بكر'": <gensim.models.keyedvectors.Vocab at 0x1e210b07400>,
#  "'سيف'": <gensim.models.keyedvectors.Vocab at 0x1e210b07438>,
#  "'يذء'": <gensim.models.keyedvectors.Vocab at 0x1e210b07470>,
#  "'دعئ'": <gensim.models.keyedvectors.Vocab at 0x1e210b074a8>,
#  "'هبة'": <gensim.models.keyedvectors.Vocab at 0x1e210b074e0>,
#  "'قمة']": <gensim.models.keyedvectors.Vocab at 0x1e210b07518>,
#  "'طبش'": <gensim.models.keyedvectors.Vocab at 0x1e210b07550>,
#  "'جوزاف'": <gensim.models.keyedvectors.Vocab at 0x1e210b07588>,
#  "'رهم'": <gensim.models.keyedvectors.Vocab at 0x1e210b075c0>,
#  "'سفر'": <gensim.models.keyedvectors.Vocab at 0x1e210b075f8>,
#  "'ارس'": <gensim.models.keyedvectors.Vocab at 0x1e210b07630>,
#  "'وهم'": <gensim.models.keyedvectors.Vocab at 0x1e210b07668>,
#  "'رنس'": <gensim.models.keyedvectors.Vocab at 0x1e210b076a0>,
#  "'رغم'": <gensim.models.keyedvectors.Vocab at 0x1e210b076d8>,
#  "'لقى'": <gensim.models.keyedvectors.Vocab at 0x1e210b07710>,
#  "'مطل'": <gensim.models.keyedvectors.Vocab at 0x1e210b07748>,
#  "'جورج'": <gensim.models.keyedvectors.Vocab at 0x1e210b07780>,
#  "'جدل'": <gensim.models.keyedvectors.Vocab at 0x1e210b077b8>,
#  "'صفة'": <gensim.models.keyedvectors.Vocab at 0x1e210b077f0>,
#  "'حرض'": <gensim.models.keyedvectors.Vocab at 0x1e210b07828>,
#  "'منع'": <gensim.models.keyedvectors.Vocab at 0x1e210b07860>,
#  "'عطئ'": <gensim.models.keyedvectors.Vocab at 0x1e210b07898>,
#  "'ولد']": <gensim.models.keyedvectors.Vocab at 0x1e210b078d0>,
#  "'دعق'": <gensim.models.keyedvectors.Vocab at 0x1e210b07908>,
#  "'نول'": <gensim.models.keyedvectors.Vocab at 0x1e210b07940>,
#  "'مهى'": <gensim.models.keyedvectors.Vocab at 0x1e210b07978>,
#  "'وزو'": <gensim.models.keyedvectors.Vocab at 0x1e210b079b0>,
#  "'اصف'": <gensim.models.keyedvectors.Vocab at 0x1e210b079e8>,
#  "'اسم'": <gensim.models.keyedvectors.Vocab at 0x1e210b07a20>,
#  "'ثمن'": <gensim.models.keyedvectors.Vocab at 0x1e210b07a58>,
#  "'رئس'": <gensim.models.keyedvectors.Vocab at 0x1e210b07a90>,
#  "'رقب'": <gensim.models.keyedvectors.Vocab at 0x1e210b07ac8>,
#  "'الت'": <gensim.models.keyedvectors.Vocab at 0x1e210b07b00>,
#  "'سمء'": <gensim.models.keyedvectors.Vocab at 0x1e210b07b38>,
#  "'فول'": <gensim.models.keyedvectors.Vocab at 0x1e210b07b70>,
#  "'دفتر'": <gensim.models.keyedvectors.Vocab at 0x1e210b07ba8>,
#  "'لف'": <gensim.models.keyedvectors.Vocab at 0x1e210b07be0>,
#  "['حصل'": <gensim.models.keyedvectors.Vocab at 0x1e210b07c18>,
#  "'نمر'": <gensim.models.keyedvectors.Vocab at 0x1e210b07c50>,
#  "'سعد'": <gensim.models.keyedvectors.Vocab at 0x1e210b07c88>,
#  "'رند'": <gensim.models.keyedvectors.Vocab at 0x1e210b07cc0>,
#  "'عرب'": <gensim.models.keyedvectors.Vocab at 0x1e210b07cf8>,
#  "'دلل'": <gensim.models.keyedvectors.Vocab at 0x1e210b07d30>,
#  "'لسن'": <gensim.models.keyedvectors.Vocab at 0x1e210b07d68>,
#  "'يشل'": <gensim.models.keyedvectors.Vocab at 0x1e210b07da0>,
#  "'الم'": <gensim.models.keyedvectors.Vocab at 0x1e210b07dd8>,
#  "'بسط'": <gensim.models.keyedvectors.Vocab at 0x1e210b07e10>,
#  "['تم'": <gensim.models.keyedvectors.Vocab at 0x1e210b07e48>,
#  "'يرو']": <gensim.models.keyedvectors.Vocab at 0x1e210b07e80>,
#  "'ايل'": <gensim.models.keyedvectors.Vocab at 0x1e210b07eb8>,
#  "'راد'": <gensim.models.keyedvectors.Vocab at 0x1e210b07ef0>,
#  "'غندور'": <gensim.models.keyedvectors.Vocab at 0x1e210b07f28>,
#  "'توعد'": <gensim.models.keyedvectors.Vocab at 0x1e210b07f60>,
#  "'اخت'": <gensim.models.keyedvectors.Vocab at 0x1e210b07f98>,
#  "'ظهر'": <gensim.models.keyedvectors.Vocab at 0x1e210b07fd0>,
#  "'ورد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b048>,
#  "'كظم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b080>,
#  "'اهن'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b0b8>,
#  "'يثر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b0f0>,
#  "'يمس'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b128>,
#  "'خلل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b160>,
#  "'برج'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b198>,
#  "'فرس'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b1d0>,
#  "'زين'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b208>,
#  "'ؤيد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b240>,
#  "'يجو'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b278>,
#  "'خدم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b2b0>,
#  "'زلي'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b2e8>,
#  "'فيليبينية'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b320>,
#  "'حئط'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b358>,
#  "'نفق'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b390>,
#  "'ينس'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b3c8>,
#  "'قلب'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b400>,
#  "'سقف'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b438>,
#  "'ندق'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b470>,
#  "'ثلاثماية'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b4a8>,
#  "'الف'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b4e0>,
#  "'لير'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b518>,
#  "'زحم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b550>,
#  "'يقم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b588>,
#  "'لغد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b5c0>,
#  "'وطى'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b5f8>,
#  "'بست'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b630>,
#  "'علا'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b668>,
#  "'مين'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b6a0>,
#  "'طرئ'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b6d8>,
#  "'طول'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b710>,
#  "'سونغ'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b748>,
#  "'نوت'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b780>,
#  "'جي'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b7b8>,
#  "'ام'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b7f0>,
#  "'سي'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b828>,
#  "'سلك'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b860>,
#  "'ؤدي'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b898>,
#  "'حمر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b8d0>,
#  "'ايب'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b908>,
#  "'اهت'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b940>,
#  "'عزلد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b978>,
#  "'عجي'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b9b0>,
#  "'هيم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0b9e8>,
#  "'عشر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ba20>,
#  "'رور'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ba58>,
#  "'غيث'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ba90>,
#  "'شرة'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bac8>,
#  "'ضوئ'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bb00>,
#  "'خضراء'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bb38>,
#  "'اذ'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bb70>,
#  "'قام'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bba8>,
#  "'طمئ'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bbe0>,
#  "'هجم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bc18>,
#  "'وجه']": <gensim.models.keyedvectors.Vocab at 0x1e210b0bc50>,
#  "'لطف'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bc88>,
#  "'رصد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bcc0>,
#  "'بن'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bcf8>,
#  "'بدي'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bd30>,
#  "'يدع'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bd68>,
#  "['دعى'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bda0>,
#  "'عدو'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bdd8>,
#  "'صور'": <gensim.models.keyedvectors.Vocab at 0x1e210b0be10>,
#  "'دئم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0be48>,
#  "'خلع'": <gensim.models.keyedvectors.Vocab at 0x1e210b0be80>,
#  "'يكن'": <gensim.models.keyedvectors.Vocab at 0x1e210b0beb8>,
#  "'يتب'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bef0>,
#  "'او'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bf28>,
#  "'حتي'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bf60>,
#  "'رنج'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bf98>,
#  "'روفر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0bfd0>,
#  "'قزح'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e048>,
#  "'فرح'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e080>,
#  "'ذيد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e0b8>,
#  "'فضل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e0f0>,
#  "'نصب'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e128>,
#  "'شهداء'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e160>,
#  "'ا'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e198>,
#  "'طفل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e1d0>,
#  "'يزب'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e208>,
#  "'عبدالل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e240>,
#  "'شفق'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e278>,
#  "'سبح'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e2b0>,
#  "'شعب'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e2e8>,
#  "'كوثر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e320>,
#  "'درويش'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e358>,
#  "'وسم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e390>,
#  "'سلت'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e3c8>,
#  "'هام'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e400>,
#  "'غنم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e438>,
#  "'خيل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e470>,
#  "'علب'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e4a8>,
#  "'زيد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e4e0>,
#  "'غنى'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e518>,
#  "'فصد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e550>,
#  "'اند'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e588>,
#  "'شيخ'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e5c0>,
#  "'ثرا'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e5f8>,
#  "'فيل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e630>,
#  "'قمع'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e668>,
#  "'فيز'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e6a0>,
#  "'هبر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e6d8>,
#  "'نزف'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e710>,
#  "'انف'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e748>,
#  "'خدش'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e780>,
#  "'غالاكس'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e7b8>,
#  "'كرن'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e7f0>,
#  "'سبع'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e828>,
#  "'فوق'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e860>,
#  "'رلى'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e898>,
#  "'كيل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e8d0>,
#  "'ارل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e908>,
#  "'انطوانيت'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e940>,
#  "'ثمر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e978>,
#  "'عرد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e9b0>,
#  "'شكت'": <gensim.models.keyedvectors.Vocab at 0x1e210b0e9e8>,
#  "'رمي'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ea20>,
#  "'سجن'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ea58>,
#  "['ادع'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ea90>,
#  "'غدة'": <gensim.models.keyedvectors.Vocab at 0x1e210b0eac8>,
#  "'فلسطينية'": <gensim.models.keyedvectors.Vocab at 0x1e210b0eb00>,
#  "'تتم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0eb38>,
#  "'رود'": <gensim.models.keyedvectors.Vocab at 0x1e210b0eb70>,
#  "'قصر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0eba8>,
#  "'عين'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ebe0>,
#  "['ان'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ec18>,
#  "'ابو'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ec50>,
#  "'لقب'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ec88>,
#  "'كنا'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ecc0>,
#  "'ردد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ecf8>,
#  "'يني'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ed30>,
#  "'تطع'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ed68>,
#  "'اعط'": <gensim.models.keyedvectors.Vocab at 0x1e210b0eda0>,
#  "'قما'": <gensim.models.keyedvectors.Vocab at 0x1e210b0edd8>,
#  "'حمم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ee10>,
#  "'اقم'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ee48>,
#  "'شمس'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ee80>,
#  "'شقة'": <gensim.models.keyedvectors.Vocab at 0x1e210b0eeb8>,
#  "'اسك'": <gensim.models.keyedvectors.Vocab at 0x1e210b0eef0>,
#  "'عقد'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ef28>,
#  "'يجر'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ef60>,
#  "'بدل'": <gensim.models.keyedvectors.Vocab at 0x1e210b0ef98>,
#  "'سني'": <gensim.models.keyedvectors.Vocab at 0x1e210b0efd0>,
#  "'خرب'": <gensim.models.keyedvectors.Vocab at 0x1e210b11048>,
#  "'حيط'": <gensim.models.keyedvectors.Vocab at 0x1e210b11080>,
#  "'علق'": <gensim.models.keyedvectors.Vocab at 0x1e210b110b8>,
#  "'وفة'": <gensim.models.keyedvectors.Vocab at 0x1e210b110f0>,
#  "'قنع'": <gensim.models.keyedvectors.Vocab at 0x1e210b11128>,
#  "'وقت'": <gensim.models.keyedvectors.Vocab at 0x1e210b11160>,
#  "'جهد'": <gensim.models.keyedvectors.Vocab at 0x1e210b11198>,
#  "'كبر'": <gensim.models.keyedvectors.Vocab at 0x1e210b111d0>,
#  "'نجز'": <gensim.models.keyedvectors.Vocab at 0x1e210b11208>,
#  "'يعد'": <gensim.models.keyedvectors.Vocab at 0x1e210b11240>,
#  "'مال'": <gensim.models.keyedvectors.Vocab at 0x1e210b11278>,
#  "'الش'": <gensim.models.keyedvectors.Vocab at 0x1e210b112b0>,
#  "'فرت'": <gensim.models.keyedvectors.Vocab at 0x1e210b112e8>,
#  "'سوس'": <gensim.models.keyedvectors.Vocab at 0x1e210b11320>,
#  "'اوط'": <gensim.models.keyedvectors.Vocab at 0x1e210b11358>,
#  "'بشي'": <gensim.models.keyedvectors.Vocab at 0x1e210b11390>,
#  "'ندي'": <gensim.models.keyedvectors.Vocab at 0x1e210b113c8>,
#  "'شبرو'": <gensim.models.keyedvectors.Vocab at 0x1e210b11400>,
#  "'خيم'": <gensim.models.keyedvectors.Vocab at 0x1e210b11438>,
#  "'هاواو'": <gensim.models.keyedvectors.Vocab at 0x1e210b11470>,
#  "'ربر'": <gensim.models.keyedvectors.Vocab at 0x1e210b114a8>,
#  "'كعك'": <gensim.models.keyedvectors.Vocab at 0x1e210b114e0>,
#  "'ك'": <gensim.models.keyedvectors.Vocab at 0x1e210b11518>,
#  "'شرل'": <gensim.models.keyedvectors.Vocab at 0x1e210b11550>,
#  "'شوف'": <gensim.models.keyedvectors.Vocab at 0x1e210b11588>,
#  "'شربل'": <gensim.models.keyedvectors.Vocab at 0x1e210b115c0>,
#  "'عبدو'": <gensim.models.keyedvectors.Vocab at 0x1e210b115f8>,
#  "'ايك'": <gensim.models.keyedvectors.Vocab at 0x1e210b11630>,
#  "'يقد'": <gensim.models.keyedvectors.Vocab at 0x1e210b11668>,
#  "'كورد'": <gensim.models.keyedvectors.Vocab at 0x1e210b116a0>,
#  "'كوك'": <gensim.models.keyedvectors.Vocab at 0x1e210b116d8>,
#  "'درة'": <gensim.models.keyedvectors.Vocab at 0x1e210b11710>,
#  "'عمة'": <gensim.models.keyedvectors.Vocab at 0x1e210b11748>,
#  "'ؤهل'": <gensim.models.keyedvectors.Vocab at 0x1e210b11780>,
#  "'طقش'": <gensim.models.keyedvectors.Vocab at 0x1e210b117b8>,
#  "'فيش'": <gensim.models.keyedvectors.Vocab at 0x1e210b117f0>,
#  "'زكر'": <gensim.models.keyedvectors.Vocab at 0x1e210b11828>,
#  "'حلل'": <gensim.models.keyedvectors.Vocab at 0x1e210b11860>,
#  "'فهد'": <gensim.models.keyedvectors.Vocab at 0x1e210b11898>,
#  "'نال'": <gensim.models.keyedvectors.Vocab at 0x1e210b118d0>,
#  "'تقم'": <gensim.models.keyedvectors.Vocab at 0x1e210b11908>,
#  "'بنء'": <gensim.models.keyedvectors.Vocab at 0x1e210b11940>,
#  "'غلا'": <gensim.models.keyedvectors.Vocab at 0x1e210b11978>,
#  "'حذي'": <gensim.models.keyedvectors.Vocab at 0x1e210b119b0>,
#  "'واجد'": <gensim.models.keyedvectors.Vocab at 0x1e210b119e8>,
#  "'زوج']": <gensim.models.keyedvectors.Vocab at 0x1e210b11a20>,
#  "'سنو'": <gensim.models.keyedvectors.Vocab at 0x1e210b11a58>,
#  "'دار'": <gensim.models.keyedvectors.Vocab at 0x1e210b11a90>,
#  "'يام'": <gensim.models.keyedvectors.Vocab at 0x1e210b11ac8>,
#  "'خزم'": <gensim.models.keyedvectors.Vocab at 0x1e210b11b00>,
#  "'صبر'": <gensim.models.keyedvectors.Vocab at 0x1e210b11b38>,
#  "'عدد'": <gensim.models.keyedvectors.Vocab at 0x1e210b11b70>,
#  "'شبن'": <gensim.models.keyedvectors.Vocab at 0x1e210b11ba8>,
#  "'دوغ'": <gensim.models.keyedvectors.Vocab at 0x1e210b11be0>,
#  "'حمرار'": <gensim.models.keyedvectors.Vocab at 0x1e210b11c18>,
#  "'سوز'": <gensim.models.keyedvectors.Vocab at 0x1e210b11c50>,
#  "'عسل'": <gensim.models.keyedvectors.Vocab at 0x1e210b11c88>,
#  "'ادي'": <gensim.models.keyedvectors.Vocab at 0x1e210b11cc0>,
#  "'شرع']": <gensim.models.keyedvectors.Vocab at 0x1e210b11cf8>,
#  "'قرقماز'": <gensim.models.keyedvectors.Vocab at 0x1e210b11d30>,
#  "'نجل'": <gensim.models.keyedvectors.Vocab at 0x1e210b11d68>,
#  "'هيلد'": <gensim.models.keyedvectors.Vocab at 0x1e210b11da0>,
#  "'غدي'": <gensim.models.keyedvectors.Vocab at 0x1e210b11dd8>,
#  "'شرف']": <gensim.models.keyedvectors.Vocab at 0x1e210b11e10>,
#  "'نيف'": <gensim.models.keyedvectors.Vocab at 0x1e210b11e48>,
#  "'يذئ'": <gensim.models.keyedvectors.Vocab at 0x1e210b11e80>,
#  "'جوهر'": <gensim.models.keyedvectors.Vocab at 0x1e210b11eb8>,
#  "'شبب'": <gensim.models.keyedvectors.Vocab at 0x1e210b11ef0>,
#  "'وال'": <gensim.models.keyedvectors.Vocab at 0x1e210b11f28>,
#  "'رنا'": <gensim.models.keyedvectors.Vocab at 0x1e210b11f60>,
#  "'دتة'": <gensim.models.keyedvectors.Vocab at 0x1e210b11f98>,
#  "'عرق'": <gensim.models.keyedvectors.Vocab at 0x1e210b11fd0>,
#  "'كليمنصو'": <gensim.models.keyedvectors.Vocab at 0x1e210b15048>,
#  "'طبي'": <gensim.models.keyedvectors.Vocab at 0x1e210b15080>,
#  "'ردن'": <gensim.models.keyedvectors.Vocab at 0x1e210b150b8>,
#  "'سان'": <gensim.models.keyedvectors.Vocab at 0x1e210b150f0>,
#  "'فرع'": <gensim.models.keyedvectors.Vocab at 0x1e210b15128>,
#  "'جري'": <gensim.models.keyedvectors.Vocab at 0x1e210b15160>,
#  "'حل'": <gensim.models.keyedvectors.Vocab at 0x1e210b15198>,
#  "'قيل'": <gensim.models.keyedvectors.Vocab at 0x1e210b151d0>,
#  "'بنة'": <gensim.models.keyedvectors.Vocab at 0x1e210b15208>,
#  "'يضع'": <gensim.models.keyedvectors.Vocab at 0x1e210b15240>,
#  "'سدس'": <gensim.models.keyedvectors.Vocab at 0x1e210b15278>,
#  "'خصر'": <gensim.models.keyedvectors.Vocab at 0x1e210b152b0>,
#  "'لحق'": <gensim.models.keyedvectors.Vocab at 0x1e210b152e8>,
#  "'اهل'": <gensim.models.keyedvectors.Vocab at 0x1e210b15320>,
#  "'صال'": <gensim.models.keyedvectors.Vocab at 0x1e210b15358>,
#  "'قصء'": <gensim.models.keyedvectors.Vocab at 0x1e210b15390>,
#  "'صري'": <gensim.models.keyedvectors.Vocab at 0x1e210b153c8>,
#  "'جوز'": <gensim.models.keyedvectors.Vocab at 0x1e210b15400>,
#  "'ودع'": <gensim.models.keyedvectors.Vocab at 0x1e210b15438>,
#  "'ينء'": <gensim.models.keyedvectors.Vocab at 0x1e210b15470>,
#  "'حصن'": <gensim.models.keyedvectors.Vocab at 0x1e210b154a8>,
#  "'حزم'": <gensim.models.keyedvectors.Vocab at 0x1e210b154e0>,
#  "'انس'": <gensim.models.keyedvectors.Vocab at 0x1e210b15518>,
#  "'همو'": <gensim.models.keyedvectors.Vocab at 0x1e210b15550>,
#  "'الة'": <gensim.models.keyedvectors.Vocab at 0x1e210b15588>,
#  "'ضحة'": <gensim.models.keyedvectors.Vocab at 0x1e210b155c0>,
#  "'سهر'": <gensim.models.keyedvectors.Vocab at 0x1e210b155f8>,
#  "'فرج'": <gensim.models.keyedvectors.Vocab at 0x1e210b15630>,
#  "'هدد']": <gensim.models.keyedvectors.Vocab at 0x1e210b15668>,
#  "'جنح'": <gensim.models.keyedvectors.Vocab at 0x1e210b156a0>,
#  "'حرب'": <gensim.models.keyedvectors.Vocab at 0x1e210b156d8>,
#  "'كلة'": <gensim.models.keyedvectors.Vocab at 0x1e210b15710>,
#  "'هندس'": <gensim.models.keyedvectors.Vocab at 0x1e210b15748>,
#  "'سمة'": <gensim.models.keyedvectors.Vocab at 0x1e210b15780>,
#  "'زيتو'": <gensim.models.keyedvectors.Vocab at 0x1e210b157b8>,
#  "'هيواو'": <gensim.models.keyedvectors.Vocab at 0x1e210b157f0>,
#  "'رعب'": <gensim.models.keyedvectors.Vocab at 0x1e210b15828>,
#  "'يسم'": <gensim.models.keyedvectors.Vocab at 0x1e210b15860>,
#  "'ركو'": <gensim.models.keyedvectors.Vocab at 0x1e210b15898>,
#  "'نري']": <gensim.models.keyedvectors.Vocab at 0x1e210b158d0>,
#  "'رشا'": <gensim.models.keyedvectors.Vocab at 0x1e210b15908>,
#  "'قتل'": <gensim.models.keyedvectors.Vocab at 0x1e210b15940>,
#  "'عطى'": <gensim.models.keyedvectors.Vocab at 0x1e210b15978>,
#  "'كجق'": <gensim.models.keyedvectors.Vocab at 0x1e210b159b0>,
#  "'فهم'": <gensim.models.keyedvectors.Vocab at 0x1e210b159e8>,
#  "'غنة'": <gensim.models.keyedvectors.Vocab at 0x1e210b15a20>,
#  "'عهد'": <gensim.models.keyedvectors.Vocab at 0x1e210b15a58>,
#  "'شقق'": <gensim.models.keyedvectors.Vocab at 0x1e210b15a90>,
#  "'تين'": <gensim.models.keyedvectors.Vocab at 0x1e210b15ac8>,
#  "'جونو'": <gensim.models.keyedvectors.Vocab at 0x1e210b15b00>,
#  "'ال'": <gensim.models.keyedvectors.Vocab at 0x1e210b15b38>,
#  "'علو'": <gensim.models.keyedvectors.Vocab at 0x1e210b15b70>,
#  ...}

# %%
from itertools import islice
list(islice(word2vec_vectors.wv.vocab, 130, 150))
# Out:
# ["'قيس'",
#  "'ميس'",
#  "'نتج'",
#  "'صبة'",
#  "'شعر'",
#  "'كتف'",
#  "'يسر'",
#  "'طرد'",
#  "'عاج'",
#  "['عرض'",
#  "'مير'",
#  "'سيم'",
#  "'يلى'",
#  "'توو'",
#  "'اسد'",
#  "'دلا'",
#  "'فوز'",
#  "'يطر'",
#  "'منى'",
#  "'برض'"]
