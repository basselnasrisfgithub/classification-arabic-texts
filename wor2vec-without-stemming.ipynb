# %%
import math

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#start arabic test
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.stem.porter import *
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
import codecs
import sys

# %%
import os
from nltk.parse import stanford as SParse
from nltk.tag import stanford as STag
from nltk.tokenize import StanfordSegmenter

from polyglot.text import Text
from rake_nltk import Rake

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

os.environ['STANFORD_MODELS'] = 'stanford-segmenter-2018-10-16/data/;stanford-postagger-full-2018-10-16/models/'
os.environ['STANFORD_PARSER'] = 'stanford-parser-full-2018-10-17'
os.environ['CLASSPATH'] = 'stanford-parser-full-2018-10-17'
os.environ['JAVAHOME'] = 'C:/Program Files/Java/jdk1.8.0_60'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Maya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#readind and preparing data ( text , label )
data=pd.read_excel('incident13types.xlsx', header=None) ## read le file
data.columns=['label','text']
print(data[2:3])
# Out:
#    label                                               text
# 2      4  اقدم المدعو وليد عدنان مرعي على شتم و اهانة ال...

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9ا-ي #+_]')
STOPWORDS = set(stopwords.words('arabic'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing. 
    text = text.replace('x', '')
#    text = re.sub(r'\W+', '', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    return text

# %%
subData = data['text']
#subData = subData[1:10]
singleTextWithPips = '|'.join(subData)
#print(singleTextWithPips)
f = open("samplePips.txt", "w",  encoding='utf-8')
f.write(singleTextWithPips)
f.close()

# %%
segmenter = StanfordSegmenter('stanford-segmenter-2018-10-16/stanford-segmenter-3.9.2.jar')
segmenter.default_config('ar')
textseg = segmenter.segment_file('samplePips.txt')
print(textseg[1:20])
# Out:
# C:\Users\Maya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.parse.corenlp.CoreNLPTokenizer instead.'
#   """Entry point for launching an IPython kernel.
# لساعة 8.15 من تاريخ

# %%
texts=textseg.split('|')
print(texts[1:3])
# Out:
# [' عند التاسعة من مساء يوم 29/9/2018 و في محلة الطريق الجديدة / ارض جلول / اوقفت دورية من مكتب معلومات بيروت الرابعة المدعو خالد عسكر بعد الاشتباه ب ه بترويج المخدرات حيث عثرت ب حوزة ه على كمية من المخدرات على الشكل التالي :\r\n50 حبة من نوع ب نزكسول\r\n80 × 1/2 حبة من نوع ب نزكسول موضبين داخل ثلاثة اكياس صغيرة\r\n9 حبات و نصف من نوع ترامال\r\n19 حبة من نوع MELEXITE المخدرة ل الاعصاب\r\n49 حبة مجهولة الصنف لون اصفر داخل حنجور\r\nب الاضافة الى 13 كارت نوع تيليكارت مغلفين ', ' اقدم المدعو وليد عدنان مرعي على شتم و اهانة المدعوة رينا حافظ لبنانية و هي زوجة ه السابقة اي طليقة ه اثناء وجود ها في محلة راس النبع شارع محمد الحوت ']

# %% [markdown]
# from nltk.stem import ISRIStemmer
# st=ISRIStemmer()
# sw=STOPWORDS
# collection_new=[]
# for  doc in texts:
#     new_doc=[]
#     for i in doc.split():
#         if not i in sw:
#             i=st.stem(i)
#             i=''.join(i)
#             new_doc.append(i)
#     collection_new.append(new_doc)
# collection=collection_new

# %%
collection=texts
print(collection[1])
# Out:
#  عند التاسعة من مساء يوم 29/9/2018 و في محلة الطريق الجديدة / ارض جلول / اوقفت دورية من مكتب معلومات بيروت الرابعة المدعو خالد عسكر بعد الاشتباه ب ه بترويج المخدرات حيث عثرت ب حوزة ه على كمية من المخدرات على الشكل التالي :
# 50 حبة من نوع ب نزكسول
# 80 × 1/2 حبة من نوع ب نزكسول موضبين داخل ثلاثة اكياس صغيرة
# 9 حبات و نصف من نوع ترامال
# 19 حبة من نوع MELEXITE المخدرة ل الاعصاب
# 49 حبة مجهولة الصنف لون اصفر داخل حنجور
# ب الاضافة الى 13 كارت نوع تيليكارت مغلفين

# %%
import re
print(collection[1])
for i in range(len(collection)):
    collection[i] = re.sub(r'\d+', '', str(collection[i]))
print(collection[1])
# Out:
#  عند التاسعة من مساء يوم // و في محلة الطريق الجديدة / ارض جلول / اوقفت دورية من مكتب معلومات بيروت الرابعة المدعو خالد عسكر بعد الاشتباه ب ه بترويج المخدرات حيث عثرت ب حوزة ه على كمية من المخدرات على الشكل التالي :
#  حبة من نوع ب نزكسول
#  × / حبة من نوع ب نزكسول موضبين داخل ثلاثة اكياس صغيرة
#  حبات و نصف من نوع ترامال
#  حبة من نوع MELEXITE المخدرة ل الاعصاب
#  حبة مجهولة الصنف لون اصفر داخل حنجور
# ب الاضافة الى  كارت نوع تيليكارت مغلفين
#  عند التاسعة من مساء يوم // و في محلة الطريق الجديدة / ارض جلول / اوقفت دورية من مكتب معلومات بيروت الرابعة المدعو خالد عسكر بعد الاشتباه ب ه بترويج المخدرات حيث عثرت ب حوزة ه على كمية من المخدرات على الشكل التالي :
#  حبة من نوع ب نزكسول
#  × / حبة من نوع ب نزكسول موضبين داخل ثلاثة اكياس صغيرة
#  حبات و نصف من نوع ترامال
#  حبة من نوع MELEXITE المخدرة ل الاعصاب
#  حبة مجهولة الصنف لون اصفر داخل حنجور
# ب الاضافة الى  كارت نوع تيليكارت مغلفين

# %%
table=str.maketrans("+=_-<>~/!*%?:;,)&1234567890@$qwertyuioplkjhgfdsamnbvcxz(QWERTYUIOPLKJHGFDSAZXCVBNM",82*" ")
for i in range(len(collection)):
    collection[i] = collection[i].translate(table)
print(collection[1])
# Out:
#  عند التاسعة من مساء يوم    و في محلة الطريق الجديدة   ارض جلول   اوقفت دورية من مكتب معلومات بيروت الرابعة المدعو خالد عسكر بعد الاشتباه ب ه بترويج المخدرات حيث عثرت ب حوزة ه على كمية من المخدرات على الشكل التالي
#  حبة من نوع ب نزكسول
#  ×   حبة من نوع ب نزكسول موضبين داخل ثلاثة اكياس صغيرة
#  حبات و نصف من نوع ترامال
#  حبة من نوع          المخدرة ل الاعصاب
#  حبة مجهولة الصنف لون اصفر داخل حنجور
# ب الاضافة الى  كارت نوع تيليكارت مغلفين

# %%
#import os, sys
#import pandas as pd
#import numpy as np
#from sklearn.metrics.pairwise import cosine_similarity
#from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.model_selection import train_test_split
#from sklearn.naive_bayes import BernoulliNB
#from sklearn.ensemble import RandomForestClassifier
##from sklearn.metrics import roc_curve, auc
#from sklearn import svm
#from sklearn.metrics import classification_report, confusion_matrix
#from sklearn.model_selection import GridSearchCV
from gensim.models import KeyedVectors
#from scipy import spatial
#import matplotlib.pyplot as plt
#from sklearn.neural_network import MLPClassifier
from nltk import bigrams
import nltk
import re
#import spacy
###FUNCTIONS
def avg_feature_vector(sentence, model, num_features, index2word_set):
        words = sentence.split()
        feature_vec = np.zeros((num_features, ), dtype='float32')
        n_words = 0
        for word in words:
            if word in index2word_set:
                n_words += 1
                feature_vec = np.add(feature_vec, model[word])
        if (n_words > 0):
            feature_vec = np.divide(feature_vec, n_words)
        return feature_vec

def convert_word2vec(sentences,num_features):
        vectors_matrix = np.zeros((len(sentences),num_features))
        i = 0
        for sent in sentences:
            temp = avg_feature_vector(sent,word2vec_vectors,num_features,index2word_set)
            vectors_matrix[i,:] = temp
            i = i+1
        return vectors_matrix
def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    #txt = [token for token in doc ]
    words=str(doc).strip().split()
    #words=[st.stem(w) for w in words ]
    return ' '.join(words)
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    #if len(txt) > 2:
      #return ' '.join(txt)
#from gensim.models.phrases import Phrases, Phraser
#data=pd.read_excel('ml2.xlsx', header=None) ## read le file
#data.columns=['text','label']
#def prep(doc):
 #   words=str(doc).strip().split()
  #  return ' '.join(words)
#Xt=Xt.apply(prep)
#sentences = Xt
data=collection
#data = data[data['Semantic_Type']!='DISREGARD']
#from gensim.models.phrases import Phrases, Phraser
#from nltk.stem import ISRIStemmer
#st=ISRIStemmer()
brief_cleaning = (re.sub("[^ا-ي']+", ' ', str(row)).lower() for row in data)
txt = [cleaning(doc) for doc in data]
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
sent = [row.split() for row in df_clean['clean']]
sentences = sent
print(sentences[1])
from gensim.models import Word2Vec
word2vec_vectors = Word2Vec(min_count=2,window=5,size=200,sample=6e-5,alpha=0.03,min_alpha=0.0007,negative=20)
word2vec_vectors.build_vocab(sentences)
word2vec_vectors.train(sentences, total_examples=word2vec_vectors.corpus_count, epochs=30, report_delay=1)
word2vec_vectors.init_sims(replace=True)
index2word_set = set(word2vec_vectors.wv.index2word)
###vectorizing the sentences
#vectors_matrix = convert_word2vec(data['Sentence'],200)
#np.random.seed(10)
#labels=data['label']
#train,test,ltrain,ltest =train_test_split(vectors_matrix, labels,test_size=0.2)#,random_state=8)
# Out:
# ['عند', 'التاسعة', 'من', 'مساء', 'يوم', 'و', 'في', 'محلة', 'الطريق', 'الجديدة', 'ارض', 'جلول', 'اوقفت', 'دورية', 'من', 'مكتب', 'معلومات', 'بيروت', 'الرابعة', 'المدعو', 'خالد', 'عسكر', 'بعد', 'الاشتباه', 'ب', 'ه', 'بترويج', 'المخدرات', 'حيث', 'عثرت', 'ب', 'حوزة', 'ه', 'على', 'كمية', 'من', 'المخدرات', 'على', 'الشكل', 'التالي', 'حبة', 'من', 'نوع', 'ب', 'نزكسول', '×', 'حبة', 'من', 'نوع', 'ب', 'نزكسول', 'موضبين', 'داخل', 'ثلاثة', 'اكياس', 'صغيرة', 'حبات', 'و', 'نصف', 'من', 'نوع', 'ترامال', 'حبة', 'من', 'نوع', 'المخدرة', 'ل', 'الاعصاب', 'حبة', 'مجهولة', 'الصنف', 'لون', 'اصفر', 'داخل', 'حنجور', 'ب', 'الاضافة', 'الى', 'كارت', 'نوع', 'تيليكارت', 'مغلفين']
# C:\Users\Maya\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "

# %%
def clean_str(text):
    search = ["أ","إ","آ","ة","_","-","/",".","،"," و "," يا ",'"',"ـ","'","ى","\\",'\n', '\t','&quot;','?','؟','!']
    replace = ["ا","ا","ا","ه"," "," ","","",""," و"," يا","","","","ي","",' ', ' ',' ',' ? ',' ؟ ',' ! ']
    
    #remove tashkeel
    p_tashkeel = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    text = re.sub(p_tashkeel,"", text)
    
    #remove longation
    p_longation = re.compile(r'(.)\1+')
    subst = r"\1\1"
    text = re.sub(p_longation, subst, text)
    
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    
    for i in range(0, len(search)):
        text = text.replace(search[i], replace[i])
    
    #trim    
    text = text.strip()

    return text
def get_vec(n_model,dim, token):
    vec = np.zeros(dim)
    is_vec = False
    if token not in n_model.wv:
        _count = 0
        is_vec = True
        for w in token.split("_"):
            if w in n_model.wv:
                _count += 1
                vec += n_model.wv[w]
        if _count > 0:
            vec = vec / _count
    else:
        vec = n_model.wv[token]
    return vec

def calc_vec(pos_tokens, neg_tokens, n_model, dim):
    vec = np.zeros(dim)
    for p in pos_tokens:
        vec += get_vec(n_model,dim,p)
    for n in neg_tokens:
        vec -= get_vec(n_model,dim,n)
    
    return vec

# %%
t_model = word2vec_vectors
pos_tokens=[ clean_str(t.strip()).replace(" ", "_") for t in ['خالد', 'مخدرات'] if t.strip() != ""]
neg_tokens=[ clean_str(t.strip()).replace(" ", "_") for t in ['سوري'] if t.strip() != ""]

vec = calc_vec(pos_tokens=pos_tokens, neg_tokens=neg_tokens, n_model=t_model, dim=t_model.vector_size)

most_sims = t_model.wv.similar_by_vector(vec, topn=10)
for term, score in most_sims:
    if term not in pos_tokens+neg_tokens:
        print(term, score)
# Out:
# ترويج 0.8308745622634888
# نصب 0.8245437145233154
# ريفوتريل 0.8226958513259888
# قليلة 0.8213380575180054
# الهيرويين 0.8204573392868042
# عربي 0.8191748261451721
# اشتبا 0.8186986446380615
# عثرت 0.8181512355804443
# مزور 0.8171675205230713

# %%
 word2vec_vectors.wv.vocab
# Out:
# {'الساعة': <gensim.models.keyedvectors.Vocab at 0x155ec8f8d30>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x155edb48c50>,
#  'من': <gensim.models.keyedvectors.Vocab at 0x155edb48c18>,
#  'تاريخ': <gensim.models.keyedvectors.Vocab at 0x155edb48be0>,
#  'ه': <gensim.models.keyedvectors.Vocab at 0x155edb48d68>,
#  'و': <gensim.models.keyedvectors.Vocab at 0x155edb48da0>,
#  'في': <gensim.models.keyedvectors.Vocab at 0x155edb48dd8>,
#  'محلة': <gensim.models.keyedvectors.Vocab at 0x155edb48e10>,
#  'المزرعة': <gensim.models.keyedvectors.Vocab at 0x155edb48e48>,
#  'تقاطع': <gensim.models.keyedvectors.Vocab at 0x155edb48e80>,
#  'ابي': <gensim.models.keyedvectors.Vocab at 0x155edb48eb8>,
#  'حيدر': <gensim.models.keyedvectors.Vocab at 0x155edb48ef0>,
#  'سلام': <gensim.models.keyedvectors.Vocab at 0x155edb48f28>,
#  'صدمت': <gensim.models.keyedvectors.Vocab at 0x155edb48f60>,
#  'سيارة': <gensim.models.keyedvectors.Vocab at 0x155edb48f98>,
#  'نوع': <gensim.models.keyedvectors.Vocab at 0x155edb48fd0>,
#  'نيسان': <gensim.models.keyedvectors.Vocab at 0x155ef86c048>,
#  'ميكرا': <gensim.models.keyedvectors.Vocab at 0x155ef86c080>,
#  'لون': <gensim.models.keyedvectors.Vocab at 0x155ef86c0b8>,
#  'رمادي': <gensim.models.keyedvectors.Vocab at 0x155ef86c0f0>,
#  'صنع': <gensim.models.keyedvectors.Vocab at 0x155ef86c128>,
#  'رقم': <gensim.models.keyedvectors.Vocab at 0x155ef86c160>,
#  'ب': <gensim.models.keyedvectors.Vocab at 0x155ef86c198>,
#  'قيادة': <gensim.models.keyedvectors.Vocab at 0x155ef86c1d0>,
#  'كريم': <gensim.models.keyedvectors.Vocab at 0x155ef86c208>,
#  'خالد': <gensim.models.keyedvectors.Vocab at 0x155ef86c240>,
#  'بديعة': <gensim.models.keyedvectors.Vocab at 0x155ef86c278>,
#  'لبناني': <gensim.models.keyedvectors.Vocab at 0x155ef86c2b0>,
#  'العريف': <gensim.models.keyedvectors.Vocab at 0x155ef86c2e8>,
#  'جوزيف': <gensim.models.keyedvectors.Vocab at 0x155ef86c320>,
#  'شلهوب': <gensim.models.keyedvectors.Vocab at 0x155ef86c358>,
#  'احد': <gensim.models.keyedvectors.Vocab at 0x155ef86c390>,
#  'عناصر': <gensim.models.keyedvectors.Vocab at 0x155ef86c3c8>,
#  'مفرزة': <gensim.models.keyedvectors.Vocab at 0x155ef86c400>,
#  'سير': <gensim.models.keyedvectors.Vocab at 0x155ef86c438>,
#  'بيروت': <gensim.models.keyedvectors.Vocab at 0x155ef86c470>,
#  'الثانية': <gensim.models.keyedvectors.Vocab at 0x155ef86c4a8>,
#  'نقل': <gensim.models.keyedvectors.Vocab at 0x155ef86c4e0>,
#  'الى': <gensim.models.keyedvectors.Vocab at 0x155ef86c518>,
#  'مستشفى': <gensim.models.keyedvectors.Vocab at 0x155ef86c550>,
#  'حداد': <gensim.models.keyedvectors.Vocab at 0x155ef86c588>,
#  'ل': <gensim.models.keyedvectors.Vocab at 0x155ef86c5c0>,
#  'المعالجة': <gensim.models.keyedvectors.Vocab at 0x155ef86c5f8>,
#  'تولت': <gensim.models.keyedvectors.Vocab at 0x155ef86c630>,
#  'اجراء': <gensim.models.keyedvectors.Vocab at 0x155ef86c668>,
#  'التحقيق': <gensim.models.keyedvectors.Vocab at 0x155ef86c6a0>,
#  'موجب': <gensim.models.keyedvectors.Vocab at 0x155ef86c6d8>,
#  'محضر': <gensim.models.keyedvectors.Vocab at 0x155ef86c710>,
#  'عند': <gensim.models.keyedvectors.Vocab at 0x155ef86c748>,
#  'التاسعة': <gensim.models.keyedvectors.Vocab at 0x155ef86c780>,
#  'مساء': <gensim.models.keyedvectors.Vocab at 0x155ef86c7b8>,
#  'يوم': <gensim.models.keyedvectors.Vocab at 0x155ef86c7f0>,
#  'الطريق': <gensim.models.keyedvectors.Vocab at 0x155ef86c828>,
#  'الجديدة': <gensim.models.keyedvectors.Vocab at 0x155ef86c860>,
#  'ارض': <gensim.models.keyedvectors.Vocab at 0x155ef86c898>,
#  'جلول': <gensim.models.keyedvectors.Vocab at 0x155ef86c8d0>,
#  'اوقفت': <gensim.models.keyedvectors.Vocab at 0x155ef86c908>,
#  'دورية': <gensim.models.keyedvectors.Vocab at 0x155ef86c940>,
#  'مكتب': <gensim.models.keyedvectors.Vocab at 0x155ef86c978>,
#  'معلومات': <gensim.models.keyedvectors.Vocab at 0x155ef86c9b0>,
#  'الرابعة': <gensim.models.keyedvectors.Vocab at 0x155ef86c9e8>,
#  'المدعو': <gensim.models.keyedvectors.Vocab at 0x155ef86ca20>,
#  'عسكر': <gensim.models.keyedvectors.Vocab at 0x155ef86ca58>,
#  'بعد': <gensim.models.keyedvectors.Vocab at 0x155ef86ca90>,
#  'الاشتباه': <gensim.models.keyedvectors.Vocab at 0x155ef86cac8>,
#  'بترويج': <gensim.models.keyedvectors.Vocab at 0x155ef86cb00>,
#  'المخدرات': <gensim.models.keyedvectors.Vocab at 0x155ef86cb38>,
#  'حيث': <gensim.models.keyedvectors.Vocab at 0x155ef86cb70>,
#  'عثرت': <gensim.models.keyedvectors.Vocab at 0x155ef86cba8>,
#  'حوزة': <gensim.models.keyedvectors.Vocab at 0x155ef86cbe0>,
#  'على': <gensim.models.keyedvectors.Vocab at 0x155ef86cc18>,
#  'كمية': <gensim.models.keyedvectors.Vocab at 0x155ef86cc50>,
#  'التالي': <gensim.models.keyedvectors.Vocab at 0x155ef86cc88>,
#  'حبة': <gensim.models.keyedvectors.Vocab at 0x155ef86ccc0>,
#  'نزكسول': <gensim.models.keyedvectors.Vocab at 0x155ef86ccf8>,
#  'داخل': <gensim.models.keyedvectors.Vocab at 0x155ef86cd30>,
#  'ثلاثة': <gensim.models.keyedvectors.Vocab at 0x155ef86cd68>,
#  'اكياس': <gensim.models.keyedvectors.Vocab at 0x155ef86cda0>,
#  'صغيرة': <gensim.models.keyedvectors.Vocab at 0x155ef86cdd8>,
#  'حبات': <gensim.models.keyedvectors.Vocab at 0x155ef86ce10>,
#  'نصف': <gensim.models.keyedvectors.Vocab at 0x155ef86ce48>,
#  'ترامال': <gensim.models.keyedvectors.Vocab at 0x155ef86ce80>,
#  'المخدرة': <gensim.models.keyedvectors.Vocab at 0x155ef86ceb8>,
#  'مجهولة': <gensim.models.keyedvectors.Vocab at 0x155ef86cef0>,
#  'اصفر': <gensim.models.keyedvectors.Vocab at 0x155ef86cf28>,
#  'حنجور': <gensim.models.keyedvectors.Vocab at 0x155ef86cf60>,
#  'الاضافة': <gensim.models.keyedvectors.Vocab at 0x155ef86cf98>,
#  'اقدم': <gensim.models.keyedvectors.Vocab at 0x155ef86cfd0>,
#  'وليد': <gensim.models.keyedvectors.Vocab at 0x155ef86e048>,
#  'عدنان': <gensim.models.keyedvectors.Vocab at 0x155ef86e080>,
#  'مرعي': <gensim.models.keyedvectors.Vocab at 0x155ef86e0b8>,
#  'شتم': <gensim.models.keyedvectors.Vocab at 0x155ef86e0f0>,
#  'اهانة': <gensim.models.keyedvectors.Vocab at 0x155ef86e128>,
#  'المدعوة': <gensim.models.keyedvectors.Vocab at 0x155ef86e160>,
#  'لبنانية': <gensim.models.keyedvectors.Vocab at 0x155ef86e198>,
#  'هي': <gensim.models.keyedvectors.Vocab at 0x155ef86e1d0>,
#  'زوجة': <gensim.models.keyedvectors.Vocab at 0x155ef86e208>,
#  'اي': <gensim.models.keyedvectors.Vocab at 0x155ef86e240>,
#  'اثناء': <gensim.models.keyedvectors.Vocab at 0x155ef86e278>,
#  'وجود': <gensim.models.keyedvectors.Vocab at 0x155ef86e2b0>,
#  'ها': <gensim.models.keyedvectors.Vocab at 0x155ef86e2e8>,
#  'راس': <gensim.models.keyedvectors.Vocab at 0x155ef86e320>,
#  'النبع': <gensim.models.keyedvectors.Vocab at 0x155ef86e358>,
#  'شارع': <gensim.models.keyedvectors.Vocab at 0x155ef86e390>,
#  'محمد': <gensim.models.keyedvectors.Vocab at 0x155ef86e3c8>,
#  'الحوت': <gensim.models.keyedvectors.Vocab at 0x155ef86e400>,
#  'ناصر': <gensim.models.keyedvectors.Vocab at 0x155ef86e438>,
#  'رضا': <gensim.models.keyedvectors.Vocab at 0x155ef86e470>,
#  'اصدار': <gensim.models.keyedvectors.Vocab at 0x155ef86e4a8>,
#  'شك': <gensim.models.keyedvectors.Vocab at 0x155ef86e4e0>,
#  'صالح': <gensim.models.keyedvectors.Vocab at 0x155ef86e518>,
#  'حسن': <gensim.models.keyedvectors.Vocab at 0x155ef86e550>,
#  'احمد': <gensim.models.keyedvectors.Vocab at 0x155ef86e588>,
#  'عبد': <gensim.models.keyedvectors.Vocab at 0x155ef86e5c0>,
#  'الرضا': <gensim.models.keyedvectors.Vocab at 0x155ef86e5f8>,
#  'تبين': <gensim.models.keyedvectors.Vocab at 0x155ef86e630>,
#  'ان': <gensim.models.keyedvectors.Vocab at 0x155ef86e668>,
#  'دون': <gensim.models.keyedvectors.Vocab at 0x155ef86e6a0>,
#  'رصيد': <gensim.models.keyedvectors.Vocab at 0x155ef86e6d8>,
#  'فردان': <gensim.models.keyedvectors.Vocab at 0x155ef86e710>,
#  'كرامي': <gensim.models.keyedvectors.Vocab at 0x155ef86e748>,
#  'بنك': <gensim.models.keyedvectors.Vocab at 0x155ef86e780>,
#  'البحر': <gensim.models.keyedvectors.Vocab at 0x155ef86e7b8>,
#  'المتوسط': <gensim.models.keyedvectors.Vocab at 0x155ef86e7f0>,
#  'تعرض': <gensim.models.keyedvectors.Vocab at 0x155ef86e828>,
#  'محمود': <gensim.models.keyedvectors.Vocab at 0x155ef86e860>,
#  'عمار': <gensim.models.keyedvectors.Vocab at 0x155ef86e898>,
#  'الدة': <gensim.models.keyedvectors.Vocab at 0x155ef86e8d0>,
#  'تولد': <gensim.models.keyedvectors.Vocab at 0x155ef86e908>,
#  'حادث': <gensim.models.keyedvectors.Vocab at 0x155ef86e940>,
#  'صدم': <gensim.models.keyedvectors.Vocab at 0x155ef86e978>,
#  'قبل': <gensim.models.keyedvectors.Vocab at 0x155ef86e9b0>,
#  'مازدا': <gensim.models.keyedvectors.Vocab at 0x155ef86e9e8>,
#  'فضي': <gensim.models.keyedvectors.Vocab at 0x155ef86ea20>,
#  'ج': <gensim.models.keyedvectors.Vocab at 0x155ef86ea58>,
#  'حياة': <gensim.models.keyedvectors.Vocab at 0x155ef86ea90>,
#  'الرحمن': <gensim.models.keyedvectors.Vocab at 0x155ef86eac8>,
#  'القيسي': <gensim.models.keyedvectors.Vocab at 0x155ef86eb00>,
#  'نتج': <gensim.models.keyedvectors.Vocab at 0x155ef86eb38>,
#  'عن': <gensim.models.keyedvectors.Vocab at 0x155ef86eb70>,
#  'اصابة': <gensim.models.keyedvectors.Vocab at 0x155ef86eba8>,
#  'شعر': <gensim.models.keyedvectors.Vocab at 0x155ef86ebe0>,
#  'كتف': <gensim.models.keyedvectors.Vocab at 0x155ef86ec18>,
#  'الايسر': <gensim.models.keyedvectors.Vocab at 0x155ef86ec50>,
#  'ادخل': <gensim.models.keyedvectors.Vocab at 0x155ef86ec88>,
#  'طراد': <gensim.models.keyedvectors.Vocab at 0x155ef86ecc0>,
#  'المعاجة': <gensim.models.keyedvectors.Vocab at 0x155ef86ecf8>,
#  'المحضر': <gensim.models.keyedvectors.Vocab at 0x155ef86ed30>,
#  'تعرضت': <gensim.models.keyedvectors.Vocab at 0x155ef86ed68>,
#  'اميرة': <gensim.models.keyedvectors.Vocab at 0x155ef86eda0>,
#  'عارف': <gensim.models.keyedvectors.Vocab at 0x155ef86edd8>,
#  'ليلى': <gensim.models.keyedvectors.Vocab at 0x155ef86ee10>,
#  'تويوتا': <gensim.models.keyedvectors.Vocab at 0x155ef86ee48>,
#  'اسود': <gensim.models.keyedvectors.Vocab at 0x155ef86ee80>,
#  'فوزي': <gensim.models.keyedvectors.Vocab at 0x155ef86eeb8>,
#  'بيطار': <gensim.models.keyedvectors.Vocab at 0x155ef86eef0>,
#  'منى': <gensim.models.keyedvectors.Vocab at 0x155ef86ef28>,
#  'الحادث': <gensim.models.keyedvectors.Vocab at 0x155ef86ef60>,
#  'برضة': <gensim.models.keyedvectors.Vocab at 0x155ef86ef98>,
#  'يد': <gensim.models.keyedvectors.Vocab at 0x155ef86efd0>,
#  'اليمنى': <gensim.models.keyedvectors.Vocab at 0x155ef871048>,
#  'عولجت': <gensim.models.keyedvectors.Vocab at 0x155ef871080>,
#  'نظم': <gensim.models.keyedvectors.Vocab at 0x155ef8710b8>,
#  'السيارة': <gensim.models.keyedvectors.Vocab at 0x155ef8710f0>,
#  'كيا': <gensim.models.keyedvectors.Vocab at 0x155ef871128>,
#  'جردوني': <gensim.models.keyedvectors.Vocab at 0x155ef871160>,
#  'م': <gensim.models.keyedvectors.Vocab at 0x155ef871198>,
#  'عياش': <gensim.models.keyedvectors.Vocab at 0x155ef8711d0>,
#  'مريم': <gensim.models.keyedvectors.Vocab at 0x155ef871208>,
#  'حسين': <gensim.models.keyedvectors.Vocab at 0x155ef871240>,
#  'حفكاوي': <gensim.models.keyedvectors.Vocab at 0x155ef871278>,
#  'نعيمة': <gensim.models.keyedvectors.Vocab at 0x155ef8712b0>,
#  'سوري': <gensim.models.keyedvectors.Vocab at 0x155ef8712e8>,
#  'ذلك': <gensim.models.keyedvectors.Vocab at 0x155ef871320>,
#  'برضوض': <gensim.models.keyedvectors.Vocab at 0x155ef871358>,
#  'انحاء': <gensim.models.keyedvectors.Vocab at 0x155ef871390>,
#  'جسد': <gensim.models.keyedvectors.Vocab at 0x155ef8713c8>,
#  'الحريري': <gensim.models.keyedvectors.Vocab at 0x155ef871400>,
#  'الحكومي': <gensim.models.keyedvectors.Vocab at 0x155ef871438>,
#  'وضع': <gensim.models.keyedvectors.Vocab at 0x155ef871470>,
#  'مستقر': <gensim.models.keyedvectors.Vocab at 0x155ef8714a8>,
#  'الاولى': <gensim.models.keyedvectors.Vocab at 0x155ef8714e0>,
#  'خلافات': <gensim.models.keyedvectors.Vocab at 0x155ef871518>,
#  'عائلية': <gensim.models.keyedvectors.Vocab at 0x155ef871550>,
#  'بين': <gensim.models.keyedvectors.Vocab at 0x155ef871588>,
#  'ندى': <gensim.models.keyedvectors.Vocab at 0x155ef8715c0>,
#  'مصطفى': <gensim.models.keyedvectors.Vocab at 0x155ef8715f8>,
#  'وهبه': <gensim.models.keyedvectors.Vocab at 0x155ef871630>,
#  'نعيم': <gensim.models.keyedvectors.Vocab at 0x155ef871668>,
#  'ابن': <gensim.models.keyedvectors.Vocab at 0x155ef8716a0>,
#  'قباني': <gensim.models.keyedvectors.Vocab at 0x155ef8716d8>,
#  'تم': <gensim.models.keyedvectors.Vocab at 0x155ef871710>,
#  'الطلب': <gensim.models.keyedvectors.Vocab at 0x155ef871748>,
#  'التوجه': <gensim.models.keyedvectors.Vocab at 0x155ef871780>,
#  'فصيلة': <gensim.models.keyedvectors.Vocab at 0x155ef8717b8>,
#  'المصيطبة': <gensim.models.keyedvectors.Vocab at 0x155ef8717f0>,
#  'تقديم': <gensim.models.keyedvectors.Vocab at 0x155ef871828>,
#  'شكوى': <gensim.models.keyedvectors.Vocab at 0x155ef871860>,
#  'حال': <gensim.models.keyedvectors.Vocab at 0x155ef871898>,
#  'رغبت': <gensim.models.keyedvectors.Vocab at 0x155ef8718d0>,
#  'مجهول': <gensim.models.keyedvectors.Vocab at 0x155ef871908>,
#  'سرقة': <gensim.models.keyedvectors.Vocab at 0x155ef871940>,
#  'الدراجة': <gensim.models.keyedvectors.Vocab at 0x155ef871978>,
#  'النارية': <gensim.models.keyedvectors.Vocab at 0x155ef8719b0>,
#  'العائدة': <gensim.models.keyedvectors.Vocab at 0x155ef8719e8>,
#  'الدعوة': <gensim.models.keyedvectors.Vocab at 0x155ef871a20>,
#  'زينب': <gensim.models.keyedvectors.Vocab at 0x155ef871a58>,
#  'مكان': <gensim.models.keyedvectors.Vocab at 0x155ef871a90>,
#  'ركن': <gensim.models.keyedvectors.Vocab at 0x155ef871ac8>,
#  'كورنيش': <gensim.models.keyedvectors.Vocab at 0x155ef871b00>,
#  'ادعت': <gensim.models.keyedvectors.Vocab at 0x155ef871b38>,
#  'امام': <gensim.models.keyedvectors.Vocab at 0x155ef871b70>,
#  'النهر': <gensim.models.keyedvectors.Vocab at 0x155ef871ba8>,
#  'فريد': <gensim.models.keyedvectors.Vocab at 0x155ef871be0>,
#  'الخوري': <gensim.models.keyedvectors.Vocab at 0x155ef871c18>,
#  'ريم': <gensim.models.keyedvectors.Vocab at 0x155ef871c50>,
#  'متن': <gensim.models.keyedvectors.Vocab at 0x155ef871c88>,
#  'دراجة': <gensim.models.keyedvectors.Vocab at 0x155ef871cc0>,
#  'نارية': <gensim.models.keyedvectors.Vocab at 0x155ef871cf8>,
#  'الحجم': <gensim.models.keyedvectors.Vocab at 0x155ef871d30>,
#  'باقي': <gensim.models.keyedvectors.Vocab at 0x155ef871d68>,
#  'المواصفات': <gensim.models.keyedvectors.Vocab at 0x155ef871da0>,
#  'نشل': <gensim.models.keyedvectors.Vocab at 0x155ef871dd8>,
#  'هاتف': <gensim.models.keyedvectors.Vocab at 0x155ef871e10>,
#  'الخليوي': <gensim.models.keyedvectors.Vocab at 0x155ef871e48>,
#  'الرصيف': <gensim.models.keyedvectors.Vocab at 0x155ef871e80>,
#  'جانب': <gensim.models.keyedvectors.Vocab at 0x155ef871eb8>,
#  'الفوروم': <gensim.models.keyedvectors.Vocab at 0x155ef871ef0>,
#  'دو': <gensim.models.keyedvectors.Vocab at 0x155ef871f28>,
#  'فر': <gensim.models.keyedvectors.Vocab at 0x155ef871f60>,
#  'جهة': <gensim.models.keyedvectors.Vocab at 0x155ef871f98>,
#  'اتجاه': <gensim.models.keyedvectors.Vocab at 0x155ef871fd0>,
#  'السير': <gensim.models.keyedvectors.Vocab at 0x155ef874048>,
#  'نزولا': <gensim.models.keyedvectors.Vocab at 0x155ef874080>,
#  'نحو': <gensim.models.keyedvectors.Vocab at 0x155ef8740b8>,
#  'محلات': <gensim.models.keyedvectors.Vocab at 0x155ef8740f0>,
#  'يحيى': <gensim.models.keyedvectors.Vocab at 0x155ef874128>,
#  'الاراكيل': <gensim.models.keyedvectors.Vocab at 0x155ef874160>,
#  'القائمة': <gensim.models.keyedvectors.Vocab at 0x155ef874198>,
#  'ادعى': <gensim.models.keyedvectors.Vocab at 0x155ef8741d0>,
#  'لدى': <gensim.models.keyedvectors.Vocab at 0x155ef874208>,
#  'طريق': <gensim.models.keyedvectors.Vocab at 0x155ef874240>,
#  'الشام': <gensim.models.keyedvectors.Vocab at 0x155ef874278>,
#  'سبيتي': <gensim.models.keyedvectors.Vocab at 0x155ef8742b0>,
#  'ايمان': <gensim.models.keyedvectors.Vocab at 0x155ef8742e8>,
#  'ضد': <gensim.models.keyedvectors.Vocab at 0x155ef874320>,
#  'مجهولين': <gensim.models.keyedvectors.Vocab at 0x155ef874358>,
#  'اقدما': <gensim.models.keyedvectors.Vocab at 0x155ef874390>,
#  'نفس': <gensim.models.keyedvectors.Vocab at 0x155ef8743c8>,
#  'التاريخ': <gensim.models.keyedvectors.Vocab at 0x155ef874400>,
#  'الخلوي': <gensim.models.keyedvectors.Vocab at 0x155ef874438>,
#  'ايفون': <gensim.models.keyedvectors.Vocab at 0x155ef874470>,
#  'يحمل': <gensim.models.keyedvectors.Vocab at 0x155ef8744a8>,
#  'شريحة': <gensim.models.keyedvectors.Vocab at 0x155ef8744e0>,
#  'الطيونة': <gensim.models.keyedvectors.Vocab at 0x155ef874518>,
#  'اول': <gensim.models.keyedvectors.Vocab at 0x155ef874550>,
#  'اوتوستراد': <gensim.models.keyedvectors.Vocab at 0x155ef874588>,
#  'السيد': <gensim.models.keyedvectors.Vocab at 0x155ef8745c0>,
#  'هادي': <gensim.models.keyedvectors.Vocab at 0x155ef8745f8>,
#  'نصرالله': <gensim.models.keyedvectors.Vocab at 0x155ef874630>,
#  'وفرا': <gensim.models.keyedvectors.Vocab at 0x155ef874668>,
#  'توقيف': <gensim.models.keyedvectors.Vocab at 0x155ef8746a0>,
#  'عمر': <gensim.models.keyedvectors.Vocab at 0x155ef8746d8>,
#  'وسط': <gensim.models.keyedvectors.Vocab at 0x155ef874710>,
#  'اللنبي': <gensim.models.keyedvectors.Vocab at 0x155ef874748>,
#  'حيازة': <gensim.models.keyedvectors.Vocab at 0x155ef874780>,
#  'حشيشة': <gensim.models.keyedvectors.Vocab at 0x155ef8747b8>,
#  'الكيف': <gensim.models.keyedvectors.Vocab at 0x155ef8747f0>,
#  'مقدار': <gensim.models.keyedvectors.Vocab at 0x155ef874828>,
#  'الحمص': <gensim.models.keyedvectors.Vocab at 0x155ef874860>,
#  'ورقة': <gensim.models.keyedvectors.Vocab at 0x155ef874898>,
#  'فئة': <gensim.models.keyedvectors.Vocab at 0x155ef8748d0>,
#  'دولار': <gensim.models.keyedvectors.Vocab at 0x155ef874908>,
#  'اميركي': <gensim.models.keyedvectors.Vocab at 0x155ef874940>,
#  'مزورة': <gensim.models.keyedvectors.Vocab at 0x155ef874978>,
#  'قد': <gensim.models.keyedvectors.Vocab at 0x155ef8749b0>,
#  'اقامت': <gensim.models.keyedvectors.Vocab at 0x155ef8749e8>,
#  'منتهية': <gensim.models.keyedvectors.Vocab at 0x155ef874a20>,
#  'الصلاحية': <gensim.models.keyedvectors.Vocab at 0x155ef874a58>,
#  'مها': <gensim.models.keyedvectors.Vocab at 0x155ef874a90>,
#  'نديم': <gensim.models.keyedvectors.Vocab at 0x155ef874ac8>,
#  'مارينا': <gensim.models.keyedvectors.Vocab at 0x155ef874b00>,
#  'اودي': <gensim.models.keyedvectors.Vocab at 0x155ef874b38>,
#  'ابيض': <gensim.models.keyedvectors.Vocab at 0x155ef874b70>,
#  'ميرا': <gensim.models.keyedvectors.Vocab at 0x155ef874ba8>,
#  'ابراهيم': <gensim.models.keyedvectors.Vocab at 0x155ef874be0>,
#  'ديما': <gensim.models.keyedvectors.Vocab at 0x155ef874c18>,
#  'ادخلت': <gensim.models.keyedvectors.Vocab at 0x155ef874c50>,
#  'الجامعة': <gensim.models.keyedvectors.Vocab at 0x155ef874c88>,
#  'الامريكية': <gensim.models.keyedvectors.Vocab at 0x155ef874cc0>,
#  'طفيفة': <gensim.models.keyedvectors.Vocab at 0x155ef874cf8>,
#  'فادي': <gensim.models.keyedvectors.Vocab at 0x155ef874d30>,
#  'صاحب': <gensim.models.keyedvectors.Vocab at 0x155ef874d68>,
#  'مؤسسة': <gensim.models.keyedvectors.Vocab at 0x155ef874da0>,
#  'المعدة': <gensim.models.keyedvectors.Vocab at 0x155ef874dd8>,
#  'بيع': <gensim.models.keyedvectors.Vocab at 0x155ef874e10>,
#  'اللحوم': <gensim.models.keyedvectors.Vocab at 0x155ef874e48>,
#  'عامل': <gensim.models.keyedvectors.Vocab at 0x155ef874e80>,
#  'السوري': <gensim.models.keyedvectors.Vocab at 0x155ef874eb8>,
#  'يوسف': <gensim.models.keyedvectors.Vocab at 0x155ef874ef0>,
#  'العبود': <gensim.models.keyedvectors.Vocab at 0x155ef874f28>,
#  'العيسى': <gensim.models.keyedvectors.Vocab at 0x155ef874f60>,
#  'ناديا': <gensim.models.keyedvectors.Vocab at 0x155ef874f98>,
#  'جرم': <gensim.models.keyedvectors.Vocab at 0x155ef874fd0>,
#  'الذي': <gensim.models.keyedvectors.Vocab at 0x155ef877048>,
#  'يملك': <gensim.models.keyedvectors.Vocab at 0x155ef877080>,
#  'مع': <gensim.models.keyedvectors.Vocab at 0x155ef8770b8>,
#  'العلم': <gensim.models.keyedvectors.Vocab at 0x155ef8770f0>,
#  'ليست': <gensim.models.keyedvectors.Vocab at 0x155ef877128>,
#  'المرة': <gensim.models.keyedvectors.Vocab at 0x155ef877160>,
#  'يعمل': <gensim.models.keyedvectors.Vocab at 0x155ef877198>,
#  'جاسم': <gensim.models.keyedvectors.Vocab at 0x155ef8771d0>,
#  'ايضا': <gensim.models.keyedvectors.Vocab at 0x155ef877208>,
#  'تجريح': <gensim.models.keyedvectors.Vocab at 0x155ef877240>,
#  'باب': <gensim.models.keyedvectors.Vocab at 0x155ef877278>,
#  'علي': <gensim.models.keyedvectors.Vocab at 0x155ef8772b0>,
#  'عواضة': <gensim.models.keyedvectors.Vocab at 0x155ef8772e8>,
#  'سابقا': <gensim.models.keyedvectors.Vocab at 0x155ef877320>,
#  'تمزيق': <gensim.models.keyedvectors.Vocab at 0x155ef877358>,
#  'اطارات': <gensim.models.keyedvectors.Vocab at 0x155ef877390>,
#  'الاربعة': <gensim.models.keyedvectors.Vocab at 0x155ef8773c8>,
#  'البيال': <gensim.models.keyedvectors.Vocab at 0x155ef877400>,
#  'حصل': <gensim.models.keyedvectors.Vocab at 0x155ef877438>,
#  'تصادم': <gensim.models.keyedvectors.Vocab at 0x155ef877470>,
#  'اللوحة': <gensim.models.keyedvectors.Vocab at 0x155ef8774a8>,
#  'فتحية': <gensim.models.keyedvectors.Vocab at 0x155ef8774e0>,
#  'شحن': <gensim.models.keyedvectors.Vocab at 0x155ef877518>,
#  'خصوصي': <gensim.models.keyedvectors.Vocab at 0x155ef877550>,
#  'فاطمة': <gensim.models.keyedvectors.Vocab at 0x155ef877588>,
#  'سائق': <gensim.models.keyedvectors.Vocab at 0x155ef8775c0>,
#  'جسم': <gensim.models.keyedvectors.Vocab at 0x155ef8775f8>,
#  'الجعيتاوي': <gensim.models.keyedvectors.Vocab at 0x155ef877630>,
#  'تلقي': <gensim.models.keyedvectors.Vocab at 0x155ef877668>,
#  'العلاج': <gensim.models.keyedvectors.Vocab at 0x155ef8776a0>,
#  'غادر': <gensim.models.keyedvectors.Vocab at 0x155ef8776d8>,
#  'ادعاء': <gensim.models.keyedvectors.Vocab at 0x155ef877710>,
#  'لوحات': <gensim.models.keyedvectors.Vocab at 0x155ef877748>,
#  'زقاق': <gensim.models.keyedvectors.Vocab at 0x155ef877780>,
#  'البلاط': <gensim.models.keyedvectors.Vocab at 0x155ef8777b8>,
#  'وعد': <gensim.models.keyedvectors.Vocab at 0x155ef8777f0>,
#  'حضور': <gensim.models.keyedvectors.Vocab at 0x155ef877828>,
#  'المدعي': <gensim.models.keyedvectors.Vocab at 0x155ef877860>,
#  'تاكيد': <gensim.models.keyedvectors.Vocab at 0x155ef877898>,
#  'الشكوى': <gensim.models.keyedvectors.Vocab at 0x155ef8778d0>,
#  'ثم': <gensim.models.keyedvectors.Vocab at 0x155ef877908>,
#  'حضر': <gensim.models.keyedvectors.Vocab at 0x155ef877940>,
#  'اتخذ': <gensim.models.keyedvectors.Vocab at 0x155ef877978>,
#  'الادعاء': <gensim.models.keyedvectors.Vocab at 0x155ef8779b0>,
#  'ختم': <gensim.models.keyedvectors.Vocab at 0x155ef8779e8>,
#  'واسطة': <gensim.models.keyedvectors.Vocab at 0x155ef877a20>,
#  'القضائية': <gensim.models.keyedvectors.Vocab at 0x155ef877a58>,
#  'هاني': <gensim.models.keyedvectors.Vocab at 0x155ef877a90>,
#  'نبيل': <gensim.models.keyedvectors.Vocab at 0x155ef877ac8>,
#  'الجميل': <gensim.models.keyedvectors.Vocab at 0x155ef877b00>,
#  'ايهاب': <gensim.models.keyedvectors.Vocab at 0x155ef877b38>,
#  'شراب': <gensim.models.keyedvectors.Vocab at 0x155ef877b70>,
#  'شيكات': <gensim.models.keyedvectors.Vocab at 0x155ef877ba8>,
#  'تعميم': <gensim.models.keyedvectors.Vocab at 0x155ef877be0>,
#  'بلاغ': <gensim.models.keyedvectors.Vocab at 0x155ef877c18>,
#  'بحث': <gensim.models.keyedvectors.Vocab at 0x155ef877c50>,
#  'تحري': <gensim.models.keyedvectors.Vocab at 0x155ef877c88>,
#  'مدة': <gensim.models.keyedvectors.Vocab at 0x155ef877cc0>,
#  'شهر': <gensim.models.keyedvectors.Vocab at 0x155ef877cf8>,
#  'حق': <gensim.models.keyedvectors.Vocab at 0x155ef877d30>,
#  'المدعى': <gensim.models.keyedvectors.Vocab at 0x155ef877d68>,
#  'اصطدمت': <gensim.models.keyedvectors.Vocab at 0x155ef877da0>,
#  'امين': <gensim.models.keyedvectors.Vocab at 0x155ef877dd8>,
#  'حليمة': <gensim.models.keyedvectors.Vocab at 0x155ef877e10>,
#  'قاسم': <gensim.models.keyedvectors.Vocab at 0x155ef877e48>,
#  'اسماعيل': <gensim.models.keyedvectors.Vocab at 0x155ef877e80>,
#  'حمدة': <gensim.models.keyedvectors.Vocab at 0x155ef877eb8>,
#  'الجنسية': <gensim.models.keyedvectors.Vocab at 0x155ef877ef0>,
#  'قوية': <gensim.models.keyedvectors.Vocab at 0x155ef877f28>,
#  'رجل': <gensim.models.keyedvectors.Vocab at 0x155ef877f60>,
#  'خوري': <gensim.models.keyedvectors.Vocab at 0x155ef877f98>,
#  'الرملة': <gensim.models.keyedvectors.Vocab at 0x155ef877fd0>,
#  'البيضاء': <gensim.models.keyedvectors.Vocab at 0x155ef87a048>,
#  'عاصم': <gensim.models.keyedvectors.Vocab at 0x155ef87a080>,
#  'قانصو': <gensim.models.keyedvectors.Vocab at 0x155ef87a0b8>,
#  'بشرى': <gensim.models.keyedvectors.Vocab at 0x155ef87a0f0>,
#  'عسيران': <gensim.models.keyedvectors.Vocab at 0x155ef87a128>,
#  'رصاصي': <gensim.models.keyedvectors.Vocab at 0x155ef87a160>,
#  'واصفر': <gensim.models.keyedvectors.Vocab at 0x155ef87a198>,
#  'طراز': <gensim.models.keyedvectors.Vocab at 0x155ef87a1d0>,
#  'الهيكل': <gensim.models.keyedvectors.Vocab at 0x155ef87a208>,
#  'المحرك': <gensim.models.keyedvectors.Vocab at 0x155ef87a240>,
#  'ما': <gensim.models.keyedvectors.Vocab at 0x155ef87a278>,
#  'التي': <gensim.models.keyedvectors.Vocab at 0x155ef87a2b0>,
#  'كانت': <gensim.models.keyedvectors.Vocab at 0x155ef87a2e8>,
#  'متوقفة': <gensim.models.keyedvectors.Vocab at 0x155ef87a320>,
#  'موقف': <gensim.models.keyedvectors.Vocab at 0x155ef87a358>,
#  'بناية': <gensim.models.keyedvectors.Vocab at 0x155ef87a390>,
#  'سكن': <gensim.models.keyedvectors.Vocab at 0x155ef87a3c8>,
#  'الدورية': <gensim.models.keyedvectors.Vocab at 0x155ef87a400>,
#  'المعززة': <gensim.models.keyedvectors.Vocab at 0x155ef87a438>,
#  'الثالثة': <gensim.models.keyedvectors.Vocab at 0x155ef87a470>,
#  'مرسيدس': <gensim.models.keyedvectors.Vocab at 0x155ef87a4a8>,
#  'موف': <gensim.models.keyedvectors.Vocab at 0x155ef87a4e0>,
#  'ص': <gensim.models.keyedvectors.Vocab at 0x155ef87a518>,
#  'رفقة': <gensim.models.keyedvectors.Vocab at 0x155ef87a550>,
#  'كل': <gensim.models.keyedvectors.Vocab at 0x155ef87a588>,
#  'ياسين': <gensim.models.keyedvectors.Vocab at 0x155ef87a5c0>,
#  'موسى': <gensim.models.keyedvectors.Vocab at 0x155ef87a5f8>,
#  'جميع': <gensim.models.keyedvectors.Vocab at 0x155ef87a630>,
#  'هم': <gensim.models.keyedvectors.Vocab at 0x155ef87a668>,
#  'اللبنانية': <gensim.models.keyedvectors.Vocab at 0x155ef87a6a0>,
#  'ضبط': <gensim.models.keyedvectors.Vocab at 0x155ef87a6d8>,
#  'الاخير': <gensim.models.keyedvectors.Vocab at 0x155ef87a710>,
#  'قطعة': <gensim.models.keyedvectors.Vocab at 0x155ef87a748>,
#  'كيس': <gensim.models.keyedvectors.Vocab at 0x155ef87a780>,
#  'نايلون': <gensim.models.keyedvectors.Vocab at 0x155ef87a7b8>,
#  'جرى': <gensim.models.keyedvectors.Vocab at 0x155ef87a7f0>,
#  'تسليم': <gensim.models.keyedvectors.Vocab at 0x155ef87a828>,
#  'الي': <gensim.models.keyedvectors.Vocab at 0x155ef87a860>,
#  'نا': <gensim.models.keyedvectors.Vocab at 0x155ef87a898>,
#  'اللازم': <gensim.models.keyedvectors.Vocab at 0x155ef87a8d0>,
#  'جابر': <gensim.models.keyedvectors.Vocab at 0x155ef87a908>,
#  'الخلف': <gensim.models.keyedvectors.Vocab at 0x155ef87a940>,
#  'تسبب': <gensim.models.keyedvectors.Vocab at 0x155ef87a978>,
#  'اضرار': <gensim.models.keyedvectors.Vocab at 0x155ef87a9b0>,
#  'جسيمة': <gensim.models.keyedvectors.Vocab at 0x155ef87a9e8>,
#  'حضرت': <gensim.models.keyedvectors.Vocab at 0x155ef87aa20>,
#  'مايا': <gensim.models.keyedvectors.Vocab at 0x155ef87aa58>,
#  'انطوان': <gensim.models.keyedvectors.Vocab at 0x155ef87aa90>,
#  'الحاج': <gensim.models.keyedvectors.Vocab at 0x155ef87aac8>,
#  'مجهولا': <gensim.models.keyedvectors.Vocab at 0x155ef87ab00>,
#  'كسر': <gensim.models.keyedvectors.Vocab at 0x155ef87ab38>,
#  'مساحة': <gensim.models.keyedvectors.Vocab at 0x155ef87ab70>,
#  'الامامية': <gensim.models.keyedvectors.Vocab at 0x155ef87aba8>,
#  'بيضاء': <gensim.models.keyedvectors.Vocab at 0x155ef87abe0>,
#  'متوسطة': <gensim.models.keyedvectors.Vocab at 0x155ef87ac18>,
#  'مكتوب': <gensim.models.keyedvectors.Vocab at 0x155ef87ac50>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x155ef87ac88>,
#  'مجمع': <gensim.models.keyedvectors.Vocab at 0x155ef87acc0>,
#  'يموت': <gensim.models.keyedvectors.Vocab at 0x155ef87acf8>,
#  'مديرة': <gensim.models.keyedvectors.Vocab at 0x155ef87ad30>,
#  'ثانوية': <gensim.models.keyedvectors.Vocab at 0x155ef87ad68>,
#  'الامير': <gensim.models.keyedvectors.Vocab at 0x155ef87ada0>,
#  'شكيب': <gensim.models.keyedvectors.Vocab at 0x155ef87add8>,
#  'ارسلان': <gensim.models.keyedvectors.Vocab at 0x155ef87ae10>,
#  'فجر': <gensim.models.keyedvectors.Vocab at 0x155ef87ae48>,
#  'اليوم': <gensim.models.keyedvectors.Vocab at 0x155ef87ae80>,
#  'كتابة': <gensim.models.keyedvectors.Vocab at 0x155ef87aeb8>,
#  'عبارات': <gensim.models.keyedvectors.Vocab at 0x155ef87aef0>,
#  'مسيئة': <gensim.models.keyedvectors.Vocab at 0x155ef87af28>,
#  'مقابل': <gensim.models.keyedvectors.Vocab at 0x155ef87af60>,
#  'مدخل': <gensim.models.keyedvectors.Vocab at 0x155ef87af98>,
#  'ماهر': <gensim.models.keyedvectors.Vocab at 0x155ef87afd0>,
#  'الموسى': <gensim.models.keyedvectors.Vocab at 0x155ef87e048>,
#  'مسؤول': <gensim.models.keyedvectors.Vocab at 0x155ef87e080>,
#  'الموظفين': <gensim.models.keyedvectors.Vocab at 0x155ef87e0b8>,
#  'اوتيل': <gensim.models.keyedvectors.Vocab at 0x155ef87e0f0>,
#  'بي': <gensim.models.keyedvectors.Vocab at 0x155ef87e128>,
#  'صرح': <gensim.models.keyedvectors.Vocab at 0x155ef87e160>,
#  'حصلت': <gensim.models.keyedvectors.Vocab at 0x155ef87e198>,
#  'عملية': <gensim.models.keyedvectors.Vocab at 0x155ef87e1d0>,
#  'الاوتيل': <gensim.models.keyedvectors.Vocab at 0x155ef87e208>,
#  'المذكور': <gensim.models.keyedvectors.Vocab at 0x155ef87e240>,
#  'الفاعل': <gensim.models.keyedvectors.Vocab at 0x155ef87e278>,
#  'يدعى': <gensim.models.keyedvectors.Vocab at 0x155ef87e2b0>,
#  'بلال': <gensim.models.keyedvectors.Vocab at 0x155ef87e2e8>,
#  'اعترف': <gensim.models.keyedvectors.Vocab at 0x155ef87e320>,
#  'هو': <gensim.models.keyedvectors.Vocab at 0x155ef87e358>,
#  'الان': <gensim.models.keyedvectors.Vocab at 0x155ef87e390>,
#  'موجود': <gensim.models.keyedvectors.Vocab at 0x155ef87e3c8>,
#  'شريك': <gensim.models.keyedvectors.Vocab at 0x155ef87e400>,
#  'اخر': <gensim.models.keyedvectors.Vocab at 0x155ef87e438>,
#  'سامر': <gensim.models.keyedvectors.Vocab at 0x155ef87e470>,
#  'الجمل': <gensim.models.keyedvectors.Vocab at 0x155ef87e4a8>,
#  'الكولا': <gensim.models.keyedvectors.Vocab at 0x155ef87e4e0>,
#  'فراولة': <gensim.models.keyedvectors.Vocab at 0x155ef87e518>,
#  'مخدرة': <gensim.models.keyedvectors.Vocab at 0x155ef87e550>,
#  'سلمت': <gensim.models.keyedvectors.Vocab at 0x155ef87e588>,
#  'جادة': <gensim.models.keyedvectors.Vocab at 0x155ef87e5c0>,
#  'اصطدام': <gensim.models.keyedvectors.Vocab at 0x155ef87e5f8>,
#  'ف': <gensim.models.keyedvectors.Vocab at 0x155ef87e630>,
#  'مدني': <gensim.models.keyedvectors.Vocab at 0x155ef87e668>,
#  'سلمان': <gensim.models.keyedvectors.Vocab at 0x155ef87e6a0>,
#  'زعيتر': <gensim.models.keyedvectors.Vocab at 0x155ef87e6d8>,
#  'جيب': <gensim.models.keyedvectors.Vocab at 0x155ef87e710>,
#  'هوندا': <gensim.models.keyedvectors.Vocab at 0x155ef87e748>,
#  'ط': <gensim.models.keyedvectors.Vocab at 0x155ef87e780>,
#  'فاروق': <gensim.models.keyedvectors.Vocab at 0x155ef87e7b8>,
#  'عثمان': <gensim.models.keyedvectors.Vocab at 0x155ef87e7f0>,
#  'مجذوب': <gensim.models.keyedvectors.Vocab at 0x155ef87e828>,
#  'صديق': <gensim.models.keyedvectors.Vocab at 0x155ef87e860>,
#  'جسدية': <gensim.models.keyedvectors.Vocab at 0x155ef87e898>,
#  'مادية': <gensim.models.keyedvectors.Vocab at 0x155ef87e8d0>,
#  'جرح': <gensim.models.keyedvectors.Vocab at 0x155ef87e908>,
#  'الراس': <gensim.models.keyedvectors.Vocab at 0x155ef87e940>,
#  'عولج': <gensim.models.keyedvectors.Vocab at 0x155ef87e978>,
#  'المقاصد': <gensim.models.keyedvectors.Vocab at 0x155ef87e9b0>,
#  'اخرج': <gensim.models.keyedvectors.Vocab at 0x155ef87e9e8>,
#  'قريطم': <gensim.models.keyedvectors.Vocab at 0x155ef87ea20>,
#  'اللبان': <gensim.models.keyedvectors.Vocab at 0x155ef87ea58>,
#  'ايمن': <gensim.models.keyedvectors.Vocab at 0x155ef87ea90>,
#  'شحاد': <gensim.models.keyedvectors.Vocab at 0x155ef87eac8>,
#  'شهاب': <gensim.models.keyedvectors.Vocab at 0x155ef87eb00>,
#  'زكي': <gensim.models.keyedvectors.Vocab at 0x155ef87eb38>,
#  'ازرق': <gensim.models.keyedvectors.Vocab at 0x155ef87eb70>,
#  'بدر': <gensim.models.keyedvectors.Vocab at 0x155ef87eba8>,
#  'شاتيلا': <gensim.models.keyedvectors.Vocab at 0x155ef87ebe0>,
#  'المصدوم': <gensim.models.keyedvectors.Vocab at 0x155ef87ec18>,
#  'برض': <gensim.models.keyedvectors.Vocab at 0x155ef87ec50>,
#  'صفر': <gensim.models.keyedvectors.Vocab at 0x155ef87ec88>,
#  'بشارة': <gensim.models.keyedvectors.Vocab at 0x155ef87ecc0>,
#  'هيونداي': <gensim.models.keyedvectors.Vocab at 0x155ef87ecf8>,
#  'تحمل': <gensim.models.keyedvectors.Vocab at 0x155ef87ed30>,
#  'الرقم': <gensim.models.keyedvectors.Vocab at 0x155ef87ed68>,
#  'خضر': <gensim.models.keyedvectors.Vocab at 0x155ef87eda0>,
#  'صفوان': <gensim.models.keyedvectors.Vocab at 0x155ef87edd8>,
#  'صيني': <gensim.models.keyedvectors.Vocab at 0x155ef87ee10>,
#  'عساف': <gensim.models.keyedvectors.Vocab at 0x155ef87ee48>,
#  'هدى': <gensim.models.keyedvectors.Vocab at 0x155ef87ee80>,
#  'خديجة': <gensim.models.keyedvectors.Vocab at 0x155ef87eeb8>,
#  'نقلا': <gensim.models.keyedvectors.Vocab at 0x155ef87eef0>,
#  'حالة': <gensim.models.keyedvectors.Vocab at 0x155ef87ef28>,
#  'هما': <gensim.models.keyedvectors.Vocab at 0x155ef87ef60>,
#  'مستقرة': <gensim.models.keyedvectors.Vocab at 0x155ef87ef98>,
#  'مقدمة': <gensim.models.keyedvectors.Vocab at 0x155ef87efd0>,
#  'المدعية': <gensim.models.keyedvectors.Vocab at 0x155ef882048>,
#  'الشركة': <gensim.models.keyedvectors.Vocab at 0x155ef882080>,
#  'التجارة': <gensim.models.keyedvectors.Vocab at 0x155ef8820b8>,
#  'ش': <gensim.models.keyedvectors.Vocab at 0x155ef8820f0>,
#  'شور': <gensim.models.keyedvectors.Vocab at 0x155ef882128>,
#  'احتيال': <gensim.models.keyedvectors.Vocab at 0x155ef882160>,
#  'عيدو': <gensim.models.keyedvectors.Vocab at 0x155ef882198>,
#  'وكيل': <gensim.models.keyedvectors.Vocab at 0x155ef8821d0>,
#  'المحامية': <gensim.models.keyedvectors.Vocab at 0x155ef882208>,
#  'سمر': <gensim.models.keyedvectors.Vocab at 0x155ef882240>,
#  'فخر': <gensim.models.keyedvectors.Vocab at 0x155ef882278>,
#  'قدح': <gensim.models.keyedvectors.Vocab at 0x155ef8822b0>,
#  'ذم': <gensim.models.keyedvectors.Vocab at 0x155ef8822e8>,
#  'تهديد': <gensim.models.keyedvectors.Vocab at 0x155ef882320>,
#  'مراجعة': <gensim.models.keyedvectors.Vocab at 0x155ef882358>,
#  'القضاء': <gensim.models.keyedvectors.Vocab at 0x155ef882390>,
#  'اشار': <gensim.models.keyedvectors.Vocab at 0x155ef8823c8>,
#  'ترك': <gensim.models.keyedvectors.Vocab at 0x155ef882400>,
#  'الخضر': <gensim.models.keyedvectors.Vocab at 0x155ef882438>,
#  'فخرو': <gensim.models.keyedvectors.Vocab at 0x155ef882470>,
#  'لقاء': <gensim.models.keyedvectors.Vocab at 0x155ef8824a8>,
#  'سند': <gensim.models.keyedvectors.Vocab at 0x155ef8824e0>,
#  'اقامة': <gensim.models.keyedvectors.Vocab at 0x155ef882518>,
#  'بيان': <gensim.models.keyedvectors.Vocab at 0x155ef882550>,
#  'كامل': <gensim.models.keyedvectors.Vocab at 0x155ef882588>,
#  'هوية': <gensim.models.keyedvectors.Vocab at 0x155ef8825c0>,
#  'المدني': <gensim.models.keyedvectors.Vocab at 0x155ef8825f8>,
#  'المدرسة': <gensim.models.keyedvectors.Vocab at 0x155ef882630>,
#  'تعمل': <gensim.models.keyedvectors.Vocab at 0x155ef882668>,
#  'سميرة': <gensim.models.keyedvectors.Vocab at 0x155ef8826a0>,
#  'عواد': <gensim.models.keyedvectors.Vocab at 0x155ef8826d8>,
#  'والد': <gensim.models.keyedvectors.Vocab at 0x155ef882710>,
#  'توجه': <gensim.models.keyedvectors.Vocab at 0x155ef882748>,
#  'القدح': <gensim.models.keyedvectors.Vocab at 0x155ef882780>,
#  'الذم': <gensim.models.keyedvectors.Vocab at 0x155ef8827b8>,
#  'كلام': <gensim.models.keyedvectors.Vocab at 0x155ef8827f0>,
#  'حاول': <gensim.models.keyedvectors.Vocab at 0x155ef882828>,
#  'مسك': <gensim.models.keyedvectors.Vocab at 0x155ef882860>,
#  'ضرب': <gensim.models.keyedvectors.Vocab at 0x155ef882898>,
#  'لكن': <gensim.models.keyedvectors.Vocab at 0x155ef8828d0>,
#  'لم': <gensim.models.keyedvectors.Vocab at 0x155ef882908>,
#  'بهيج': <gensim.models.keyedvectors.Vocab at 0x155ef882940>,
#  'احتيالية': <gensim.models.keyedvectors.Vocab at 0x155ef882978>,
#  'مطر': <gensim.models.keyedvectors.Vocab at 0x155ef8829b0>,
#  'بضائع': <gensim.models.keyedvectors.Vocab at 0x155ef8829e8>,
#  'اخرى': <gensim.models.keyedvectors.Vocab at 0x155ef882a20>,
#  'فروا': <gensim.models.keyedvectors.Vocab at 0x155ef882a58>,
#  'تقدر': <gensim.models.keyedvectors.Vocab at 0x155ef882a90>,
#  'الاحتيال': <gensim.models.keyedvectors.Vocab at 0x155ef882ac8>,
#  'قيمة': <gensim.models.keyedvectors.Vocab at 0x155ef882b00>,
#  'زهر': <gensim.models.keyedvectors.Vocab at 0x155ef882b38>,
#  'الدين': <gensim.models.keyedvectors.Vocab at 0x155ef882b70>,
#  'قفل': <gensim.models.keyedvectors.Vocab at 0x155ef882ba8>,
#  'منزل': <gensim.models.keyedvectors.Vocab at 0x155ef882be0>,
#  'السكن': <gensim.models.keyedvectors.Vocab at 0x155ef882c18>,
#  'اذن': <gensim.models.keyedvectors.Vocab at 0x155ef882c50>,
#  'اعلام': <gensim.models.keyedvectors.Vocab at 0x155ef882c88>,
#  'الروشة': <gensim.models.keyedvectors.Vocab at 0x155ef882cc0>,
#  'العميد': <gensim.models.keyedvectors.Vocab at 0x155ef882cf8>,
#  'المتقاعد': <gensim.models.keyedvectors.Vocab at 0x155ef882d30>,
#  'الجيش': <gensim.models.keyedvectors.Vocab at 0x155ef882d68>,
#  'اللبناني': <gensim.models.keyedvectors.Vocab at 0x155ef882da0>,
#  'هشام': <gensim.models.keyedvectors.Vocab at 0x155ef882dd8>,
#  'مفيد': <gensim.models.keyedvectors.Vocab at 0x155ef882e10>,
#  'حوالي': <gensim.models.keyedvectors.Vocab at 0x155ef882e48>,
#  'اقدمت': <gensim.models.keyedvectors.Vocab at 0x155ef882e80>,
#  'اثيوبية': <gensim.models.keyedvectors.Vocab at 0x155ef882eb8>,
#  'الكائن': <gensim.models.keyedvectors.Vocab at 0x155ef882ef0>,
#  'صليبا': <gensim.models.keyedvectors.Vocab at 0x155ef882f28>,
#  'طابق': <gensim.models.keyedvectors.Vocab at 0x155ef882f60>,
#  'ثياب': <gensim.models.keyedvectors.Vocab at 0x155ef882f98>,
#  'عائدة': <gensim.models.keyedvectors.Vocab at 0x155ef882fd0>,
#  'ذهبية': <gensim.models.keyedvectors.Vocab at 0x155ef886048>,
#  'غادرا': <gensim.models.keyedvectors.Vocab at 0x155ef886080>,
#  'قدر': <gensim.models.keyedvectors.Vocab at 0x155ef8860b8>,
#  'المسروقات': <gensim.models.keyedvectors.Vocab at 0x155ef8860f0>,
#  'امريكي': <gensim.models.keyedvectors.Vocab at 0x155ef886128>,
#  'موضوع': <gensim.models.keyedvectors.Vocab at 0x155ef886160>,
#  'همام': <gensim.models.keyedvectors.Vocab at 0x155ef886198>,
#  'شاهين': <gensim.models.keyedvectors.Vocab at 0x155ef8861d0>,
#  'ياما': <gensim.models.keyedvectors.Vocab at 0x155ef886208>,
#  'ابريو': <gensim.models.keyedvectors.Vocab at 0x155ef886240>,
#  'ادريس': <gensim.models.keyedvectors.Vocab at 0x155ef886278>,
#  'صعب': <gensim.models.keyedvectors.Vocab at 0x155ef8862b0>,
#  'امنة': <gensim.models.keyedvectors.Vocab at 0x155ef8862e8>,
#  'فؤاد': <gensim.models.keyedvectors.Vocab at 0x155ef886320>,
#  'عبير': <gensim.models.keyedvectors.Vocab at 0x155ef886358>,
#  'طبارة': <gensim.models.keyedvectors.Vocab at 0x155ef886390>,
#  'صباح': <gensim.models.keyedvectors.Vocab at 0x155ef8863c8>,
#  'مجهولان': <gensim.models.keyedvectors.Vocab at 0x155ef886400>,
#  'حقيبة': <gensim.models.keyedvectors.Vocab at 0x155ef886438>,
#  'اوراق': <gensim.models.keyedvectors.Vocab at 0x155ef886470>,
#  'ثبوتية': <gensim.models.keyedvectors.Vocab at 0x155ef8864a8>,
#  'خاصة': <gensim.models.keyedvectors.Vocab at 0x155ef8864e0>,
#  'مبلغ': <gensim.models.keyedvectors.Vocab at 0x155ef886518>,
#  'مالي': <gensim.models.keyedvectors.Vocab at 0x155ef886550>,
#  'الظريف': <gensim.models.keyedvectors.Vocab at 0x155ef886588>,
#  'يعقوب': <gensim.models.keyedvectors.Vocab at 0x155ef8865c0>,
#  'فرا': <gensim.models.keyedvectors.Vocab at 0x155ef8865f8>,
#  'الاجراء': <gensim.models.keyedvectors.Vocab at 0x155ef886630>,
#  'الازم': <gensim.models.keyedvectors.Vocab at 0x155ef886668>,
#  'جمال': <gensim.models.keyedvectors.Vocab at 0x155ef8866a0>,
#  'تمام': <gensim.models.keyedvectors.Vocab at 0x155ef8866d8>,
#  'رابيد': <gensim.models.keyedvectors.Vocab at 0x155ef886710>,
#  'كونغو': <gensim.models.keyedvectors.Vocab at 0x155ef886748>,
#  'وقوف': <gensim.models.keyedvectors.Vocab at 0x155ef886780>,
#  'عبدالناصر': <gensim.models.keyedvectors.Vocab at 0x155ef8867b8>,
#  'محطة': <gensim.models.keyedvectors.Vocab at 0x155ef8867f0>,
#  'المقداد': <gensim.models.keyedvectors.Vocab at 0x155ef886828>,
#  'وفر': <gensim.models.keyedvectors.Vocab at 0x155ef886860>,
#  'فلسطيني': <gensim.models.keyedvectors.Vocab at 0x155ef886898>,
#  'سبب': <gensim.models.keyedvectors.Vocab at 0x155ef8868d0>,
#  'حصول': <gensim.models.keyedvectors.Vocab at 0x155ef886908>,
#  'اشكال': <gensim.models.keyedvectors.Vocab at 0x155ef886940>,
#  'عماد': <gensim.models.keyedvectors.Vocab at 0x155ef886978>,
#  'النابلسي': <gensim.models.keyedvectors.Vocab at 0x155ef8869b0>,
#  'فاتن': <gensim.models.keyedvectors.Vocab at 0x155ef8869e8>,
#  'بئر': <gensim.models.keyedvectors.Vocab at 0x155ef886a20>,
#  'خارج': <gensim.models.keyedvectors.Vocab at 0x155ef886a58>,
#  'نطاق': <gensim.models.keyedvectors.Vocab at 0x155ef886a90>,
#  'شرطة': <gensim.models.keyedvectors.Vocab at 0x155ef886ac8>,
#  'ورد': <gensim.models.keyedvectors.Vocab at 0x155ef886b00>,
#  'اتصال': <gensim.models.keyedvectors.Vocab at 0x155ef886b38>,
#  'عبر': <gensim.models.keyedvectors.Vocab at 0x155ef886b70>,
#  'خط': <gensim.models.keyedvectors.Vocab at 0x155ef886ba8>,
#  'النجد': <gensim.models.keyedvectors.Vocab at 0x155ef886be0>,
#  'مفاد': <gensim.models.keyedvectors.Vocab at 0x155ef886c18>,
#  'اقدام': <gensim.models.keyedvectors.Vocab at 0x155ef886c50>,
#  'الحمراء': <gensim.models.keyedvectors.Vocab at 0x155ef886c88>,
#  'اسباب': <gensim.models.keyedvectors.Vocab at 0x155ef886cc0>,
#  'حسب': <gensim.models.keyedvectors.Vocab at 0x155ef886cf8>,
#  'افادة': <gensim.models.keyedvectors.Vocab at 0x155ef886d30>,
#  'عمل': <gensim.models.keyedvectors.Vocab at 0x155ef886d68>,
#  'ازالة': <gensim.models.keyedvectors.Vocab at 0x155ef886da0>,
#  'اصلاح': <gensim.models.keyedvectors.Vocab at 0x155ef886dd8>,
#  'الاطارات': <gensim.models.keyedvectors.Vocab at 0x155ef886e10>,
#  'الاتصال': <gensim.models.keyedvectors.Vocab at 0x155ef886e48>,
#  'النجدة': <gensim.models.keyedvectors.Vocab at 0x155ef886e80>,
#  'يحضر': <gensim.models.keyedvectors.Vocab at 0x155ef886eb8>,
#  'ميرنا': <gensim.models.keyedvectors.Vocab at 0x155ef886ef0>,
#  'بسام': <gensim.models.keyedvectors.Vocab at 0x155ef886f28>,
#  'عوالي': <gensim.models.keyedvectors.Vocab at 0x155ef886f60>,
#  'امل': <gensim.models.keyedvectors.Vocab at 0x155ef886f98>,
#  'تواد': <gensim.models.keyedvectors.Vocab at 0x155ef886fd0>,
#  'قوف': <gensim.models.keyedvectors.Vocab at 0x155ef889048>,
#  'تيدا': <gensim.models.keyedvectors.Vocab at 0x155ef889080>,
#  'الوحة': <gensim.models.keyedvectors.Vocab at 0x155ef8890b8>,
#  'المتحف': <gensim.models.keyedvectors.Vocab at 0x155ef8890f0>,
#  'كنيسة': <gensim.models.keyedvectors.Vocab at 0x155ef889128>,
#  'سيدة': <gensim.models.keyedvectors.Vocab at 0x155ef889160>,
#  'شخصين': <gensim.models.keyedvectors.Vocab at 0x155ef889198>,
#  'الثبوتية': <gensim.models.keyedvectors.Vocab at 0x155ef8891d0>,
#  'الخاصة': <gensim.models.keyedvectors.Vocab at 0x155ef889208>,
#  'جسر': <gensim.models.keyedvectors.Vocab at 0x155ef889240>,
#  'العدلية': <gensim.models.keyedvectors.Vocab at 0x155ef889278>,
#  'تنظيم': <gensim.models.keyedvectors.Vocab at 0x155ef8892b0>,
#  'الفصيلة': <gensim.models.keyedvectors.Vocab at 0x155ef8892e8>,
#  'المذكورة': <gensim.models.keyedvectors.Vocab at 0x155ef889320>,
#  'اصطدم': <gensim.models.keyedvectors.Vocab at 0x155ef889358>,
#  'الجيب': <gensim.models.keyedvectors.Vocab at 0x155ef889390>,
#  'برادو': <gensim.models.keyedvectors.Vocab at 0x155ef8893c8>,
#  'باج': <gensim.models.keyedvectors.Vocab at 0x155ef889400>,
#  'السائق': <gensim.models.keyedvectors.Vocab at 0x155ef889438>,
#  'المكان': <gensim.models.keyedvectors.Vocab at 0x155ef889470>,
#  'نبيذي': <gensim.models.keyedvectors.Vocab at 0x155ef8894a8>,
#  'حمزة': <gensim.models.keyedvectors.Vocab at 0x155ef8894e0>,
#  'الحركة': <gensim.models.keyedvectors.Vocab at 0x155ef889518>,
#  'اصيب': <gensim.models.keyedvectors.Vocab at 0x155ef889550>,
#  'الاميركية': <gensim.models.keyedvectors.Vocab at 0x155ef889588>,
#  'قائمة': <gensim.models.keyedvectors.Vocab at 0x155ef8895c0>,
#  'الكريم': <gensim.models.keyedvectors.Vocab at 0x155ef8895f8>,
#  'غسان': <gensim.models.keyedvectors.Vocab at 0x155ef889630>,
#  'الناريه': <gensim.models.keyedvectors.Vocab at 0x155ef889668>,
#  'تابت': <gensim.models.keyedvectors.Vocab at 0x155ef8896a0>,
#  'باحة': <gensim.models.keyedvectors.Vocab at 0x155ef8896d8>,
#  'جعفر': <gensim.models.keyedvectors.Vocab at 0x155ef889710>,
#  'غاية': <gensim.models.keyedvectors.Vocab at 0x155ef889748>,
#  'يغان': <gensim.models.keyedvectors.Vocab at 0x155ef889780>,
#  'مراب': <gensim.models.keyedvectors.Vocab at 0x155ef8897b8>,
#  'السيارات': <gensim.models.keyedvectors.Vocab at 0x155ef8897f0>,
#  'عبيد': <gensim.models.keyedvectors.Vocab at 0x155ef889828>,
#  'روان': <gensim.models.keyedvectors.Vocab at 0x155ef889860>,
#  'سكين': <gensim.models.keyedvectors.Vocab at 0x155ef889898>,
#  'ستة': <gensim.models.keyedvectors.Vocab at 0x155ef8898d0>,
#  'طقات': <gensim.models.keyedvectors.Vocab at 0x155ef889908>,
#  'المدعوين': <gensim.models.keyedvectors.Vocab at 0x155ef889940>,
#  'سمير': <gensim.models.keyedvectors.Vocab at 0x155ef889978>,
#  'غصن': <gensim.models.keyedvectors.Vocab at 0x155ef8899b0>,
#  'عباس': <gensim.models.keyedvectors.Vocab at 0x155ef8899e8>,
#  'مغربل': <gensim.models.keyedvectors.Vocab at 0x155ef889a20>,
#  'عصام': <gensim.models.keyedvectors.Vocab at 0x155ef889a58>,
#  'الهاتف': <gensim.models.keyedvectors.Vocab at 0x155ef889a90>,
#  'س': <gensim.models.keyedvectors.Vocab at 0x155ef889ac8>,
#  'اشخاص': <gensim.models.keyedvectors.Vocab at 0x155ef889b00>,
#  'عدم': <gensim.models.keyedvectors.Vocab at 0x155ef889b38>,
#  'تسجيل': <gensim.models.keyedvectors.Vocab at 0x155ef889b70>,
#  'ابنة': <gensim.models.keyedvectors.Vocab at 0x155ef889ba8>,
#  'سلمة': <gensim.models.keyedvectors.Vocab at 0x155ef889be0>,
#  'العبد': <gensim.models.keyedvectors.Vocab at 0x155ef889c18>,
#  'مالك': <gensim.models.keyedvectors.Vocab at 0x155ef889c50>,
#  'حامد': <gensim.models.keyedvectors.Vocab at 0x155ef889c88>,
#  'غير': <gensim.models.keyedvectors.Vocab at 0x155ef889cc0>,
#  'مشروعة': <gensim.models.keyedvectors.Vocab at 0x155ef889cf8>,
#  'الروم': <gensim.models.keyedvectors.Vocab at 0x155ef889d30>,
#  'المعاون': <gensim.models.keyedvectors.Vocab at 0x155ef889d68>,
#  'حريق': <gensim.models.keyedvectors.Vocab at 0x155ef889da0>,
#  'رتباء': <gensim.models.keyedvectors.Vocab at 0x155ef889dd8>,
#  'بعبدا': <gensim.models.keyedvectors.Vocab at 0x155ef889e10>,
#  'اثر': <gensim.models.keyedvectors.Vocab at 0x155ef889e48>,
#  'وحدة': <gensim.models.keyedvectors.Vocab at 0x155ef889e80>,
#  'فيكتور': <gensim.models.keyedvectors.Vocab at 0x155ef889eb8>,
#  'فياض': <gensim.models.keyedvectors.Vocab at 0x155ef889ef0>,
#  'قدم': <gensim.models.keyedvectors.Vocab at 0x155ef889f28>,
#  'اليسرى': <gensim.models.keyedvectors.Vocab at 0x155ef889f60>,
#  'اجريت': <gensim.models.keyedvectors.Vocab at 0x155ef889f98>,
#  'المفتش': <gensim.models.keyedvectors.Vocab at 0x155ef889fd0>,
#  'كهرباء': <gensim.models.keyedvectors.Vocab at 0x155ef88d048>,
#  'لبنان': <gensim.models.keyedvectors.Vocab at 0x155ef88d080>,
#  'الناصر': <gensim.models.keyedvectors.Vocab at 0x155ef88d0b8>,
#  'ديب': <gensim.models.keyedvectors.Vocab at 0x155ef88d0f0>,
#  'جبان': <gensim.models.keyedvectors.Vocab at 0x155ef88d128>,
#  'نفيسة': <gensim.models.keyedvectors.Vocab at 0x155ef88d160>,
#  'السوديكو': <gensim.models.keyedvectors.Vocab at 0x155ef88d198>,
#  'الاستقلال': <gensim.models.keyedvectors.Vocab at 0x155ef88d1d0>,
#  'ارضي': <gensim.models.keyedvectors.Vocab at 0x155ef88d208>,
#  'قيام': <gensim.models.keyedvectors.Vocab at 0x155ef88d240>,
#  'مهمة': <gensim.models.keyedvectors.Vocab at 0x155ef88d278>,
#  'تنفيذ': <gensim.models.keyedvectors.Vocab at 0x155ef88d2b0>,
#  'قطع': <gensim.models.keyedvectors.Vocab at 0x155ef88d2e8>,
#  'التيار': <gensim.models.keyedvectors.Vocab at 0x155ef88d320>,
#  'الكهربائي': <gensim.models.keyedvectors.Vocab at 0x155ef88d358>,
#  'شخص': <gensim.models.keyedvectors.Vocab at 0x155ef88d390>,
#  'دفع': <gensim.models.keyedvectors.Vocab at 0x155ef88d3c8>,
#  'صفع': <gensim.models.keyedvectors.Vocab at 0x155ef88d400>,
#  'وجه': <gensim.models.keyedvectors.Vocab at 0x155ef88d438>,
#  'الاشرفية': <gensim.models.keyedvectors.Vocab at 0x155ef88d470>,
#  'حليم': <gensim.models.keyedvectors.Vocab at 0x155ef88d4a8>,
#  'ماضي': <gensim.models.keyedvectors.Vocab at 0x155ef88d4e0>,
#  'تواجد': <gensim.models.keyedvectors.Vocab at 0x155ef88d518>,
#  'قرب': <gensim.models.keyedvectors.Vocab at 0x155ef88d550>,
#  'بوظة': <gensim.models.keyedvectors.Vocab at 0x155ef88d588>,
#  'بشير': <gensim.models.keyedvectors.Vocab at 0x155ef88d5c0>,
#  'يرتدي': <gensim.models.keyedvectors.Vocab at 0x155ef88d5f8>,
#  'هواوي': <gensim.models.keyedvectors.Vocab at 0x155ef88d630>,
#  'المعنية': <gensim.models.keyedvectors.Vocab at 0x155ef88d668>,
#  'فولفو': <gensim.models.keyedvectors.Vocab at 0x155ef88d6a0>,
#  'رمز': <gensim.models.keyedvectors.Vocab at 0x155ef88d6d8>,
#  'هاوجيو': <gensim.models.keyedvectors.Vocab at 0x155ef88d710>,
#  'برتقالي': <gensim.models.keyedvectors.Vocab at 0x155ef88d748>,
#  'هنادي': <gensim.models.keyedvectors.Vocab at 0x155ef88d780>,
#  'نور': <gensim.models.keyedvectors.Vocab at 0x155ef88d7b8>,
#  'مروان': <gensim.models.keyedvectors.Vocab at 0x155ef88d7f0>,
#  'مهنا': <gensim.models.keyedvectors.Vocab at 0x155ef88d828>,
#  'رضى': <gensim.models.keyedvectors.Vocab at 0x155ef88d860>,
#  'همن': <gensim.models.keyedvectors.Vocab at 0x155ef88d898>,
#  'بيب': <gensim.models.keyedvectors.Vocab at 0x155ef88d8d0>,
#  'الحجار': <gensim.models.keyedvectors.Vocab at 0x155ef88d908>,
#  'الرحمان': <gensim.models.keyedvectors.Vocab at 0x155ef88d940>,
#  'نظيرة': <gensim.models.keyedvectors.Vocab at 0x155ef88d978>,
#  'هارلي': <gensim.models.keyedvectors.Vocab at 0x155ef88d9b0>,
#  'الحصروني': <gensim.models.keyedvectors.Vocab at 0x155ef88d9e8>,
#  'علاء': <gensim.models.keyedvectors.Vocab at 0x155ef88da20>,
#  'العياص': <gensim.models.keyedvectors.Vocab at 0x155ef88da58>,
#  'رانيا': <gensim.models.keyedvectors.Vocab at 0x155ef88da90>,
#  'تحت': <gensim.models.keyedvectors.Vocab at 0x155ef88dac8>,
#  'الجسر': <gensim.models.keyedvectors.Vocab at 0x155ef88db00>,
#  'اكس': <gensim.models.keyedvectors.Vocab at 0x155ef88db38>,
#  'الشريحة': <gensim.models.keyedvectors.Vocab at 0x155ef88db70>,
#  'سناء': <gensim.models.keyedvectors.Vocab at 0x155ef88dba8>,
#  'الحكيم': <gensim.models.keyedvectors.Vocab at 0x155ef88dbe0>,
#  'رياض': <gensim.models.keyedvectors.Vocab at 0x155ef88dc18>,
#  'الرفاعي': <gensim.models.keyedvectors.Vocab at 0x155ef88dc50>,
#  'عائشة': <gensim.models.keyedvectors.Vocab at 0x155ef88dc88>,
#  'رزق': <gensim.models.keyedvectors.Vocab at 0x155ef88dcc0>,
#  'موظف': <gensim.models.keyedvectors.Vocab at 0x155ef88dcf8>,
#  'شركة': <gensim.models.keyedvectors.Vocab at 0x155ef88dd30>,
#  'الضرب': <gensim.models.keyedvectors.Vocab at 0x155ef88dd68>,
#  'الكهرباء': <gensim.models.keyedvectors.Vocab at 0x155ef88dda0>,
#  'محي': <gensim.models.keyedvectors.Vocab at 0x155ef88ddd8>,
#  'المغربل': <gensim.models.keyedvectors.Vocab at 0x155ef88de10>,
#  'مركونة': <gensim.models.keyedvectors.Vocab at 0x155ef88de48>,
#  'العام': <gensim.models.keyedvectors.Vocab at 0x155ef88de80>,
#  'مبنى': <gensim.models.keyedvectors.Vocab at 0x155ef88deb8>,
#  'فرار': <gensim.models.keyedvectors.Vocab at 0x155ef88def0>,
#  'يامن': <gensim.models.keyedvectors.Vocab at 0x155ef88df28>,
#  'بشار': <gensim.models.keyedvectors.Vocab at 0x155ef88df60>,
#  'خلفية': <gensim.models.keyedvectors.Vocab at 0x155ef88df98>,
#  'خلاف': <gensim.models.keyedvectors.Vocab at 0x155ef88dfd0>,
#  'عائلي': <gensim.models.keyedvectors.Vocab at 0x155ef890048>,
#  'قدرية': <gensim.models.keyedvectors.Vocab at 0x155ef890080>,
#  'نجوى': <gensim.models.keyedvectors.Vocab at 0x155ef8900b8>,
#  'خير': <gensim.models.keyedvectors.Vocab at 0x155ef8900f0>,
#  'سنية': <gensim.models.keyedvectors.Vocab at 0x155ef890128>,
#  'اصيبت': <gensim.models.keyedvectors.Vocab at 0x155ef890160>,
#  'نقلت': <gensim.models.keyedvectors.Vocab at 0x155ef890198>,
#  'الزهراء': <gensim.models.keyedvectors.Vocab at 0x155ef8901d0>,
#  'ناجي': <gensim.models.keyedvectors.Vocab at 0x155ef890208>,
#  'راشد': <gensim.models.keyedvectors.Vocab at 0x155ef890240>,
#  'تعاطي': <gensim.models.keyedvectors.Vocab at 0x155ef890278>,
#  'دراجات': <gensim.models.keyedvectors.Vocab at 0x155ef8902b0>,
#  'مسجلة': <gensim.models.keyedvectors.Vocab at 0x155ef8902e8>,
#  'عدة': <gensim.models.keyedvectors.Vocab at 0x155ef890320>,
#  'لا': <gensim.models.keyedvectors.Vocab at 0x155ef890358>,
#  'مسروقة': <gensim.models.keyedvectors.Vocab at 0x155ef890390>,
#  'حسام': <gensim.models.keyedvectors.Vocab at 0x155ef8903c8>,
#  'مكية': <gensim.models.keyedvectors.Vocab at 0x155ef890400>,
#  'ممثلة': <gensim.models.keyedvectors.Vocab at 0x155ef890438>,
#  'المفوض': <gensim.models.keyedvectors.Vocab at 0x155ef890470>,
#  'التوقيع': <gensim.models.keyedvectors.Vocab at 0x155ef8904a8>,
#  'طوني': <gensim.models.keyedvectors.Vocab at 0x155ef8904e0>,
#  'ملك': <gensim.models.keyedvectors.Vocab at 0x155ef890518>,
#  'خلال': <gensim.models.keyedvectors.Vocab at 0x155ef890550>,
#  'الليل': <gensim.models.keyedvectors.Vocab at 0x155ef890588>,
#  'المنصرم': <gensim.models.keyedvectors.Vocab at 0x155ef8905c0>,
#  'سرقت': <gensim.models.keyedvectors.Vocab at 0x155ef8905f8>,
#  'ليل': <gensim.models.keyedvectors.Vocab at 0x155ef890630>,
#  'ينهاي': <gensim.models.keyedvectors.Vocab at 0x155ef890668>,
#  'لوحة': <gensim.models.keyedvectors.Vocab at 0x155ef8906a0>,
#  'افاد': <gensim.models.keyedvectors.Vocab at 0x155ef8906d8>,
#  'رتيب': <gensim.models.keyedvectors.Vocab at 0x155ef890710>,
#  'تواصل': <gensim.models.keyedvectors.Vocab at 0x155ef890748>,
#  'الدكتور': <gensim.models.keyedvectors.Vocab at 0x155ef890780>,
#  'رقي': <gensim.models.keyedvectors.Vocab at 0x155ef8907b8>,
#  'تحضر': <gensim.models.keyedvectors.Vocab at 0x155ef8907f0>,
#  'مركز': <gensim.models.keyedvectors.Vocab at 0x155ef890828>,
#  'بكر': <gensim.models.keyedvectors.Vocab at 0x155ef890860>,
#  'السيوفي': <gensim.models.keyedvectors.Vocab at 0x155ef890898>,
#  'محاولة': <gensim.models.keyedvectors.Vocab at 0x155ef8908d0>,
#  'ايذاء': <gensim.models.keyedvectors.Vocab at 0x155ef890908>,
#  'تراجع': <gensim.models.keyedvectors.Vocab at 0x155ef890940>,
#  'ادعائ': <gensim.models.keyedvectors.Vocab at 0x155ef890978>,
#  'روني': <gensim.models.keyedvectors.Vocab at 0x155ef8909b0>,
#  'هبة': <gensim.models.keyedvectors.Vocab at 0x155ef8909e8>,
#  'الطبش': <gensim.models.keyedvectors.Vocab at 0x155ef890a20>,
#  'حسني': <gensim.models.keyedvectors.Vocab at 0x155ef890a58>,
#  'جوزاف': <gensim.models.keyedvectors.Vocab at 0x155ef890a90>,
#  'عيسى': <gensim.models.keyedvectors.Vocab at 0x155ef890ac8>,
#  'سفر': <gensim.models.keyedvectors.Vocab at 0x155ef890b00>,
#  'باريس': <gensim.models.keyedvectors.Vocab at 0x155ef890b38>,
#  'عائلة': <gensim.models.keyedvectors.Vocab at 0x155ef890b70>,
#  'اوهم': <gensim.models.keyedvectors.Vocab at 0x155ef890ba8>,
#  'السفر': <gensim.models.keyedvectors.Vocab at 0x155ef890be0>,
#  'فرنسا': <gensim.models.keyedvectors.Vocab at 0x155ef890c18>,
#  'رغم': <gensim.models.keyedvectors.Vocab at 0x155ef890c50>,
#  'مطالبة': <gensim.models.keyedvectors.Vocab at 0x155ef890c88>,
#  'اعادة': <gensim.models.keyedvectors.Vocab at 0x155ef890cc0>,
#  'المبلغ': <gensim.models.keyedvectors.Vocab at 0x155ef890cf8>,
#  'يتلقى': <gensim.models.keyedvectors.Vocab at 0x155ef890d30>,
#  'سوى': <gensim.models.keyedvectors.Vocab at 0x155ef890d68>,
#  'المماطلة': <gensim.models.keyedvectors.Vocab at 0x155ef890da0>,
#  'جورج': <gensim.models.keyedvectors.Vocab at 0x155ef890dd8>,
#  'منصور': <gensim.models.keyedvectors.Vocab at 0x155ef890e10>,
#  'سليم': <gensim.models.keyedvectors.Vocab at 0x155ef890e48>,
#  'انتحال': <gensim.models.keyedvectors.Vocab at 0x155ef890e80>,
#  'صفة': <gensim.models.keyedvectors.Vocab at 0x155ef890eb8>,
#  'طرد': <gensim.models.keyedvectors.Vocab at 0x155ef890ef0>,
#  'اولاد': <gensim.models.keyedvectors.Vocab at 0x155ef890f28>,
#  'ربيع': <gensim.models.keyedvectors.Vocab at 0x155ef890f60>,
#  'جلال': <gensim.models.keyedvectors.Vocab at 0x155ef890f98>,
#  'مدير': <gensim.models.keyedvectors.Vocab at 0x155ef890fd0>,
#  'اعطائ': <gensim.models.keyedvectors.Vocab at 0x155ef893048>,
#  'الداعوق': <gensim.models.keyedvectors.Vocab at 0x155ef893080>,
#  'نوال': <gensim.models.keyedvectors.Vocab at 0x155ef8930b8>,
#  'مهى': <gensim.models.keyedvectors.Vocab at 0x155ef8930f0>,
#  'سوزوكي': <gensim.models.keyedvectors.Vocab at 0x155ef893128>,
#  'ناصيف': <gensim.models.keyedvectors.Vocab at 0x155ef893160>,
#  'اسمهان': <gensim.models.keyedvectors.Vocab at 0x155ef893198>,
#  'رئاسة': <gensim.models.keyedvectors.Vocab at 0x155ef8931d0>,
#  'الرقيب': <gensim.models.keyedvectors.Vocab at 0x155ef893208>,
#  'القادري': <gensim.models.keyedvectors.Vocab at 0x155ef893240>,
#  'الت': <gensim.models.keyedvectors.Vocab at 0x155ef893278>,
#  'اسماء': <gensim.models.keyedvectors.Vocab at 0x155ef8932b0>,
#  'مادة': <gensim.models.keyedvectors.Vocab at 0x155ef8932e8>,
#  'حجم': <gensim.models.keyedvectors.Vocab at 0x155ef893320>,
#  'فول': <gensim.models.keyedvectors.Vocab at 0x155ef893358>,
#  'دفتر': <gensim.models.keyedvectors.Vocab at 0x155ef893390>,
#  'لف': <gensim.models.keyedvectors.Vocab at 0x155ef8933c8>,
#  'الكورنيش': <gensim.models.keyedvectors.Vocab at 0x155ef893400>,
#  'البحري': <gensim.models.keyedvectors.Vocab at 0x155ef893438>,
#  'مدينة': <gensim.models.keyedvectors.Vocab at 0x155ef893470>,
#  'سليمان': <gensim.models.keyedvectors.Vocab at 0x155ef8934a8>,
#  'سعاد': <gensim.models.keyedvectors.Vocab at 0x155ef8934e0>,
#  'رندا': <gensim.models.keyedvectors.Vocab at 0x155ef893518>,
#  'خلف': <gensim.models.keyedvectors.Vocab at 0x155ef893550>,
#  'عرابي': <gensim.models.keyedvectors.Vocab at 0x155ef893588>,
#  'دلال': <gensim.models.keyedvectors.Vocab at 0x155ef8935c0>,
#  'الاخيرة': <gensim.models.keyedvectors.Vocab at 0x155ef8935f8>,
#  'اجري': <gensim.models.keyedvectors.Vocab at 0x155ef893630>,
#  'تحقيق': <gensim.models.keyedvectors.Vocab at 0x155ef893668>,
#  'تلاسن': <gensim.models.keyedvectors.Vocab at 0x155ef8936a0>,
#  'ريما': <gensim.models.keyedvectors.Vocab at 0x155ef8936d8>,
#  'ميشال': <gensim.models.keyedvectors.Vocab at 0x155ef893710>,
#  'نعمان': <gensim.models.keyedvectors.Vocab at 0x155ef893748>,
#  'البسطة': <gensim.models.keyedvectors.Vocab at 0x155ef893780>,
#  'وجد': <gensim.models.keyedvectors.Vocab at 0x155ef8937b8>,
#  'الفول': <gensim.models.keyedvectors.Vocab at 0x155ef8937f0>,
#  'ايلي': <gensim.models.keyedvectors.Vocab at 0x155ef893828>,
#  'مراد': <gensim.models.keyedvectors.Vocab at 0x155ef893860>,
#  'سيم': <gensim.models.keyedvectors.Vocab at 0x155ef893898>,
#  'غندور': <gensim.models.keyedvectors.Vocab at 0x155ef8938d0>,
#  'سلامة': <gensim.models.keyedvectors.Vocab at 0x155ef893908>,
#  'الشخصية': <gensim.models.keyedvectors.Vocab at 0x155ef893940>,
#  'متوعدا': <gensim.models.keyedvectors.Vocab at 0x155ef893978>,
#  'ايا': <gensim.models.keyedvectors.Vocab at 0x155ef8939b0>,
#  'الايذاء': <gensim.models.keyedvectors.Vocab at 0x155ef8939e8>,
#  'اخت': <gensim.models.keyedvectors.Vocab at 0x155ef893a20>,
#  'الشتائم': <gensim.models.keyedvectors.Vocab at 0x155ef893a58>,
#  'هاتفي': <gensim.models.keyedvectors.Vocab at 0x155ef893a90>,
#  'يظهر': <gensim.models.keyedvectors.Vocab at 0x155ef893ac8>,
#  'المتصل': <gensim.models.keyedvectors.Vocab at 0x155ef893b00>,
#  'عرف': <gensim.models.keyedvectors.Vocab at 0x155ef893b38>,
#  'كاظم': <gensim.models.keyedvectors.Vocab at 0x155ef893b70>,
#  'هذا': <gensim.models.keyedvectors.Vocab at 0x155ef893ba8>,
#  'التهديد': <gensim.models.keyedvectors.Vocab at 0x155ef893be0>,
#  'بل': <gensim.models.keyedvectors.Vocab at 0x155ef893c18>,
#  'ظروف': <gensim.models.keyedvectors.Vocab at 0x155ef893c50>,
#  'كرامة': <gensim.models.keyedvectors.Vocab at 0x155ef893c88>,
#  'برج': <gensim.models.keyedvectors.Vocab at 0x155ef893cc0>,
#  'سابق': <gensim.models.keyedvectors.Vocab at 0x155ef893cf8>,
#  'فراس': <gensim.models.keyedvectors.Vocab at 0x155ef893d30>,
#  'زين': <gensim.models.keyedvectors.Vocab at 0x155ef893d68>,
#  'بيجو': <gensim.models.keyedvectors.Vocab at 0x155ef893da0>,
#  'العاملة': <gensim.models.keyedvectors.Vocab at 0x155ef893dd8>,
#  'الخدمة': <gensim.models.keyedvectors.Vocab at 0x155ef893e10>,
#  'المنزلية': <gensim.models.keyedvectors.Vocab at 0x155ef893e48>,
#  'نوري': <gensim.models.keyedvectors.Vocab at 0x155ef893e80>,
#  'فيليبينية': <gensim.models.keyedvectors.Vocab at 0x155ef893eb8>,
#  'حائط': <gensim.models.keyedvectors.Vocab at 0x155ef893ef0>,
#  'نفق': <gensim.models.keyedvectors.Vocab at 0x155ef893f28>,
#  'فينيسيا': <gensim.models.keyedvectors.Vocab at 0x155ef893f60>,
#  'انقلبت': <gensim.models.keyedvectors.Vocab at 0x155ef893f98>,
#  'سقف': <gensim.models.keyedvectors.Vocab at 0x155ef893fd0>,
#  'تولى': <gensim.models.keyedvectors.Vocab at 0x155ef897048>,
#  'فندق': <gensim.models.keyedvectors.Vocab at 0x155ef897080>,
#  'البريستول': <gensim.models.keyedvectors.Vocab at 0x155ef8970b8>,
#  'ثلاثماية': <gensim.models.keyedvectors.Vocab at 0x155ef8970f0>,
#  'الف': <gensim.models.keyedvectors.Vocab at 0x155ef897128>,
#  'ليرة': <gensim.models.keyedvectors.Vocab at 0x155ef897160>,
#  'محفظة': <gensim.models.keyedvectors.Vocab at 0x155ef897198>,
#  'سكنة': <gensim.models.keyedvectors.Vocab at 0x155ef8971d0>,
#  'يقوم': <gensim.models.keyedvectors.Vocab at 0x155ef897208>,
#  'الغد': <gensim.models.keyedvectors.Vocab at 0x155ef897240>,
#  'الحضور': <gensim.models.keyedvectors.Vocab at 0x155ef897278>,
#  'وطى': <gensim.models.keyedvectors.Vocab at 0x155ef8972b0>,
#  'البستاني': <gensim.models.keyedvectors.Vocab at 0x155ef8972e8>,
#  'عليا': <gensim.models.keyedvectors.Vocab at 0x155ef897320>,
#  'امينة': <gensim.models.keyedvectors.Vocab at 0x155ef897358>,
#  'الصدم': <gensim.models.keyedvectors.Vocab at 0x155ef897390>,
#  'فواز': <gensim.models.keyedvectors.Vocab at 0x155ef8973c8>,
#  'نورا': <gensim.models.keyedvectors.Vocab at 0x155ef897400>,
#  'طوارئ': <gensim.models.keyedvectors.Vocab at 0x155ef897438>,
#  'كسور': <gensim.models.keyedvectors.Vocab at 0x155ef897470>,
#  'جروح': <gensim.models.keyedvectors.Vocab at 0x155ef8974a8>,
#  'الطويل': <gensim.models.keyedvectors.Vocab at 0x155ef8974e0>,
#  'صغير': <gensim.models.keyedvectors.Vocab at 0x155ef897518>,
#  'المواصفاة': <gensim.models.keyedvectors.Vocab at 0x155ef897550>,
#  'سامسونغ': <gensim.models.keyedvectors.Vocab at 0x155ef897588>,
#  'نوت': <gensim.models.keyedvectors.Vocab at 0x155ef8975c0>,
#  'جي': <gensim.models.keyedvectors.Vocab at 0x155ef8975f8>,
#  'ام': <gensim.models.keyedvectors.Vocab at 0x155ef897630>,
#  'سي': <gensim.models.keyedvectors.Vocab at 0x155ef897668>,
#  'المسلك': <gensim.models.keyedvectors.Vocab at 0x155ef8976a0>,
#  'المؤدي': <gensim.models.keyedvectors.Vocab at 0x155ef8976d8>,
#  'مستديرة': <gensim.models.keyedvectors.Vocab at 0x155ef897710>,
#  'الحمرا': <gensim.models.keyedvectors.Vocab at 0x155ef897748>,
#  'صلاح': <gensim.models.keyedvectors.Vocab at 0x155ef897780>,
#  'الايوبي': <gensim.models.keyedvectors.Vocab at 0x155ef8977b8>,
#  'تاهيتي': <gensim.models.keyedvectors.Vocab at 0x155ef8977f0>,
#  'الموصفات': <gensim.models.keyedvectors.Vocab at 0x155ef897828>,
#  'عزالدين': <gensim.models.keyedvectors.Vocab at 0x155ef897860>,
#  'هيام': <gensim.models.keyedvectors.Vocab at 0x155ef897898>,
#  'سورية': <gensim.models.keyedvectors.Vocab at 0x155ef8978d0>,
#  'بداخل': <gensim.models.keyedvectors.Vocab at 0x155ef897908>,
#  'عشرة': <gensim.models.keyedvectors.Vocab at 0x155ef897940>,
#  'الاف': <gensim.models.keyedvectors.Vocab at 0x155ef897978>,
#  'خليوي': <gensim.models.keyedvectors.Vocab at 0x155ef8979b0>,
#  'تجهل': <gensim.models.keyedvectors.Vocab at 0x155ef8979e8>,
#  'مرور': <gensim.models.keyedvectors.Vocab at 0x155ef897a20>,
#  'سيرا': <gensim.models.keyedvectors.Vocab at 0x155ef897a58>,
#  'الاقدام': <gensim.models.keyedvectors.Vocab at 0x155ef897a90>,
#  ...}

# %%
from itertools import islice
list(islice(word2vec_vectors.wv.vocab, 130, 150))
# Out:
# ['صدم',
#  'قبل',
#  'مازدا',
#  'فضي',
#  'ج',
#  'حياة',
#  'الرحمن',
#  'القيسي',
#  'نتج',
#  'عن',
#  'اصابة',
#  'شعر',
#  'كتف',
#  'الايسر',
#  'ادخل',
#  'طراد',
#  'المعاجة',
#  'المحضر',
#  'تعرضت',
#  'اميرة']
