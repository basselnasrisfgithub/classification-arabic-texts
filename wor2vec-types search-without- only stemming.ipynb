# %%
import math

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#start arabic test
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.stem.porter import *
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
import codecs
import sys

# %%
import os
from nltk.parse import stanford as SParse
from nltk.tag import stanford as STag
from nltk.tokenize import StanfordSegmenter

from polyglot.text import Text
from rake_nltk import Rake

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

os.environ['STANFORD_MODELS'] = 'stanford-segmenter-2018-10-16/data/;stanford-postagger-full-2018-10-16/models/'
os.environ['STANFORD_PARSER'] = 'stanford-parser-full-2018-10-17'
os.environ['CLASSPATH'] = 'stanford-parser-full-2018-10-17'
os.environ['JAVAHOME'] = 'C:/Program Files/Java/jdk1.8.0_60'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Maya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#readind and preparing data ( text , label )
data=pd.read_excel('ML1.xlsx', header=None) ## read le file
data.columns=['label','text']
print(data[2:3])
# Out:
#    label                                               text
# 2      4  محضر تحقيق بحق المدعو ماهر صالح الحرامي سوري ل...

# %%
import nltk 
nltk.download('stopwords') 
from nltk.corpus import stopwords
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9ا-ي #+_]')
STOPWORDS = set(stopwords.words('arabic'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing. 
    text = text.replace('x', '')
#    text = re.sub(r'\W+', '', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    return text
data['text'] =data['text'].apply(clean_text)
data['text'] =data['text'].str.replace('\d+', '')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Maya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
subData = data['text']
#subData = subData[1:10]
singleTextWithPips = '|'.join(subData)
#print(singleTextWithPips)
f = open("samplePips.txt", "w",  encoding='utf-8')
f.write(singleTextWithPips)
f.close()

# %%
segmenter = StanfordSegmenter('stanford-segmenter-2018-10-16/stanford-segmenter-3.9.2.jar')
segmenter.default_config('ar')
textseg = segmenter.segment_file('samplePips.txt')
print(textseg[1:20])
# Out:
# C:\Users\Maya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.parse.corenlp.CoreNLPTokenizer instead.'
#   """Entry point for launching an IPython kernel.
# حضر تحقيق ب حق المد

# %%
texts=textseg.split('|')
print(texts[1:3])
# Out:
# [' محضر تحقيق ب ادعا المدعوة اسما هدى انيس قساطلي لبنانية ب حق مجهول ب موضوع فقدان محفظة تحتوي بطاقة هوية و مبلغ مالي ', ' محضر تحقيق ب حق المدعو ماهر صالح الحرامي سوري ل حيازة ه هوية ب اسم يوسف فتين الحرامي سوري و ترك ه سند اقامة ب الاضافة الى المدعو يوسف المذكور ب جرم تبادل الاوراق الثبوتية بين هما ']

# %% [markdown]
# from nltk.stem import ISRIStemmer
# st=ISRIStemmer()
# sw=STOPWORDS
# collection_new=[]
# for  doc in texts:
#     new_doc=[]
#     for i in doc.split():
#         if not i in sw:
#             i=st.stem(i)
#             i=''.join(i)
#             new_doc.append(i)
#     collection_new.append(new_doc)
# collection=collection_new

# %% [markdown]
# collection=texts
# print(collection[1])

# %% [markdown]
# import re
# print(collection[1])
# for i in range(len(collection)):
#     collection[i] = re.sub(r'\d+', '', str(collection[i]))
# print(collection[1])

# %% [markdown]
# table=str.maketrans("+=_-<>~/!*%?:;,)&1234567890@$qwertyuioplkjhgfdsamnbvcxz(QWERTYUIOPLKJHGFDSAZXCVBNM",82*" ")
# for i in range(len(collection)):
#     collection[i] = collection[i].translate(table)
# print(collection[1])

# %%
#import os, sys
#import pandas as pd
#import numpy as np
#from sklearn.metrics.pairwise import cosine_similarity
#from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.model_selection import train_test_split
#from sklearn.naive_bayes import BernoulliNB
#from sklearn.ensemble import RandomForestClassifier
##from sklearn.metrics import roc_curve, auc
#from sklearn import svm
#from sklearn.metrics import classification_report, confusion_matrix
#from sklearn.model_selection import GridSearchCV
from gensim.models import KeyedVectors
#from scipy import spatial
#import matplotlib.pyplot as plt
#from sklearn.neural_network import MLPClassifier
from nltk import bigrams
import nltk
import re
#import spacy
###FUNCTIONS
def avg_feature_vector(sentence, model, num_features, index2word_set):
        words = sentence.split()
        feature_vec = np.zeros((num_features, ), dtype='float32')
        n_words = 0
        for word in words:
            if word in index2word_set:
                n_words += 1
                feature_vec = np.add(feature_vec, model[word])
        if (n_words > 0):
            feature_vec = np.divide(feature_vec, n_words)
        return feature_vec

def convert_word2vec(sentences,num_features):
        vectors_matrix = np.zeros((len(sentences),num_features))
        i = 0
        for sent in sentences:
            temp = avg_feature_vector(sent,word2vec_vectors,num_features,index2word_set)
            vectors_matrix[i,:] = temp
            i = i+1
        return vectors_matrix
def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    #txt = [token for token in doc ]
    words=str(doc).strip().split()
    #words=[st.stem(w) for w in words ]
    return ' '.join(words)
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    #if len(txt) > 2:
      #return ' '.join(txt)
#from gensim.models.phrases import Phrases, Phraser
#data=pd.read_excel('ml2.xlsx', header=None) ## read le file
#data.columns=['text','label']
#def prep(doc):
 #   words=str(doc).strip().split()
  #  return ' '.join(words)
#Xt=Xt.apply(prep)
#sentences = Xt
data=texts
#data = data[data['Semantic_Type']!='DISREGARD']
#from gensim.models.phrases import Phrases, Phraser
#from nltk.stem import ISRIStemmer
#st=ISRIStemmer()
brief_cleaning = (re.sub("[^ا-ي']+", ' ', str(row)).lower() for row in data)
txt = [cleaning(doc) for doc in data]
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
sent = [row.split() for row in df_clean['clean']]
sentences = sent
print(sentences[1])
from gensim.models import Word2Vec
word2vec_vectors = Word2Vec(min_count=2,window=5,size=200,sample=6e-5,alpha=0.03,min_alpha=0.0007,negative=20)
word2vec_vectors.build_vocab(sentences)
word2vec_vectors.train(sentences, total_examples=word2vec_vectors.corpus_count, epochs=30, report_delay=1)
word2vec_vectors.init_sims(replace=True)
index2word_set = set(word2vec_vectors.wv.index2word)
###vectorizing the sentences
#vectors_matrix = convert_word2vec(data['Sentence'],200)
#np.random.seed(10)
#labels=data['label']
#train,test,ltrain,ltest =train_test_split(vectors_matrix, labels,test_size=0.2)#,random_state=8)
# Out:
# ['محضر', 'تحقيق', 'ب', 'ادعا', 'المدعوة', 'اسما', 'هدى', 'انيس', 'قساطلي', 'لبنانية', 'ب', 'حق', 'مجهول', 'ب', 'موضوع', 'فقدان', 'محفظة', 'تحتوي', 'بطاقة', 'هوية', 'و', 'مبلغ', 'مالي']
# C:\Users\Maya\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "

# %%
def clean_str(text):
    search = ["أ","إ","آ","ة","_","-","/",".","،"," و "," يا ",'"',"ـ","'","ى","\\",'\n', '\t','&quot;','?','؟','!']
    replace = ["ا","ا","ا","ه"," "," ","","",""," و"," يا","","","","ي","",' ', ' ',' ',' ? ',' ؟ ',' ! ']
    
    #remove tashkeel
    p_tashkeel = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    text = re.sub(p_tashkeel,"", text)
    
    #remove longation
    p_longation = re.compile(r'(.)\1+')
    subst = r"\1\1"
    text = re.sub(p_longation, subst, text)
    
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    
    for i in range(0, len(search)):
        text = text.replace(search[i], replace[i])
    
    #trim    
    text = text.strip()

    return text
def get_vec(n_model,dim, token):
    vec = np.zeros(dim)
    is_vec = False
    if token not in n_model.wv:
        _count = 0
        is_vec = True
        for w in token.split("_"):
            if w in n_model.wv:
                _count += 1
                vec += n_model.wv[w]
        if _count > 0:
            vec = vec / _count
    else:
        vec = n_model.wv[token]
    return vec

def calc_vec(pos_tokens, neg_tokens, n_model, dim):
    vec = np.zeros(dim)
    for p in pos_tokens:
        vec += get_vec(n_model,dim,p)
    for n in neg_tokens:
        vec -= get_vec(n_model,dim,n)
    
    return vec

# %%
t_model = word2vec_vectors
pos_tokens=[ clean_str(t.strip()).replace(" ", "_") for t in ['خالد عسكر', 'مخدرات'] if t.strip() != ""]
neg_tokens=[ clean_str(t.strip()).replace(" ", "_") for t in ['سوري'] if t.strip() != ""]

vec = calc_vec(pos_tokens=pos_tokens, neg_tokens=neg_tokens, n_model=t_model, dim=t_model.vector_size)

most_sims = t_model.wv.similar_by_vector(vec, topn=10)
for term, score in most_sims:
    if term not in pos_tokens+neg_tokens:
        print(term, score)
# Out:
# جرن 0.9983263611793518
# جيراني 0.9983227252960205
# الضيقة 0.9982736706733704
# فقيه 0.9982253313064575
# الموسوي 0.998197078704834
# مخالفات 0.9981967806816101
# الدامة 0.998173713684082
# مخردات 0.9981735348701477
# تمساح 0.9981616735458374
# السكين 0.9981446266174316

# %%
 word2vec_vectors.wv.vocab
# Out:
# {'محضر': <gensim.models.keyedvectors.Vocab at 0x1fa3914a898>,
#  'تحقيق': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4198>,
#  'ب': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4080>,
#  'حق': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4048>,
#  'المدعو': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4278>,
#  'محمود': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e42b0>,
#  'مبارك': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e42e8>,
#  'سوري': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4320>,
#  'جرم': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4358>,
#  'اقامة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4390>,
#  'مشروعة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e43c8>,
#  'و': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4400>,
#  'توقيف': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4438>,
#  'ه': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4470>,
#  'ادعا': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e44a8>,
#  'المدعوة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e44e0>,
#  'هدى': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4518>,
#  'انيس': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4550>,
#  'لبنانية': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4588>,
#  'مجهول': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e45c0>,
#  'موضوع': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e45f8>,
#  'فقدان': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4630>,
#  'محفظة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4668>,
#  'تحتوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e46a0>,
#  'بطاقة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e46d8>,
#  'هوية': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4710>,
#  'مبلغ': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4748>,
#  'مالي': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4780>,
#  'ماهر': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e47b8>,
#  'صالح': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e47f0>,
#  'الحرامي': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4828>,
#  'ل': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4860>,
#  'حيازة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4898>,
#  'اسم': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e48d0>,
#  'يوسف': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4908>,
#  'فتين': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4940>,
#  'ترك': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4978>,
#  'سند': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e49b0>,
#  'الاضافة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e49e8>,
#  'الى': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4a20>,
#  'المذكور': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4a58>,
#  'الاوراق': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4a90>,
#  'الثبوتية': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4ac8>,
#  'بين': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4b00>,
#  'هما': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4b38>,
#  'تنفيذ': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4b70>,
#  'خلاصة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4ba8>,
#  'حكم': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4be0>,
#  'محمد': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4c18>,
#  'سعد': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4c50>,
#  'الدين': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4c88>,
#  'الصعيدي': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4cc0>,
#  'لبناني': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4cf8>,
#  'اسلحة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4d30>,
#  'كف': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4d68>,
#  'البحث': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4da0>,
#  'عن': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4dd8>,
#  'قرار': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4e10>,
#  'جزاي': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4e48>,
#  'مخالفة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4e80>,
#  'انظمة': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4eb8>,
#  'السير': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4ef0>,
#  'شطب': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4f28>,
#  'الدليل': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4f60>,
#  'عامر': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4f98>,
#  'اسعد': <gensim.models.keyedvectors.Vocab at 0x1fa3a4e4fd0>,
#  'المولى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2048>,
#  'شجار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2080>,
#  'حرا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b20b8>,
#  'القاضي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b20f0>,
#  'المنفرد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2128>,
#  'الجزاي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2160>,
#  'جبل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2198>,
#  'لبنان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b21d0>,
#  'البحق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2208>,
#  'طرابلس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2240>,
#  'طلال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2278>,
#  'صادق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b22b0>,
#  'محكمة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b22e8>,
#  'جزا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2320>,
#  'صيدا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2358>,
#  'رامي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2390>,
#  'سكر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b23c8>,
#  'ظاهر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2400>,
#  'بعلبك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2438>,
#  'عباس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2470>,
#  'محي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b24a8>,
#  'موسوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b24e0>,
#  'تعرض': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2518>,
#  'الاداب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2550>,
#  'العامة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2588>,
#  'الادعا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b25c0>,
#  'الفوري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b25f8>,
#  'المدعية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2630>,
#  'حول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2668>,
#  'اوراق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b26a0>,
#  'ثبوتية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b26d8>,
#  'تلف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2710>,
#  'دراجة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2748>,
#  'نارية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2780>,
#  'نوع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b27b8>,
#  'رقم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b27f0>,
#  'هيكل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2828>,
#  'ها': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2860>,
#  'صرف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2898>,
#  'النظر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b28d0>,
#  'احضار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2908>,
#  'الاكتفا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2940>,
#  'المحاضر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2978>,
#  'الادارية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b29b0>,
#  'السوري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b29e8>,
#  'عبد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2a20>,
#  'احمد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2a58>,
#  'الحسين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2a90>,
#  'رهن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2ac8>,
#  'التحقيق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2b00>,
#  'كفالة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2b38>,
#  'حازم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2b70>,
#  'شوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2ba8>,
#  'المخالفات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2be0>,
#  'بيروت': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2c18>,
#  'حسن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2c50>,
#  'رحال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2c88>,
#  'عدم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2cc0>,
#  'نقل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2cf8>,
#  'التنفيذ': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2d30>,
#  'رشيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2d68>,
#  'بو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2da0>,
#  'كرم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2dd8>,
#  'ضد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2e10>,
#  'قدح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2e48>,
#  'بيان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2e80>,
#  'كامل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2eb8>,
#  'المدعى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2ef0>,
#  'النبطية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2f28>,
#  'خالد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2f60>,
#  'عودة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2f98>,
#  'الشكوى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b2fd0>,
#  'المقدمة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6048>,
#  'مالك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6080>,
#  'المصري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b60b8>,
#  'وكيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b60f0>,
#  'المحامي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6128>,
#  'عدنان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6160>,
#  'الشعار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6198>,
#  'على': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b61d0>,
#  'كريم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6208>,
#  'عز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6240>,
#  'لبنانيان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6278>,
#  'شك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b62b0>,
#  'رصيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b62e8>,
#  'سامي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6320>,
#  'الجنسية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6358>,
#  'اجهزة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6390>,
#  'داخل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b63c8>,
#  'سيارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6400>,
#  'اجرة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6438>,
#  'فوري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6470>,
#  'رنا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b64a8>,
#  'وهبي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b64e0>,
#  'ذم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6518>,
#  'زهر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6550>,
#  'علي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6588>,
#  'حمز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b65c0>,
#  'مجهولان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b65f8>,
#  'محاولة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6630>,
#  'نشل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6668>,
#  'متن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b66a0>,
#  'فرح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b66d8>,
#  'فارس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6710>,
#  'تعاطي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6748>,
#  'مخدرات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6780>,
#  'عماد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b67b8>,
#  'حمود': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b67f0>,
#  'حبوب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6828>,
#  'مخدرة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6860>,
#  'امام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6898>,
#  'مدخل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b68d0>,
#  'قصر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6908>,
#  'عدل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6940>,
#  'ضبط': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6978>,
#  'سكين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b69b0>,
#  'حوزة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b69e8>,
#  'السكين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6a20>,
#  'تسليم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6a58>,
#  'نا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6a90>,
#  'غسان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6ac8>,
#  'الخوري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6b00>,
#  'طلقات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6b38>,
#  'عيار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6b70>,
#  'ملم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6ba8>,
#  'المدعي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6be0>,
#  'طارق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6c18>,
#  'ابراهيم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6c50>,
#  'دياب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6c88>,
#  'بوكالة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6cc0>,
#  'عيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6cf8>,
#  'شهاب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6d30>,
#  'زياد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6d68>,
#  'كلش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6da0>,
#  'احتيال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6dd8>,
#  'اساة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6e10>,
#  'امانة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6e48>,
#  'اشكوى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6e80>,
#  'جورج': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6eb8>,
#  'الريس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6ef0>,
#  'استعمال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6f28>,
#  'لوحة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6f60>,
#  'استدعا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6f98>,
#  'شربل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b6fd0>,
#  'ناجي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9048>,
#  'جرجس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9080>,
#  'المر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b90b8>,
#  'رسمية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b90f0>,
#  'محلة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9128>,
#  'العدلية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9160>,
#  'الياس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9198>,
#  'السوديكو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b91d0>,
#  'وليم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9208>,
#  'شادي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9240>,
#  'ابو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9278>,
#  'عجرم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b92b0>,
#  'السورية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b92e8>,
#  'حجز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9320>,
#  'السيارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9358>,
#  'عدليا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9390>,
#  'اداريا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b93c8>,
#  'المضبوطات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9400>,
#  'المدعوين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9438>,
#  'مصباح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9470>,
#  'عثمان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b94a8>,
#  'انطونيوس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b94e0>,
#  'جرن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9518>,
#  'الجندي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9550>,
#  'المخدرات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9588>,
#  'المضبوط': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b95c0>,
#  'الظريف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b95f8>,
#  'جنح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9630>,
#  'احداث': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9668>,
#  'منصور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b96a0>,
#  'استناف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b96d8>,
#  'علا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9710>,
#  'مشيك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9748>,
#  'الشمال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9780>,
#  'الصالح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b97b8>,
#  'منتهية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b97f0>,
#  'تسوية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9828>,
#  'وضع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9860>,
#  'الكفيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9898>,
#  'المحامية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b98d0>,
#  'امين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9908>,
#  'مصري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9940>,
#  'مروان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9978>,
#  'طربيه': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b99b0>,
#  'التهجم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b99e8>,
#  'القضاة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9a20>,
#  'نحقيق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9a58>,
#  'عميرات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9a90>,
#  'غاية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9ac8>,
#  'الساعة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9b00>,
#  'تاريخ': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9b38>,
#  'بعد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9b70>,
#  'سنو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9ba8>,
#  'المفتش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9be0>,
#  'الاول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9c18>,
#  'الامن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9c50>,
#  'العام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9c88>,
#  'سرقة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9cc0>,
#  'النارية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9cf8>,
#  'قبل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9d30>,
#  'بلال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9d68>,
#  'مدني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9da0>,
#  'الرزاق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9dd8>,
#  'المحمد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9e10>,
#  'حضور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9e48>,
#  'والد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9e80>,
#  'حسين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9eb8>,
#  'التعميم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9ef0>,
#  'ضر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9f28>,
#  'الرقيب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9f60>,
#  'بسام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9f98>,
#  'فخر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9b9fd0>,
#  'اقدام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc048>,
#  'الغير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc080>,
#  'مسجلة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc0b8>,
#  'لقا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc0f0>,
#  'سعاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc128>,
#  'نصر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc160>,
#  'بدارو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc198>,
#  'لطفي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc1d0>,
#  'مستندات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc208>,
#  'مسدس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc240>,
#  'خلبي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc278>,
#  'ترخيص': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc2b0>,
#  'المسدس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc2e8>,
#  'سهيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc320>,
#  'سليم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc358>,
#  'نصار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc390>,
#  'هاتف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc3c8>,
#  'خليوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc400>,
#  'الوهاب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc438>,
#  'الدرزي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc470>,
#  'قيادة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc4a8>,
#  'انقاض': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc4e0>,
#  'اللوحة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc518>,
#  'م': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc550>,
#  'مغايرة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc588>,
#  'حشيشة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc5c0>,
#  'حيدر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc5f8>,
#  'قاصر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc630>,
#  'الكيف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc668>,
#  'حلبا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc6a0>,
#  'شركة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc6d8>,
#  'السيارات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc710>,
#  'زعيتر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc748>,
#  'رخصة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc780>,
#  'مركبة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc7b8>,
#  'هنادي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc7f0>,
#  'اجازة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc828>,
#  'عمل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc860>,
#  'الاثيوبية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc898>,
#  'عطي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc8d0>,
#  'الحنان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc908>,
#  'الدرجه': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc940>,
#  'قطعة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc978>,
#  'مزورة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc9b0>,
#  'دولار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bc9e8>,
#  'الحاج': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bca20>,
#  'ناصر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bca58>,
#  'كلاس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bca90>,
#  'دينا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcac8>,
#  'الجيش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcb00>,
#  'اللبنانية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcb38>,
#  'خليل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcb70>,
#  'صلح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcba8>,
#  'شهادة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcbe0>,
#  'المقدم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcc18>,
#  'سامر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcc50>,
#  'الحسامي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcc88>,
#  'مريم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bccc0>,
#  'الرحمن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bccf8>,
#  'لينا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcd30>,
#  'دعبول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcd68>,
#  'قصقص': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcda0>,
#  'البيضا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcdd8>,
#  'سن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bce10>,
#  'سورية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bce48>,
#  'باسيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bce80>,
#  'خوري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bceb8>,
#  'زينب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcef0>,
#  'مخالفات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcf28>,
#  'صبحي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcf60>,
#  'غدارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcf98>,
#  'اقلاق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bcfd0>,
#  'راحة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf048>,
#  'جنايات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf080>,
#  'عصام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf0b8>,
#  'فهمي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf0f0>,
#  'منهية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf128>,
#  'الصلاحية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf160>,
#  'سوداني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf198>,
#  'الخلف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf1d0>,
#  'تراجع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf208>,
#  'العثور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf240>,
#  'جمال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf278>,
#  'حسب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf2b0>,
#  'اقوال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf2e8>,
#  'سعيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf320>,
#  'ايهاب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf358>,
#  'سيجارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf390>,
#  'ملفوفة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf3c8>,
#  'يعتقد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf400>,
#  'ان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf438>,
#  'مادة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf470>,
#  'المحكمة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf4a8>,
#  'العسكرية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf4e0>,
#  'الدامة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf518>,
#  'اسماعيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf550>,
#  'نعمان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf588>,
#  'اطلاق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf5c0>,
#  'نار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf5f8>,
#  'سلاح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf630>,
#  'حربي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf668>,
#  'تبين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf6a0>,
#  'الخلاصة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf6d8>,
#  'يحق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf710>,
#  'سليمان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf748>,
#  'فضل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf780>,
#  'الله': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf7b8>,
#  'طالب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf7f0>,
#  'الدرجة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf828>,
#  'الثانية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf860>,
#  'سير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf898>,
#  'عمر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf8d0>,
#  'وليد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf908>,
#  'البنا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf940>,
#  'الروف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf978>,
#  'فنيش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf9b0>,
#  'ز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bf9e8>,
#  'الحشيشة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfa20>,
#  'المخدرة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfa58>,
#  'سرعة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfa90>,
#  'زادة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfac8>,
#  'الخالد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfb00>,
#  'حنان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfb38>,
#  'يونس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfb70>,
#  'غزاوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfba8>,
#  'سيم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfbe0>,
#  'النتيجة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfc18>,
#  'سلبية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfc50>,
#  'البطاقة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfc88>,
#  'غندور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfcc0>,
#  'رتبا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfcf8>,
#  'قوى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfd30>,
#  'الداخلي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfd68>,
#  'مهيدي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfda0>,
#  'الجماله': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfdd8>,
#  'البنغلادشية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfe10>,
#  'زحلة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfe48>,
#  'ديب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfe80>,
#  'ميرنا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfeb8>,
#  'روبير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bfef0>,
#  'اجرا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bff28>,
#  'دفع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bff60>,
#  'اشارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bff98>,
#  'القضا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9bffd0>,
#  'فراس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4048>,
#  'مواليد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4080>,
#  'واسطة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c40b8>,
#  'مكتب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c40f0>,
#  'مكافحة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4128>,
#  'المركزي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4160>,
#  'ليال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4198>,
#  'حماده': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c41d0>,
#  'المهل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4208>,
#  'مهدي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4240>,
#  'ظنيط': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4278>,
#  'استيلا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c42b0>,
#  'لون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c42e8>,
#  'الهيكل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4320>,
#  'كون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4358>,
#  'تم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4390>,
#  'سار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c43c8>,
#  'رباح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4400>,
#  'تسديد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4438>,
#  'الغرامة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4470>,
#  'نزهة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c44a8>,
#  'طبارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c44e0>,
#  'شقيق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4518>,
#  'نبيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4550>,
#  'ضرب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4588>,
#  'ايذا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c45c0>,
#  'شكوى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c45f8>,
#  'مقدمة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4630>,
#  'نقابة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4668>,
#  'رنده': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c46a0>,
#  'اسبر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c46d8>,
#  'هاشم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4710>,
#  'نديم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4748>,
#  'مخايل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4780>,
#  'كلاب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c47b8>,
#  'مونة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c47f0>,
#  'جعار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4828>,
#  'اردني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4860>,
#  'صقر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4898>,
#  'دخول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c48d0>,
#  'البلاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4908>,
#  'خلسة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4940>,
#  'السيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4978>,
#  'الغني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c49b0>,
#  'فلسطيني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c49e8>,
#  'راس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4a20>,
#  'النبع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4a58>,
#  'قبيسي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4a90>,
#  'ايلي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4ac8>,
#  'بطرس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4b00>,
#  'اللبناني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4b38>,
#  'رفع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4b70>,
#  'فواز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4ba8>,
#  'الجاسم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4be0>,
#  'تسبب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4c18>,
#  'برلا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4c50>,
#  'الحلو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4c88>,
#  'تبسيط': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4cc0>,
#  'الزعبي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4cf8>,
#  'الموسوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4d30>,
#  'خالفة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4d68>,
#  'ابقا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4da0>,
#  'البلاغ': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4dd8>,
#  'ساري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4e10>,
#  'المفعول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4e48>,
#  'الشخص': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4e80>,
#  'المطلوب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4eb8>,
#  'لدي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4ef0>,
#  'فاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4f28>,
#  'بركات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4f60>,
#  'السرقة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4f98>,
#  'الاستدعا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c4fd0>,
#  'المستدعي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7048>,
#  'سلامة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7080>,
#  'حسان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c70b8>,
#  'الخطيب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c70f0>,
#  'سوق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7128>,
#  'رس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7160>,
#  'نجيب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7198>,
#  'اللحام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c71d0>,
#  'رمضان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7208>,
#  'اموال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7240>,
#  'تهديد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7278>,
#  'الايذا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c72b0>,
#  'مقابلة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c72e8>,
#  'الدعى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7320>,
#  'ختم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7358>,
#  'المحضر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7390>,
#  'فايز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c73c8>,
#  'العلي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7400>,
#  'منيمن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7438>,
#  'هادي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7470>,
#  'العميم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c74a8>,
#  'البقيلي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c74e0>,
#  'المقصود': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7518>,
#  'توفر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7550>,
#  'معلومات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7588>,
#  'المعاون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c75c0>,
#  'ربيع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c75f8>,
#  'نتيجة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7630>,
#  'ترم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7668>,
#  'عطايا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c76a0>,
#  'مصطفى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c76d8>,
#  'سندي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7710>,
#  'ايمن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7748>,
#  'الحويك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7780>,
#  'العاملة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c77b8>,
#  'شاهين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c77f0>,
#  'رمزي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7828>,
#  'عياش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7860>,
#  'سماح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7898>,
#  'داوود': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c78d0>,
#  'مقاومة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7908>,
#  'رجال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7940>,
#  'السلطة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7978>,
#  'بلاغ': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c79b0>,
#  'رستم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c79e8>,
#  'مهران': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7a20>,
#  'ريما': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7a58>,
#  'حاتم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7a90>,
#  'الشدة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7ac8>,
#  'موجب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7b00>,
#  'افرام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7b38>,
#  'المصرية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7b70>,
#  'المجيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7ba8>,
#  'جوزيف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7be0>,
#  'اميل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7c18>,
#  'الاهانة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7c50>,
#  'ناتالي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7c88>,
#  'ضاهر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7cc0>,
#  'دانيا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7cf8>,
#  'شمص': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7d30>,
#  'داني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7d68>,
#  'الحق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7da0>,
#  'القوة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7dd8>,
#  'خاصة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7e10>,
#  'حمد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7e48>,
#  'يقود': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7e80>,
#  'ترمس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7eb8>,
#  'مولى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7ef0>,
#  'منزل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7f28>,
#  'الكسر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7f60>,
#  'الخلع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7f98>,
#  'تحمل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9c7fd0>,
#  'حنا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca048>,
#  'كاذبة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca080>,
#  'ناهض': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca0b8>,
#  'مطر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca0f0>,
#  'غروب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca128>,
#  'ممثلة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca160>,
#  'عطا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca198>,
#  'الاخبار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca1d0>,
#  'القادر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca208>,
#  'تشهير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca240>,
#  'مضمون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca278>,
#  'امل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca2b0>,
#  'رامز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca2e8>,
#  'الاشرفية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca320>,
#  'الزين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca358>,
#  'ميسا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca390>,
#  'صادر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca3c8>,
#  'ارطان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca400>,
#  'مارديريان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca438>,
#  'باتريك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca470>,
#  'هم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca4a8>,
#  'غازي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca4e0>,
#  'فيليب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca518>,
#  'هاني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca550>,
#  'سمير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca588>,
#  'شعيب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca5c0>,
#  'العزيز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca5f8>,
#  'اول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca630>,
#  'حسام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca668>,
#  'صادرة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca6a0>,
#  'كمال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca6d8>,
#  'جريس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca710>,
#  'وجود': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca748>,
#  'الفرار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca780>,
#  'ابراز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca7b8>,
#  'ابلاغ': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca7f0>,
#  'وجوب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca828>,
#  'مراجعة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca860>,
#  'الشرطة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca898>,
#  'ساريا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca8d0>,
#  'ليلى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca908>,
#  'المال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca940>,
#  'محفظت': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca978>,
#  'اشتباه': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca9b0>,
#  'رلى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ca9e8>,
#  'ايليا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caa20>,
#  'مشهور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caa58>,
#  'رانيا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caa90>,
#  'زهير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caac8>,
#  'الخدمة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cab00>,
#  'المنزلية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cab38>,
#  'اثيوبية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cab70>,
#  'طه': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caba8>,
#  'صبح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cabe0>,
#  'عبيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cac18>,
#  'دفتر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cac50>,
#  'لف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cac88>,
#  'الحليم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cacc0>,
#  'الانظمة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cacf8>,
#  'ياسين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cad30>,
#  'فريد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cad68>,
#  'تعميم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cada0>,
#  'بحث': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cadd8>,
#  'تحري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cae10>,
#  'مدة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cae48>,
#  'شهر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cae80>,
#  'الالفي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caeb8>,
#  'جاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caef0>,
#  'ضيا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caf28>,
#  'خصوصية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caf60>,
#  'جويا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9caf98>,
#  'رضا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cafd0>,
#  'عبدالله': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce048>,
#  'قحطان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce080>,
#  'الشمري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce0b8>,
#  'بيع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce0f0>,
#  'جر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce128>,
#  'رسول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce160>,
#  'الشب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce198>,
#  'ديانا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce1d0>,
#  'لمى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce208>,
#  'شلهوب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce240>,
#  'ف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce278>,
#  'اليات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce2b0>,
#  'منيمنة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce2e8>,
#  'اسامة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce320>,
#  'فرحات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce358>,
#  'مجهولين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce390>,
#  'سباق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce3c8>,
#  'الخيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce400>,
#  'نور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce438>,
#  'جمعة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce470>,
#  'هوندا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce4a8>,
#  'الاسمر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce4e0>,
#  'جباعي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce518>,
#  'افترا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce550>,
#  'العرب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce588>,
#  'شحاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce5c0>,
#  'القاصر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce5f8>,
#  'سندات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce630>,
#  'عطوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce668>,
#  'زكريا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce6a0>,
#  'خضر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce6d8>,
#  'خياط': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce710>,
#  'يعمل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce748>,
#  'يحي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce780>,
#  'فصيلة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce7b8>,
#  'طويل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce7f0>,
#  'الطيونة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce828>,
#  'حمدان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce860>,
#  'المنفردة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce898>,
#  'شتم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce8d0>,
#  'ماري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce908>,
#  'نمر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce940>,
#  'طراد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce978>,
#  'شمعون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce9b0>,
#  'قبض': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ce9e8>,
#  'باكير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cea20>,
#  'عملة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cea58>,
#  'عمار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cea90>,
#  'ام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ceac8>,
#  'كوكايين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ceb00>,
#  'كشلي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ceb38>,
#  'عيسى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ceb70>,
#  'هرا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ceba8>,
#  'صلاح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cebe0>,
#  'تزوير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cec18>,
#  'عمومية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cec50>,
#  'شريف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cec88>,
#  'برقية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cecc0>,
#  'سلام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cecf8>,
#  'رواد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ced30>,
#  'شكر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ced68>,
#  'نعنوع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ceda0>,
#  'وقوف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cedd8>,
#  'ممنوع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cee10>,
#  'النشل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cee48>,
#  'جمركية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cee80>,
#  'ماجد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ceeb8>,
#  'اللوحات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ceef0>,
#  'طحان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cef28>,
#  'هلال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cef60>,
#  'طفيلي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cef98>,
#  'كو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9cefd0>,
#  'شخص': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2048>,
#  'نحاس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2080>,
#  'التراجع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d20b8>,
#  'شعبان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d20f0>,
#  'ملاعب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2128>,
#  'حرش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2160>,
#  'متزن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2198>,
#  'عفيف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d21d0>,
#  'بيضون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2208>,
#  'جاسم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2240>,
#  'زين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2278>,
#  'جو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d22b0>,
#  'ناصيف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d22e8>,
#  'قيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2320>,
#  'باشلكوى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2358>,
#  'نهى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2390>,
#  'اللبان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d23c8>,
#  'حسني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2400>,
#  'نصب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2438>,
#  'المتحف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2470>,
#  'جوزاف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d24a8>,
#  'سكاف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d24e0>,
#  'رغبة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2518>,
#  'تعهد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2550>,
#  'حدث': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2588>,
#  'عبير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d25c0>,
#  'عيتاني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d25f8>,
#  'الاخير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2630>,
#  'الصدم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2668>,
#  'الشتم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d26a0>,
#  'ميلاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d26d8>,
#  'قزحيا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2710>,
#  'الحايك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2748>,
#  'فقيه': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2780>,
#  'الثاني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d27b8>,
#  'فياض': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d27f0>,
#  'مارون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2828>,
#  'الشامي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2860>,
#  'نعمة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2898>,
#  'زغرتا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d28d0>,
#  'غانم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2908>,
#  'عوالي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2940>,
#  'تكسير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2978>,
#  'مرسيدس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d29b0>,
#  'ج': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d29e8>,
#  'مع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2a20>,
#  'نعم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2a58>,
#  'الاملاك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2a90>,
#  'الخاصة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2ac8>,
#  'تخريب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2b00>,
#  'التحرش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2b38>,
#  'من': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2b70>,
#  'افادة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2ba8>,
#  'الكريم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2be0>,
#  'سلوم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2c18>,
#  'جود': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2c50>,
#  'جواز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2c88>,
#  'سفر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2cc0>,
#  'عاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2cf8>,
#  'ندى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2d30>,
#  'المستندات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2d68>,
#  'ال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2da0>,
#  'المواد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2dd8>,
#  'المتدرجة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2e10>,
#  'غنوة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2e48>,
#  'كسر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2e80>,
#  'درويش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2eb8>,
#  'كمية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2ef0>,
#  'خير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2f28>,
#  'بزي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2f60>,
#  'كارلوس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2f98>,
#  'مسعد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d2fd0>,
#  'رالف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5048>,
#  'الممور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5080>,
#  'راد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d50b8>,
#  'تسطير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d50f0>,
#  'الفحص': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5128>,
#  'المخبري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5160>,
#  'نظير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5198>,
#  'مكتوم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d51d0>,
#  'القيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5208>,
#  'مزور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5240>,
#  'الدرس': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5278>,
#  'بندقية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d52b0>,
#  'حربية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d52e8>,
#  'رفقة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5320>,
#  'ط': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5358>,
#  'هماز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5390>,
#  'العابدين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d53c8>,
#  'ياما': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5400>,
#  'عقيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5438>,
#  'فاروق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5470>,
#  'كيلة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d54a8>,
#  'الدة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d54e0>,
#  'وفا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5518>,
#  'تسجيل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5550>,
#  'الاولى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5588>,
#  'المجند': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d55c0>,
#  'عبود': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d55f8>,
#  'جميل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5630>,
#  'الهوية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5668>,
#  'المقداد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d56a0>,
#  'الباقي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d56d8>,
#  'اخذ': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5710>,
#  'جان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5748>,
#  'العريف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5780>,
#  'الضرب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d57b8>,
#  'اميون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d57f0>,
#  'مازن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5828>,
#  'كهربا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5860>,
#  'مذكرة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5898>,
#  'منفذة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d58d0>,
#  'شحيتلي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5908>,
#  'ميشال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5940>,
#  'الغول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5978>,
#  'قيام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d59b0>,
#  'المتن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d59e8>,
#  'خرق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5a20>,
#  'قانون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5a58>,
#  'الاجانب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5a90>,
#  'نصرالله': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5ac8>,
#  'المدعة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5b00>,
#  'بديع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5b38>,
#  'شرف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5b70>,
#  'حداد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5ba8>,
#  'عادة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5be0>,
#  'زوين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5c18>,
#  'عساكر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5c50>,
#  'حقيبة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5c88>,
#  'رولان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5cc0>,
#  'راشد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5cf8>,
#  'جوزف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5d30>,
#  'بشارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5d68>,
#  'القتل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5da0>,
#  'تحقير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5dd8>,
#  'بشير': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5e10>,
#  'دانيال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5e48>,
#  'انطوان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5e80>,
#  'محسن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5eb8>,
#  'ابي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5ef0>,
#  'الاسدعا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5f28>,
#  'جنان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5f60>,
#  'ملص': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5f98>,
#  'عربيد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d5fd0>,
#  'الكشف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8048>,
#  'محجوزة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8080>,
#  'مفرزة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d80b8>,
#  'رياض': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d80f0>,
#  'موسى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8128>,
#  'دهدو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8160>,
#  'ادلبي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8198>,
#  'تحر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d81d0>,
#  'حرفوش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8208>,
#  'اسماعيلات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8240>,
#  'المعلم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8278>,
#  'تهجم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d82b0>,
#  'الجهاز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d82e8>,
#  'الخليوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8320>,
#  'المراقبة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8358>,
#  'حصول': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8390>,
#  'اشكال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d83c8>,
#  'مفتوح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8400>,
#  'حال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8438>,
#  'تعدي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8470>,
#  'سيارات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d84a8>,
#  'البغدادي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d84e0>,
#  'مختار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8518>,
#  'العمري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8550>,
#  'هرموش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8588>,
#  'المستدعية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d85c0>,
#  'رعد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d85f8>,
#  'الشيخ': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8630>,
#  'جهاز': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8668>,
#  'ممدوح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d86a0>,
#  'الاشتباه': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d86d8>,
#  'الطفيلي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8710>,
#  'الرضا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8748>,
#  'الساتر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8780>,
#  'حبات': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d87b8>,
#  'البستاني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d87f0>,
#  'شارل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8828>,
#  'المزود': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8860>,
#  'باقي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8898>,
#  'الموسوري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d88d0>,
#  'طريقة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8908>,
#  'مجهولة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8940>,
#  'استخدام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8978>,
#  'ميرا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d89b0>,
#  'رجاوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d89e8>,
#  'مهند': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8a20>,
#  'ملا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8a58>,
#  'اديب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8a90>,
#  'فاديا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8ac8>,
#  'اليو': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8b00>,
#  'المديرية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8b38>,
#  'ناديا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8b70>,
#  'زوج': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8ba8>,
#  'البدوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8be0>,
#  'ظاظا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8c18>,
#  'عساف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8c50>,
#  'زكي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8c88>,
#  'بكار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8cc0>,
#  'جمعية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8cf8>,
#  'كفى': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8d30>,
#  'بدر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8d68>,
#  'التعرض': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8da0>,
#  'او': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8dd8>,
#  'زوجة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8e10>,
#  'الجهة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8e48>,
#  'بدوي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8e80>,
#  'عون': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8eb8>,
#  'المتدرج': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8ef0>,
#  'مرعي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8f28>,
#  'المفوض': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8f60>,
#  'التوقيع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8f98>,
#  'الشركة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9d8fd0>,
#  'بنك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd048>,
#  'المشرق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd080>,
#  'نسرين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd0b8>,
#  'حمزة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd0f0>,
#  'الرحيم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd128>,
#  'ملحم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd160>,
#  'سمعان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd198>,
#  'فادي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd1d0>,
#  'حجازي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd208>,
#  'ليندا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd240>,
#  'دلباني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd278>,
#  'اساتدعا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd2b0>,
#  'مسروقة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd2e8>,
#  'مرسال': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd320>,
#  'الاطرش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd358>,
#  'مالية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd390>,
#  'كيا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd3c8>,
#  'جرك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd400>,
#  'فحص': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd438>,
#  'اكرم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd470>,
#  'مصيطف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd4a8>,
#  'يوما': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd4e0>,
#  'غلاييني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd518>,
#  'بيك': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd550>,
#  'ازعاج': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd588>,
#  'هيثم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd5c0>,
#  'رضوان': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd5f8>,
#  'الفلسطيني': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd630>,
#  'اقويدر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd668>,
#  'ذخار': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd6a0>,
#  'حر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd6d8>,
#  'الرقم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd710>,
#  'امجد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd748>,
#  'سيف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd780>,
#  'بهيج': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd7b8>,
#  'لبنانين': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd7f0>,
#  'نهاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd828>,
#  'مسروق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd860>,
#  'وارد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd898>,
#  'اعطا': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd8d0>,
#  'مهلة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd908>,
#  'قدور': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd940>,
#  'مكحل': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd978>,
#  'جرام': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd9b0>,
#  'محذر': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dd9e8>,
#  'ترويج': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dda20>,
#  'جراح': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dda58>,
#  'فاخوري': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dda90>,
#  'خلع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddac8>,
#  'تابت': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddb00>,
#  'طرابلسي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddb38>,
#  'مراد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddb70>,
#  'وهبه': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddba8>,
#  'تمكن': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddbe0>,
#  'استماع': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddc18>,
#  'عيش': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddc50>,
#  'جهاد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddc88>,
#  'المارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddcc0>,
#  'قرب': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddcf8>,
#  'الجامعة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddd30>,
#  'شديد': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddd68>,
#  'شقيقة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddda0>,
#  'تعريف': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dddd8>,
#  'تنظيم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dde10>,
#  'اسحق': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dde48>,
#  'والدة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9dde80>,
#  'مخدوم': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddeb8>,
#  'السفارة': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddef0>,
#  'الفليبينية': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddf28>,
#  'الدسوقي': <gensim.models.keyedvectors.Vocab at 0x1fa3a9ddf60>,
#  ...}

# %%
from itertools import islice
list(islice(word2vec_vectors.wv.vocab, 130, 150))
# Out:
# ['قدح',
#  'بيان',
#  'كامل',
#  'المدعى',
#  'النبطية',
#  'خالد',
#  'عودة',
#  'الشكوى',
#  'المقدمة',
#  'مالك',
#  'المصري',
#  'وكيل',
#  'المحامي',
#  'عدنان',
#  'الشعار',
#  'على',
#  'كريم',
#  'عز',
#  'لبنانيان',
#  'شك']
