# %%
import math

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#start arabic test
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.stem.porter import *
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
import codecs
import sys

# %% [markdown]
# import os
# from nltk.parse import stanford as SParse
# from nltk.tag import stanford as STag
# from nltk.tokenize import StanfordSegmenter
#
# from polyglot.text import Text
# from rake_nltk import Rake
#
# import nltk
# nltk.download('stopwords')
# from nltk.corpus import stopwords
#
# os.environ['STANFORD_MODELS'] = 'stanford-segmenter-2018-10-16/data/;stanford-postagger-full-2018-10-16/models/'
# os.environ['STANFORD_PARSER'] = 'stanford-parser-full-2018-10-17'
# os.environ['CLASSPATH'] = 'stanford-parser-full-2018-10-17'
# os.environ['JAVAHOME'] = 'C:/Program Files/Java/jdk1.8.0_60'

# %%
#readind and preparing data ( text , label )
data=pd.read_excel('ML1.xlsx', header=None) ## read le file
data.columns=['label','text']
print(data[2:3])
# Out:
#    label                                               text
# 2      4  محضر تحقيق بحق المدعو ماهر صالح الحرامي سوري ل...

# %%
import nltk 
nltk.download('stopwords') 
from nltk.corpus import stopwords
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9ا-ي #+_]')
STOPWORDS = set(stopwords.words('arabic'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing. 
    text = text.replace('x', '')
#    text = re.sub(r'\W+', '', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    return text
data['text'] =data['text'].apply(clean_text)
data['text'] =data['text'].str.replace('\d+', '')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Maya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# subData = data['text']
# #subData = subData[1:10]
# singleTextWithPips = '|'.join(subData)
# #print(singleTextWithPips)
# f = open("samplePips.txt", "w",  encoding='utf-8')
# f.write(singleTextWithPips)
# f.close()

# %% [markdown]
# segmenter = StanfordSegmenter('stanford-segmenter-2018-10-16/stanford-segmenter-3.9.2.jar')
# segmenter.default_config('ar')
# textseg = segmenter.segment_file('samplePips.txt')
# print(textseg[1:20])

# %% [markdown]
# texts=textseg.split('|')
# print(texts[1:3])

# %% [markdown]
# from nltk.stem import ISRIStemmer
# st=ISRIStemmer()
# sw=STOPWORDS
# collection_new=[]
# for  doc in texts:
#     new_doc=[]
#     for i in doc.split():
#         if not i in sw:
#             i=st.stem(i)
#             i=''.join(i)
#             new_doc.append(i)
#     collection_new.append(new_doc)
# collection=collection_new

# %% [markdown]
# collection=texts
# print(collection[1])

# %% [markdown]
# import re
# print(collection[1])
# for i in range(len(collection)):
#     collection[i] = re.sub(r'\d+', '', str(collection[i]))
# print(collection[1])

# %% [markdown]
# table=str.maketrans("+=_-<>~/!*%?:;,)&1234567890@$qwertyuioplkjhgfdsamnbvcxz(QWERTYUIOPLKJHGFDSAZXCVBNM",82*" ")
# for i in range(len(collection)):
#     collection[i] = collection[i].translate(table)
# print(collection[1])

# %%
#import os, sys
#import pandas as pd
#import numpy as np
#from sklearn.metrics.pairwise import cosine_similarity
#from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.model_selection import train_test_split
#from sklearn.naive_bayes import BernoulliNB
#from sklearn.ensemble import RandomForestClassifier
##from sklearn.metrics import roc_curve, auc
#from sklearn import svm
#from sklearn.metrics import classification_report, confusion_matrix
#from sklearn.model_selection import GridSearchCV
from gensim.models import KeyedVectors
#from scipy import spatial
#import matplotlib.pyplot as plt
#from sklearn.neural_network import MLPClassifier
from nltk import bigrams
import nltk
import re
#import spacy
###FUNCTIONS
def avg_feature_vector(sentence, model, num_features, index2word_set):
        words = sentence.split()
        feature_vec = np.zeros((num_features, ), dtype='float32')
        n_words = 0
        for word in words:
            if word in index2word_set:
                n_words += 1
                feature_vec = np.add(feature_vec, model[word])
        if (n_words > 0):
            feature_vec = np.divide(feature_vec, n_words)
        return feature_vec

def convert_word2vec(sentences,num_features):
        vectors_matrix = np.zeros((len(sentences),num_features))
        i = 0
        for sent in sentences:
            temp = avg_feature_vector(sent,word2vec_vectors,num_features,index2word_set)
            vectors_matrix[i,:] = temp
            i = i+1
        return vectors_matrix
def cleaning(doc):
    # Lemmatizes and removes stopwords
    # doc needs to be a spacy Doc object
    #txt = [token for token in doc ]
    words=str(doc).strip().split()
    #words=[st.stem(w) for w in words ]
    return ' '.join(words)
    # Word2Vec uses context words to learn the vector representation of a target word,
    # if a sentence is only one or two words long,
    # the benefit for the training is very small
    #if len(txt) > 2:
      #return ' '.join(txt)
#from gensim.models.phrases import Phrases, Phraser
#data=pd.read_excel('ml2.xlsx', header=None) ## read le file
#data.columns=['text','label']
#def prep(doc):
 #   words=str(doc).strip().split()
  #  return ' '.join(words)
#Xt=Xt.apply(prep)
#sentences = Xt
data=data['text']
#data = data[data['Semantic_Type']!='DISREGARD']
#from gensim.models.phrases import Phrases, Phraser
#from nltk.stem import ISRIStemmer
#st=ISRIStemmer()
brief_cleaning = (re.sub("[^ا-ي']+", ' ', str(row)).lower() for row in data)
txt = [cleaning(doc) for doc in data]
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
sent = [row.split() for row in df_clean['clean']]
sentences = sent
print(sentences[1])
from gensim.models import Word2Vec
word2vec_vectors = Word2Vec(min_count=2,window=5,size=200,sample=6e-5,alpha=0.03,min_alpha=0.0007,negative=20)
word2vec_vectors.build_vocab(sentences)
word2vec_vectors.train(sentences, total_examples=word2vec_vectors.corpus_count, epochs=30, report_delay=1)
word2vec_vectors.init_sims(replace=True)
index2word_set = set(word2vec_vectors.wv.index2word)
###vectorizing the sentences
#vectors_matrix = convert_word2vec(data['Sentence'],200)
#np.random.seed(10)
#labels=data['label']
#train,test,ltrain,ltest =train_test_split(vectors_matrix, labels,test_size=0.2)#,random_state=8)
# Out:
# ['محضر', 'تحقيق', 'بادعا', 'المدعوة', 'اسما', 'هدى', 'انيس', 'قساطلي', 'لبنانية', 'بحق', 'مجهول', 'بموضوع', 'فقدان', 'محفظة', 'تحتوي', 'بطاقة', 'هوية', 'و', 'مبلغ', 'مالي']
# C:\Users\Maya\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "

# %%
def clean_str(text):
    search = ["أ","إ","آ","ة","_","-","/",".","،"," و "," يا ",'"',"ـ","'","ى","\\",'\n', '\t','&quot;','?','؟','!']
    replace = ["ا","ا","ا","ه"," "," ","","",""," و"," يا","","","","ي","",' ', ' ',' ',' ? ',' ؟ ',' ! ']
    
    #remove tashkeel
    p_tashkeel = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    text = re.sub(p_tashkeel,"", text)
    
    #remove longation
    p_longation = re.compile(r'(.)\1+')
    subst = r"\1\1"
    text = re.sub(p_longation, subst, text)
    
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    
    for i in range(0, len(search)):
        text = text.replace(search[i], replace[i])
    
    #trim    
    text = text.strip()

    return text
def get_vec(n_model,dim, token):
    vec = np.zeros(dim)
    is_vec = False
    if token not in n_model.wv:
        _count = 0
        is_vec = True
        for w in token.split("_"):
            if w in n_model.wv:
                _count += 1
                vec += n_model.wv[w]
        if _count > 0:
            vec = vec / _count
    else:
        vec = n_model.wv[token]
    return vec

def calc_vec(pos_tokens, neg_tokens, n_model, dim):
    vec = np.zeros(dim)
    for p in pos_tokens:
        vec += get_vec(n_model,dim,p)
    for n in neg_tokens:
        vec -= get_vec(n_model,dim,n)
    
    return vec

# %%
t_model = word2vec_vectors
pos_tokens=[ clean_str(t.strip()).replace(" ", "_") for t in ['خالد عسكر', 'مخدرات'] if t.strip() != ""]
neg_tokens=[ clean_str(t.strip()).replace(" ", "_") for t in ['سوري'] if t.strip() != ""]

vec = calc_vec(pos_tokens=pos_tokens, neg_tokens=neg_tokens, n_model=t_model, dim=t_model.vector_size)

most_sims = t_model.wv.similar_by_vector(vec, topn=10)
for term, score in most_sims:
    if term not in pos_tokens+neg_tokens:
        print(term, score)
# Out:
# توقيفهما 0.9992691874504089
# توقيفهم 0.9991694092750549
# تعاطي 0.9991551041603088
# لحيازتهما 0.9991446733474731
# المخدرة 0.9990957975387573
# تمساح 0.9990941286087036
# الضيقة 0.9990732669830322
# مادة 0.9990568161010742
# القعسماني 0.9990436434745789

# %%
print(data[1258])
print(data[1259])
print(data[1257])
# Out:
# محضر تحقيق المدعو جاد القعسماني بجرم عدم حيازة اوراق ثبوتية و تركه رهن التحقيق لابراز مستند يعرف عنه التعريف عنه قبل المحامي سمير ابو اسماعيل
# محضر تنفيذ خلاصة حكم بحق المدعو جاد القعسماني لبناني الجنسية بجرم مخدرات و كف البحث عنه و تركه سعد دفع الغرامة
# محضر تحقيق بحق المدعوين رواد خالد ابو و جاد عبد الهادي القعسماني لبناني بجرم حيازة مخدرات و توقيفهما بجرم حيازة و تعاطي مخدرات و حجز السيارة اداريا و عدليا

# %%
 word2vec_vectors.wv.vocab
# Out:
# {'محضر': <gensim.models.keyedvectors.Vocab at 0x2c14a59afd0>,
#  'تحقيق': <gensim.models.keyedvectors.Vocab at 0x2c14a671b38>,
#  'بحق': <gensim.models.keyedvectors.Vocab at 0x2c14a671908>,
#  'المدعو': <gensim.models.keyedvectors.Vocab at 0x2c14a671a20>,
#  'محمود': <gensim.models.keyedvectors.Vocab at 0x2c14a671be0>,
#  'مبارك': <gensim.models.keyedvectors.Vocab at 0x2c14a671c18>,
#  'سوري': <gensim.models.keyedvectors.Vocab at 0x2c14a671c50>,
#  'بجرم': <gensim.models.keyedvectors.Vocab at 0x2c14a671c88>,
#  'اقامة': <gensim.models.keyedvectors.Vocab at 0x2c14a671cc0>,
#  'مشروعة': <gensim.models.keyedvectors.Vocab at 0x2c14a671cf8>,
#  'و': <gensim.models.keyedvectors.Vocab at 0x2c14a671d30>,
#  'توقيفه': <gensim.models.keyedvectors.Vocab at 0x2c14a671d68>,
#  'بادعا': <gensim.models.keyedvectors.Vocab at 0x2c14a671da0>,
#  'المدعوة': <gensim.models.keyedvectors.Vocab at 0x2c14a671dd8>,
#  'هدى': <gensim.models.keyedvectors.Vocab at 0x2c14a671e10>,
#  'انيس': <gensim.models.keyedvectors.Vocab at 0x2c14a671e48>,
#  'لبنانية': <gensim.models.keyedvectors.Vocab at 0x2c14a671e80>,
#  'مجهول': <gensim.models.keyedvectors.Vocab at 0x2c14a671eb8>,
#  'بموضوع': <gensim.models.keyedvectors.Vocab at 0x2c14a671ef0>,
#  'فقدان': <gensim.models.keyedvectors.Vocab at 0x2c14a671f28>,
#  'محفظة': <gensim.models.keyedvectors.Vocab at 0x2c14a671f60>,
#  'تحتوي': <gensim.models.keyedvectors.Vocab at 0x2c14a671f98>,
#  'بطاقة': <gensim.models.keyedvectors.Vocab at 0x2c14a671fd0>,
#  'هوية': <gensim.models.keyedvectors.Vocab at 0x2c14ab47048>,
#  'مبلغ': <gensim.models.keyedvectors.Vocab at 0x2c14ab47080>,
#  'مالي': <gensim.models.keyedvectors.Vocab at 0x2c14ab470b8>,
#  'ماهر': <gensim.models.keyedvectors.Vocab at 0x2c14ab470f0>,
#  'صالح': <gensim.models.keyedvectors.Vocab at 0x2c14ab47128>,
#  'الحرامي': <gensim.models.keyedvectors.Vocab at 0x2c14ab47160>,
#  'لحيازته': <gensim.models.keyedvectors.Vocab at 0x2c14ab47198>,
#  'باسم': <gensim.models.keyedvectors.Vocab at 0x2c14ab471d0>,
#  'يوسف': <gensim.models.keyedvectors.Vocab at 0x2c14ab47208>,
#  'فتين': <gensim.models.keyedvectors.Vocab at 0x2c14ab47240>,
#  'تركه': <gensim.models.keyedvectors.Vocab at 0x2c14ab47278>,
#  'سند': <gensim.models.keyedvectors.Vocab at 0x2c14ab472b0>,
#  'بالاضافة': <gensim.models.keyedvectors.Vocab at 0x2c14ab472e8>,
#  'الى': <gensim.models.keyedvectors.Vocab at 0x2c14ab47320>,
#  'المذكور': <gensim.models.keyedvectors.Vocab at 0x2c14ab47358>,
#  'الاوراق': <gensim.models.keyedvectors.Vocab at 0x2c14ab47390>,
#  'الثبوتية': <gensim.models.keyedvectors.Vocab at 0x2c14ab473c8>,
#  'بينهما': <gensim.models.keyedvectors.Vocab at 0x2c14ab47400>,
#  'بتنفيذ': <gensim.models.keyedvectors.Vocab at 0x2c14ab47438>,
#  'خلاصة': <gensim.models.keyedvectors.Vocab at 0x2c14ab47470>,
#  'حكم': <gensim.models.keyedvectors.Vocab at 0x2c14ab474a8>,
#  'محمد': <gensim.models.keyedvectors.Vocab at 0x2c14ab474e0>,
#  'سعد': <gensim.models.keyedvectors.Vocab at 0x2c14ab47518>,
#  'الدين': <gensim.models.keyedvectors.Vocab at 0x2c14ab47550>,
#  'الصعيدي': <gensim.models.keyedvectors.Vocab at 0x2c14ab47588>,
#  'لبناني': <gensim.models.keyedvectors.Vocab at 0x2c14ab475c0>,
#  'اسلحة': <gensim.models.keyedvectors.Vocab at 0x2c14ab475f8>,
#  'كف': <gensim.models.keyedvectors.Vocab at 0x2c14ab47630>,
#  'البحث': <gensim.models.keyedvectors.Vocab at 0x2c14ab47668>,
#  'عنه': <gensim.models.keyedvectors.Vocab at 0x2c14ab476a0>,
#  'قرار': <gensim.models.keyedvectors.Vocab at 0x2c14ab476d8>,
#  'جزاي': <gensim.models.keyedvectors.Vocab at 0x2c14ab47710>,
#  'بمخالفة': <gensim.models.keyedvectors.Vocab at 0x2c14ab47748>,
#  'انظمة': <gensim.models.keyedvectors.Vocab at 0x2c14ab47780>,
#  'السير': <gensim.models.keyedvectors.Vocab at 0x2c14ab477b8>,
#  'شطب': <gensim.models.keyedvectors.Vocab at 0x2c14ab477f0>,
#  'الدليل': <gensim.models.keyedvectors.Vocab at 0x2c14ab47828>,
#  'عامر': <gensim.models.keyedvectors.Vocab at 0x2c14ab47860>,
#  'اسعد': <gensim.models.keyedvectors.Vocab at 0x2c14ab47898>,
#  'المولى': <gensim.models.keyedvectors.Vocab at 0x2c14ab478d0>,
#  'شجار': <gensim.models.keyedvectors.Vocab at 0x2c14ab47908>,
#  'حرا': <gensim.models.keyedvectors.Vocab at 0x2c14ab47940>,
#  'تنفيذ': <gensim.models.keyedvectors.Vocab at 0x2c14ab47978>,
#  'القاضي': <gensim.models.keyedvectors.Vocab at 0x2c14ab479b0>,
#  'المنفرد': <gensim.models.keyedvectors.Vocab at 0x2c14ab479e8>,
#  'الجزاي': <gensim.models.keyedvectors.Vocab at 0x2c14ab47a20>,
#  'جبل': <gensim.models.keyedvectors.Vocab at 0x2c14ab47a58>,
#  'لبنان': <gensim.models.keyedvectors.Vocab at 0x2c14ab47a90>,
#  'مخالفة': <gensim.models.keyedvectors.Vocab at 0x2c14ab47ac8>,
#  'البحق': <gensim.models.keyedvectors.Vocab at 0x2c14ab47b00>,
#  'طرابلس': <gensim.models.keyedvectors.Vocab at 0x2c14ab47b38>,
#  'طلال': <gensim.models.keyedvectors.Vocab at 0x2c14ab47b70>,
#  'صادق': <gensim.models.keyedvectors.Vocab at 0x2c14ab47ba8>,
#  'محكمة': <gensim.models.keyedvectors.Vocab at 0x2c14ab47be0>,
#  'جزا': <gensim.models.keyedvectors.Vocab at 0x2c14ab47c18>,
#  'صيدا': <gensim.models.keyedvectors.Vocab at 0x2c14ab47c50>,
#  'رامي': <gensim.models.keyedvectors.Vocab at 0x2c14ab47c88>,
#  'سكر': <gensim.models.keyedvectors.Vocab at 0x2c14ab47cc0>,
#  'ظاهر': <gensim.models.keyedvectors.Vocab at 0x2c14ab47cf8>,
#  'بعلبك': <gensim.models.keyedvectors.Vocab at 0x2c14ab47d30>,
#  'عباس': <gensim.models.keyedvectors.Vocab at 0x2c14ab47d68>,
#  'محي': <gensim.models.keyedvectors.Vocab at 0x2c14ab47da0>,
#  'موسوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab47dd8>,
#  'تعرض': <gensim.models.keyedvectors.Vocab at 0x2c14ab47e10>,
#  'للاداب': <gensim.models.keyedvectors.Vocab at 0x2c14ab47e48>,
#  'العامة': <gensim.models.keyedvectors.Vocab at 0x2c14ab47e80>,
#  'بالادعا': <gensim.models.keyedvectors.Vocab at 0x2c14ab47eb8>,
#  'الفوري': <gensim.models.keyedvectors.Vocab at 0x2c14ab47ef0>,
#  'المدعية': <gensim.models.keyedvectors.Vocab at 0x2c14ab47f28>,
#  'حول': <gensim.models.keyedvectors.Vocab at 0x2c14ab47f60>,
#  'اوراق': <gensim.models.keyedvectors.Vocab at 0x2c14ab47f98>,
#  'ثبوتية': <gensim.models.keyedvectors.Vocab at 0x2c14ab47fd0>,
#  'تلف': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b048>,
#  'دراجة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b080>,
#  'نارية': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b0b8>,
#  'نوع': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b0f0>,
#  'رقم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b128>,
#  'هيكلها': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b160>,
#  'صرف': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b198>,
#  'النظر': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b1d0>,
#  'تلفها': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b208>,
#  'احضار': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b240>,
#  'اوراقها': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b278>,
#  'الاكتفا': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b2b0>,
#  'الادارية': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b2e8>,
#  'السوري': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b320>,
#  'عبد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b358>,
#  'احمد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b390>,
#  'الحسين': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b3c8>,
#  'رهن': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b400>,
#  'التحقيق': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b438>,
#  'بكفالة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b470>,
#  'حازم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b4a8>,
#  'شوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b4e0>,
#  'المخالفات': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b518>,
#  'بيروت': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b550>,
#  'حسن': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b588>,
#  'رحال': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b5c0>,
#  'عدم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b5f8>,
#  'نقل': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b630>,
#  'التنفيذ': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b668>,
#  'رشيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b6a0>,
#  'بو': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b6d8>,
#  'كرم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b710>,
#  'ضد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b748>,
#  'قدح': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b780>,
#  'بيان': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b7b8>,
#  'كامل': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b7f0>,
#  'المدعى': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b828>,
#  'النبطية': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b860>,
#  'خالد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b898>,
#  'عودة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b8d0>,
#  'بالشكوى': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b908>,
#  'المقدمة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b940>,
#  'مالك': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b978>,
#  'المصري': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b9b0>,
#  'وكيله': <gensim.models.keyedvectors.Vocab at 0x2c14ab4b9e8>,
#  'المحامي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ba20>,
#  'عدنان': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ba58>,
#  'الشعار': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ba90>,
#  'عليهما': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bac8>,
#  'كريم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bb00>,
#  'عز': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bb38>,
#  'لبنانيان': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bb70>,
#  'شك': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bba8>,
#  'رصيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bbe0>,
#  'سامي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bc18>,
#  'الجنسية': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bc50>,
#  'اجهزة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bc88>,
#  'داخل': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bcc0>,
#  'سيارة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bcf8>,
#  'اجرة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bd30>,
#  'فوري': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bd68>,
#  'ادعا': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bda0>,
#  'رنا': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bdd8>,
#  'وهبي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4be10>,
#  'ذم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4be48>,
#  'زهره': <gensim.models.keyedvectors.Vocab at 0x2c14ab4be80>,
#  'علي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4beb8>,
#  'حمزه': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bef0>,
#  'مجهولان': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bf28>,
#  'محاولة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bf60>,
#  'نشل': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bf98>,
#  'متن': <gensim.models.keyedvectors.Vocab at 0x2c14ab4bfd0>,
#  'توقيف': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e048>,
#  'فرح': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e080>,
#  'فارس': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e0b8>,
#  'حيازة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e0f0>,
#  'تعاطي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e128>,
#  'مخدرات': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e160>,
#  'عماد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e198>,
#  'حمود': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e1d0>,
#  'حبوب': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e208>,
#  'مخدرة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e240>,
#  'امام': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e278>,
#  'مدخل': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e2b0>,
#  'قصر': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e2e8>,
#  'عدل': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e320>,
#  'ضبط': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e358>,
#  'سكين': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e390>,
#  'بحوزة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e3c8>,
#  'السكين': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e400>,
#  'تسليمنا': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e438>,
#  'غسان': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e470>,
#  'الخوري': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e4a8>,
#  'طلقات': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e4e0>,
#  'عيار': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e518>,
#  'ملم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e550>,
#  'المدعي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e588>,
#  'طارق': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e5c0>,
#  'ابراهيم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e5f8>,
#  'دياب': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e630>,
#  'بوكالة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e668>,
#  'عيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e6a0>,
#  'شهاب': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e6d8>,
#  'زياد': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e710>,
#  'كلش': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e748>,
#  'احتيال': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e780>,
#  'اساة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e7b8>,
#  'امانة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e7f0>,
#  'باشكوى': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e828>,
#  'جورج': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e860>,
#  'الريس': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e898>,
#  'استعمال': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e8d0>,
#  'لوحة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e908>,
#  'باستدعا': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e940>,
#  'شربل': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e978>,
#  'ناجي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e9b0>,
#  'جرجس': <gensim.models.keyedvectors.Vocab at 0x2c14ab4e9e8>,
#  'المر': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ea20>,
#  'رسمية': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ea58>,
#  'محلة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ea90>,
#  'العدلية': <gensim.models.keyedvectors.Vocab at 0x2c14ab4eac8>,
#  'الياس': <gensim.models.keyedvectors.Vocab at 0x2c14ab4eb00>,
#  'السوديكو': <gensim.models.keyedvectors.Vocab at 0x2c14ab4eb38>,
#  'بتوقيف': <gensim.models.keyedvectors.Vocab at 0x2c14ab4eb70>,
#  'وليم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4eba8>,
#  'شادي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ebe0>,
#  'ابو': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ec18>,
#  'عجرم': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ec50>,
#  'السورية': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ec88>,
#  'حجز': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ecc0>,
#  'السيارة': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ecf8>,
#  'عدليا': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ed30>,
#  'اداريا': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ed68>,
#  'المضبوطات': <gensim.models.keyedvectors.Vocab at 0x2c14ab4eda0>,
#  'المدعوين': <gensim.models.keyedvectors.Vocab at 0x2c14ab4edd8>,
#  'مصباح': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ee10>,
#  'عثمان': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ee48>,
#  'انطونيوس': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ee80>,
#  'لحيازتهما': <gensim.models.keyedvectors.Vocab at 0x2c14ab4eeb8>,
#  'توقيفها': <gensim.models.keyedvectors.Vocab at 0x2c14ab4eef0>,
#  'بجرن': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ef28>,
#  'الجندي': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ef60>,
#  'المخدرات': <gensim.models.keyedvectors.Vocab at 0x2c14ab4ef98>,
#  'المضبوط': <gensim.models.keyedvectors.Vocab at 0x2c14ab4efd0>,
#  'الظريف': <gensim.models.keyedvectors.Vocab at 0x2c14ab51048>,
#  'جنح': <gensim.models.keyedvectors.Vocab at 0x2c14ab51080>,
#  'احداث': <gensim.models.keyedvectors.Vocab at 0x2c14ab510b8>,
#  'منصور': <gensim.models.keyedvectors.Vocab at 0x2c14ab510f0>,
#  'استناف': <gensim.models.keyedvectors.Vocab at 0x2c14ab51128>,
#  'علا': <gensim.models.keyedvectors.Vocab at 0x2c14ab51160>,
#  'مشيك': <gensim.models.keyedvectors.Vocab at 0x2c14ab51198>,
#  'الشمال': <gensim.models.keyedvectors.Vocab at 0x2c14ab511d0>,
#  'بالتحقيق': <gensim.models.keyedvectors.Vocab at 0x2c14ab51208>,
#  'الصالح': <gensim.models.keyedvectors.Vocab at 0x2c14ab51240>,
#  'منتهية': <gensim.models.keyedvectors.Vocab at 0x2c14ab51278>,
#  'لتسوية': <gensim.models.keyedvectors.Vocab at 0x2c14ab512b0>,
#  'وضعه': <gensim.models.keyedvectors.Vocab at 0x2c14ab512e8>,
#  'الكفيل': <gensim.models.keyedvectors.Vocab at 0x2c14ab51320>,
#  'المحامية': <gensim.models.keyedvectors.Vocab at 0x2c14ab51358>,
#  'امين': <gensim.models.keyedvectors.Vocab at 0x2c14ab51390>,
#  'مصري': <gensim.models.keyedvectors.Vocab at 0x2c14ab513c8>,
#  'مروان': <gensim.models.keyedvectors.Vocab at 0x2c14ab51400>,
#  'طربيه': <gensim.models.keyedvectors.Vocab at 0x2c14ab51438>,
#  'التهجم': <gensim.models.keyedvectors.Vocab at 0x2c14ab51470>,
#  'القضاة': <gensim.models.keyedvectors.Vocab at 0x2c14ab514a8>,
#  'نحقيق': <gensim.models.keyedvectors.Vocab at 0x2c14ab514e0>,
#  'عميرات': <gensim.models.keyedvectors.Vocab at 0x2c14ab51518>,
#  'لغاية': <gensim.models.keyedvectors.Vocab at 0x2c14ab51550>,
#  'الساعة': <gensim.models.keyedvectors.Vocab at 0x2c14ab51588>,
#  'تاريخ': <gensim.models.keyedvectors.Vocab at 0x2c14ab515c0>,
#  'بعدها': <gensim.models.keyedvectors.Vocab at 0x2c14ab515f8>,
#  'سنو': <gensim.models.keyedvectors.Vocab at 0x2c14ab51630>,
#  'الاول': <gensim.models.keyedvectors.Vocab at 0x2c14ab51668>,
#  'الامن': <gensim.models.keyedvectors.Vocab at 0x2c14ab516a0>,
#  'العام': <gensim.models.keyedvectors.Vocab at 0x2c14ab516d8>,
#  'سرقة': <gensim.models.keyedvectors.Vocab at 0x2c14ab51710>,
#  'دراجته': <gensim.models.keyedvectors.Vocab at 0x2c14ab51748>,
#  'النارية': <gensim.models.keyedvectors.Vocab at 0x2c14ab51780>,
#  'قبل': <gensim.models.keyedvectors.Vocab at 0x2c14ab517b8>,
#  'بلال': <gensim.models.keyedvectors.Vocab at 0x2c14ab517f0>,
#  'مدني': <gensim.models.keyedvectors.Vocab at 0x2c14ab51828>,
#  'الرزاق': <gensim.models.keyedvectors.Vocab at 0x2c14ab51860>,
#  'المحمد': <gensim.models.keyedvectors.Vocab at 0x2c14ab51898>,
#  'بحضور': <gensim.models.keyedvectors.Vocab at 0x2c14ab518d0>,
#  'والده': <gensim.models.keyedvectors.Vocab at 0x2c14ab51908>,
#  'حسين': <gensim.models.keyedvectors.Vocab at 0x2c14ab51940>,
#  'تسوية': <gensim.models.keyedvectors.Vocab at 0x2c14ab51978>,
#  'حضوره': <gensim.models.keyedvectors.Vocab at 0x2c14ab519b0>,
#  'التعميم': <gensim.models.keyedvectors.Vocab at 0x2c14ab519e8>,
#  'ضر': <gensim.models.keyedvectors.Vocab at 0x2c14ab51a20>,
#  'الرقيب': <gensim.models.keyedvectors.Vocab at 0x2c14ab51a58>,
#  'بسام': <gensim.models.keyedvectors.Vocab at 0x2c14ab51a90>,
#  'فخر': <gensim.models.keyedvectors.Vocab at 0x2c14ab51ac8>,
#  'لاقدامه': <gensim.models.keyedvectors.Vocab at 0x2c14ab51b00>,
#  'وضع': <gensim.models.keyedvectors.Vocab at 0x2c14ab51b38>,
#  'سيارته': <gensim.models.keyedvectors.Vocab at 0x2c14ab51b70>,
#  'الغير': <gensim.models.keyedvectors.Vocab at 0x2c14ab51ba8>,
#  'مسجلة': <gensim.models.keyedvectors.Vocab at 0x2c14ab51be0>,
#  'لقا': <gensim.models.keyedvectors.Vocab at 0x2c14ab51c18>,
#  'سعاد': <gensim.models.keyedvectors.Vocab at 0x2c14ab51c50>,
#  'نصر': <gensim.models.keyedvectors.Vocab at 0x2c14ab51c88>,
#  'بدارو': <gensim.models.keyedvectors.Vocab at 0x2c14ab51cc0>,
#  'لطفي': <gensim.models.keyedvectors.Vocab at 0x2c14ab51cf8>,
#  'مستندات': <gensim.models.keyedvectors.Vocab at 0x2c14ab51d30>,
#  'مسدس': <gensim.models.keyedvectors.Vocab at 0x2c14ab51d68>,
#  'خلبي': <gensim.models.keyedvectors.Vocab at 0x2c14ab51da0>,
#  'ترخيص': <gensim.models.keyedvectors.Vocab at 0x2c14ab51dd8>,
#  'المسدس': <gensim.models.keyedvectors.Vocab at 0x2c14ab51e10>,
#  'سهيل': <gensim.models.keyedvectors.Vocab at 0x2c14ab51e48>,
#  'سليم': <gensim.models.keyedvectors.Vocab at 0x2c14ab51e80>,
#  'نصار': <gensim.models.keyedvectors.Vocab at 0x2c14ab51eb8>,
#  'هاتف': <gensim.models.keyedvectors.Vocab at 0x2c14ab51ef0>,
#  'خليوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab51f28>,
#  'الوهاب': <gensim.models.keyedvectors.Vocab at 0x2c14ab51f60>,
#  'الدرزي': <gensim.models.keyedvectors.Vocab at 0x2c14ab51f98>,
#  'لقيادته': <gensim.models.keyedvectors.Vocab at 0x2c14ab51fd0>,
#  'انقاض': <gensim.models.keyedvectors.Vocab at 0x2c14ab54048>,
#  'اللوحة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54080>,
#  'م': <gensim.models.keyedvectors.Vocab at 0x2c14ab540b8>,
#  'مغايرة': <gensim.models.keyedvectors.Vocab at 0x2c14ab540f0>,
#  'حشيشة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54128>,
#  'حيدر': <gensim.models.keyedvectors.Vocab at 0x2c14ab54160>,
#  'قاصر': <gensim.models.keyedvectors.Vocab at 0x2c14ab54198>,
#  'تعاطيه': <gensim.models.keyedvectors.Vocab at 0x2c14ab541d0>,
#  'الكيف': <gensim.models.keyedvectors.Vocab at 0x2c14ab54208>,
#  'حلبا': <gensim.models.keyedvectors.Vocab at 0x2c14ab54240>,
#  'شركة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54278>,
#  'السيارات': <gensim.models.keyedvectors.Vocab at 0x2c14ab542b0>,
#  'وكيلها': <gensim.models.keyedvectors.Vocab at 0x2c14ab542e8>,
#  'زعيتر': <gensim.models.keyedvectors.Vocab at 0x2c14ab54320>,
#  'رخصة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54358>,
#  'مركبة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54390>,
#  'هنادي': <gensim.models.keyedvectors.Vocab at 0x2c14ab543c8>,
#  'اجازة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54400>,
#  'عمل': <gensim.models.keyedvectors.Vocab at 0x2c14ab54438>,
#  'الاثيوبية': <gensim.models.keyedvectors.Vocab at 0x2c14ab54470>,
#  'عطيه': <gensim.models.keyedvectors.Vocab at 0x2c14ab544a8>,
#  'الحنان': <gensim.models.keyedvectors.Vocab at 0x2c14ab544e0>,
#  'الدرجه': <gensim.models.keyedvectors.Vocab at 0x2c14ab54518>,
#  'قطعة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54550>,
#  'مزورة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54588>,
#  'دولار': <gensim.models.keyedvectors.Vocab at 0x2c14ab545c0>,
#  'الحاج': <gensim.models.keyedvectors.Vocab at 0x2c14ab545f8>,
#  'ناصر': <gensim.models.keyedvectors.Vocab at 0x2c14ab54630>,
#  'ترك': <gensim.models.keyedvectors.Vocab at 0x2c14ab54668>,
#  'كلاس': <gensim.models.keyedvectors.Vocab at 0x2c14ab546a0>,
#  'دينا': <gensim.models.keyedvectors.Vocab at 0x2c14ab546d8>,
#  'الجيش': <gensim.models.keyedvectors.Vocab at 0x2c14ab54710>,
#  'اللبنانية': <gensim.models.keyedvectors.Vocab at 0x2c14ab54748>,
#  'خليل': <gensim.models.keyedvectors.Vocab at 0x2c14ab54780>,
#  'صلح': <gensim.models.keyedvectors.Vocab at 0x2c14ab547b8>,
#  'شهادة': <gensim.models.keyedvectors.Vocab at 0x2c14ab547f0>,
#  'المقدم': <gensim.models.keyedvectors.Vocab at 0x2c14ab54828>,
#  'سامر': <gensim.models.keyedvectors.Vocab at 0x2c14ab54860>,
#  'الحسامي': <gensim.models.keyedvectors.Vocab at 0x2c14ab54898>,
#  'مريم': <gensim.models.keyedvectors.Vocab at 0x2c14ab548d0>,
#  'الرحمن': <gensim.models.keyedvectors.Vocab at 0x2c14ab54908>,
#  'لينا': <gensim.models.keyedvectors.Vocab at 0x2c14ab54940>,
#  'دعبول': <gensim.models.keyedvectors.Vocab at 0x2c14ab54978>,
#  'قصقص': <gensim.models.keyedvectors.Vocab at 0x2c14ab549b0>,
#  'البيضا': <gensim.models.keyedvectors.Vocab at 0x2c14ab549e8>,
#  'سورية': <gensim.models.keyedvectors.Vocab at 0x2c14ab54a20>,
#  'تركها': <gensim.models.keyedvectors.Vocab at 0x2c14ab54a58>,
#  'باسيل': <gensim.models.keyedvectors.Vocab at 0x2c14ab54a90>,
#  'خوري': <gensim.models.keyedvectors.Vocab at 0x2c14ab54ac8>,
#  'زينب': <gensim.models.keyedvectors.Vocab at 0x2c14ab54b00>,
#  'مخالفات': <gensim.models.keyedvectors.Vocab at 0x2c14ab54b38>,
#  'صبحي': <gensim.models.keyedvectors.Vocab at 0x2c14ab54b70>,
#  'غدارة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54ba8>,
#  'اقلاق': <gensim.models.keyedvectors.Vocab at 0x2c14ab54be0>,
#  'راحة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54c18>,
#  'جنايات': <gensim.models.keyedvectors.Vocab at 0x2c14ab54c50>,
#  'عصام': <gensim.models.keyedvectors.Vocab at 0x2c14ab54c88>,
#  'فهمي': <gensim.models.keyedvectors.Vocab at 0x2c14ab54cc0>,
#  'منهية': <gensim.models.keyedvectors.Vocab at 0x2c14ab54cf8>,
#  'الصلاحية': <gensim.models.keyedvectors.Vocab at 0x2c14ab54d30>,
#  'سوداني': <gensim.models.keyedvectors.Vocab at 0x2c14ab54d68>,
#  'الخلف': <gensim.models.keyedvectors.Vocab at 0x2c14ab54da0>,
#  'للعثور': <gensim.models.keyedvectors.Vocab at 0x2c14ab54dd8>,
#  'جمال': <gensim.models.keyedvectors.Vocab at 0x2c14ab54e10>,
#  'بحسب': <gensim.models.keyedvectors.Vocab at 0x2c14ab54e48>,
#  'اقواله': <gensim.models.keyedvectors.Vocab at 0x2c14ab54e80>,
#  'لعدم': <gensim.models.keyedvectors.Vocab at 0x2c14ab54eb8>,
#  'حيازته': <gensim.models.keyedvectors.Vocab at 0x2c14ab54ef0>,
#  'سعيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab54f28>,
#  'ايهاب': <gensim.models.keyedvectors.Vocab at 0x2c14ab54f60>,
#  'سيجارة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54f98>,
#  'ملفوفة': <gensim.models.keyedvectors.Vocab at 0x2c14ab54fd0>,
#  'يعتقد': <gensim.models.keyedvectors.Vocab at 0x2c14ab58048>,
#  'انها': <gensim.models.keyedvectors.Vocab at 0x2c14ab58080>,
#  'مادة': <gensim.models.keyedvectors.Vocab at 0x2c14ab580b8>,
#  'اوراقه': <gensim.models.keyedvectors.Vocab at 0x2c14ab580f0>,
#  'المحكمة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58128>,
#  'العسكرية': <gensim.models.keyedvectors.Vocab at 0x2c14ab58160>,
#  'الدامة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58198>,
#  'اسماعيل': <gensim.models.keyedvectors.Vocab at 0x2c14ab581d0>,
#  'نعمان': <gensim.models.keyedvectors.Vocab at 0x2c14ab58208>,
#  'اطلاق': <gensim.models.keyedvectors.Vocab at 0x2c14ab58240>,
#  'نار': <gensim.models.keyedvectors.Vocab at 0x2c14ab58278>,
#  'سلاح': <gensim.models.keyedvectors.Vocab at 0x2c14ab582b0>,
#  'حربي': <gensim.models.keyedvectors.Vocab at 0x2c14ab582e8>,
#  'ان': <gensim.models.keyedvectors.Vocab at 0x2c14ab58320>,
#  'تبين': <gensim.models.keyedvectors.Vocab at 0x2c14ab58358>,
#  'الخلاصة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58390>,
#  'يحقه': <gensim.models.keyedvectors.Vocab at 0x2c14ab583c8>,
#  'سليمان': <gensim.models.keyedvectors.Vocab at 0x2c14ab58400>,
#  'فضل': <gensim.models.keyedvectors.Vocab at 0x2c14ab58438>,
#  'الله': <gensim.models.keyedvectors.Vocab at 0x2c14ab58470>,
#  'طالب': <gensim.models.keyedvectors.Vocab at 0x2c14ab584a8>,
#  'الدرجة': <gensim.models.keyedvectors.Vocab at 0x2c14ab584e0>,
#  'الثانية': <gensim.models.keyedvectors.Vocab at 0x2c14ab58518>,
#  'سير': <gensim.models.keyedvectors.Vocab at 0x2c14ab58550>,
#  'عمر': <gensim.models.keyedvectors.Vocab at 0x2c14ab58588>,
#  'وليد': <gensim.models.keyedvectors.Vocab at 0x2c14ab585c0>,
#  'البنا': <gensim.models.keyedvectors.Vocab at 0x2c14ab585f8>,
#  'الروف': <gensim.models.keyedvectors.Vocab at 0x2c14ab58630>,
#  'فنيش': <gensim.models.keyedvectors.Vocab at 0x2c14ab58668>,
#  'ز': <gensim.models.keyedvectors.Vocab at 0x2c14ab586a0>,
#  'الحشيشة': <gensim.models.keyedvectors.Vocab at 0x2c14ab586d8>,
#  'المخدرة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58710>,
#  'سرعة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58748>,
#  'زادة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58780>,
#  'الخالد': <gensim.models.keyedvectors.Vocab at 0x2c14ab587b8>,
#  'حنان': <gensim.models.keyedvectors.Vocab at 0x2c14ab587f0>,
#  'يونس': <gensim.models.keyedvectors.Vocab at 0x2c14ab58828>,
#  'غزاوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab58860>,
#  'وسيم': <gensim.models.keyedvectors.Vocab at 0x2c14ab58898>,
#  'النتيجة': <gensim.models.keyedvectors.Vocab at 0x2c14ab588d0>,
#  'سلبية': <gensim.models.keyedvectors.Vocab at 0x2c14ab58908>,
#  'البطاقة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58940>,
#  'غندور': <gensim.models.keyedvectors.Vocab at 0x2c14ab58978>,
#  'رتبا': <gensim.models.keyedvectors.Vocab at 0x2c14ab589b0>,
#  'قوى': <gensim.models.keyedvectors.Vocab at 0x2c14ab589e8>,
#  'الداخلي': <gensim.models.keyedvectors.Vocab at 0x2c14ab58a20>,
#  'مهيدي': <gensim.models.keyedvectors.Vocab at 0x2c14ab58a58>,
#  'الجماله': <gensim.models.keyedvectors.Vocab at 0x2c14ab58a90>,
#  'البنغلادشية': <gensim.models.keyedvectors.Vocab at 0x2c14ab58ac8>,
#  'زحلة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58b00>,
#  'ديب': <gensim.models.keyedvectors.Vocab at 0x2c14ab58b38>,
#  'قيادته': <gensim.models.keyedvectors.Vocab at 0x2c14ab58b70>,
#  'ميرنا': <gensim.models.keyedvectors.Vocab at 0x2c14ab58ba8>,
#  'روبير': <gensim.models.keyedvectors.Vocab at 0x2c14ab58be0>,
#  'لاجرا': <gensim.models.keyedvectors.Vocab at 0x2c14ab58c18>,
#  'دفع': <gensim.models.keyedvectors.Vocab at 0x2c14ab58c50>,
#  'لاشارة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58c88>,
#  'القضا': <gensim.models.keyedvectors.Vocab at 0x2c14ab58cc0>,
#  'فراس': <gensim.models.keyedvectors.Vocab at 0x2c14ab58cf8>,
#  'مواليد': <gensim.models.keyedvectors.Vocab at 0x2c14ab58d30>,
#  'بواسطة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58d68>,
#  'مكتب': <gensim.models.keyedvectors.Vocab at 0x2c14ab58da0>,
#  'مكافحة': <gensim.models.keyedvectors.Vocab at 0x2c14ab58dd8>,
#  'المركزي': <gensim.models.keyedvectors.Vocab at 0x2c14ab58e10>,
#  'ليال': <gensim.models.keyedvectors.Vocab at 0x2c14ab58e48>,
#  'حماده': <gensim.models.keyedvectors.Vocab at 0x2c14ab58e80>,
#  'المهل': <gensim.models.keyedvectors.Vocab at 0x2c14ab58eb8>,
#  'مهدي': <gensim.models.keyedvectors.Vocab at 0x2c14ab58ef0>,
#  'ظنيط': <gensim.models.keyedvectors.Vocab at 0x2c14ab58f28>,
#  'استيلا': <gensim.models.keyedvectors.Vocab at 0x2c14ab58f60>,
#  'سيارتها': <gensim.models.keyedvectors.Vocab at 0x2c14ab58f98>,
#  'تسليمها': <gensim.models.keyedvectors.Vocab at 0x2c14ab58fd0>,
#  'لون': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c048>,
#  'الهيكل': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c080>,
#  'كونه': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c0b8>,
#  'تم': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c0f0>,
#  'بحجزها': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c128>,
#  'ساره': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c160>,
#  'رباح': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c198>,
#  'تسديد': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c1d0>,
#  'الغرامة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c208>,
#  'نزهة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c240>,
#  'طبارة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c278>,
#  'شقيقها': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c2b0>,
#  'نبيل': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c2e8>,
#  'ضرب': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c320>,
#  'ايذا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c358>,
#  'بشكوى': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c390>,
#  'مقدمة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c3c8>,
#  'نقابة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c400>,
#  'رنده': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c438>,
#  'اسبر': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c470>,
#  'هاشم': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c4a8>,
#  'نديم': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c4e0>,
#  'مخايل': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c518>,
#  'كلاب': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c550>,
#  'مونة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c588>,
#  'جعار': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c5c0>,
#  'اردني': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c5f8>,
#  'صقر': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c630>,
#  'دخول': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c668>,
#  'البلاد': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c6a0>,
#  'خلسة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c6d8>,
#  'السيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c710>,
#  'الغني': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c748>,
#  'فلسطيني': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c780>,
#  'راس': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c7b8>,
#  'النبع': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c7f0>,
#  'قبيسي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c828>,
#  'ايلي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c860>,
#  'بطرس': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c898>,
#  'توقيفهما': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c8d0>,
#  'اللبناني': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c908>,
#  'عليها': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c940>,
#  'رفع': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c978>,
#  'عنها': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c9b0>,
#  'فواز': <gensim.models.keyedvectors.Vocab at 0x2c14ab5c9e8>,
#  'الجاسم': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ca20>,
#  'تسبب': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ca58>,
#  'بايذا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ca90>,
#  'برلا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cac8>,
#  'الحلو': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cb00>,
#  'تبسيط': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cb38>,
#  'الزعبي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cb70>,
#  'الموسوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cba8>,
#  'خالفة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cbe0>,
#  'ابقا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cc18>,
#  'البلاغ': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cc50>,
#  'ساري': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cc88>,
#  'المفعول': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ccc0>,
#  'كون': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ccf8>,
#  'الشخص': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cd30>,
#  'المطلوب': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cd68>,
#  'لدينا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cda0>,
#  'فاد': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cdd8>,
#  'بركات': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ce10>,
#  'السرقة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ce48>,
#  'بالاستدعا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ce80>,
#  'المستدعي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ceb8>,
#  'سلامة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cef0>,
#  'حسان': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cf28>,
#  'الخطيب': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cf60>,
#  'سوق': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cf98>,
#  'رس': <gensim.models.keyedvectors.Vocab at 0x2c14ab5cfd0>,
#  'نجيب': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e048>,
#  'اللحام': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e080>,
#  'رمضان': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e0b8>,
#  'اموال': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e0f0>,
#  'تهديد': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e128>,
#  'اجرا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e160>,
#  'مقابلة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e198>,
#  'الدعى': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e1d0>,
#  'ختم': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e208>,
#  'المحضر': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e240>,
#  'فايز': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e278>,
#  'العلي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e2b0>,
#  'منيمنه': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e2e8>,
#  'هادي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e320>,
#  'حضور': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e358>,
#  'العميم': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e390>,
#  'البقيلي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e3c8>,
#  'انه': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e400>,
#  'المقصود': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e438>,
#  'توفر': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e470>,
#  'معلومات': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e4a8>,
#  'المعاون': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e4e0>,
#  'ربيع': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e518>,
#  'نتيجة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e550>,
#  'عطايا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e588>,
#  'مصطفى': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e5c0>,
#  'سندي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e5f8>,
#  'ايمن': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e630>,
#  'الحويك': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e668>,
#  'للعاملة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e6a0>,
#  'شاهين': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e6d8>,
#  'رمزي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e710>,
#  'عياش': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e748>,
#  'سماح': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e780>,
#  'داوود': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e7b8>,
#  'مقاومة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e7f0>,
#  'رجال': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e828>,
#  'السلطة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e860>,
#  'بلاغ': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e898>,
#  'رستم': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e8d0>,
#  'مهران': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e908>,
#  'ريما': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e940>,
#  'حاتم': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e978>,
#  'بالشدة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e9b0>,
#  'افرام': <gensim.models.keyedvectors.Vocab at 0x2c14ab5e9e8>,
#  'المصرية': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ea20>,
#  'المجيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ea58>,
#  'جوزيف': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ea90>,
#  'اميل': <gensim.models.keyedvectors.Vocab at 0x2c14ab5eac8>,
#  'الاهانة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5eb00>,
#  'ناتالي': <gensim.models.keyedvectors.Vocab at 0x2c14ab5eb38>,
#  'ضاهر': <gensim.models.keyedvectors.Vocab at 0x2c14ab5eb70>,
#  'دانيا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5eba8>,
#  'شمص': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ebe0>,
#  'داني': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ec18>,
#  'الحق': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ec50>,
#  'بالقوة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ec88>,
#  'خاصة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ecc0>,
#  'تراجع': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ecf8>,
#  'حمد': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ed30>,
#  'يقودها': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ed68>,
#  'ترمس': <gensim.models.keyedvectors.Vocab at 0x2c14ab5eda0>,
#  'مولى': <gensim.models.keyedvectors.Vocab at 0x2c14ab5edd8>,
#  'منزل': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ee10>,
#  'الكسر': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ee48>,
#  'الخلع': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ee80>,
#  'تحمل': <gensim.models.keyedvectors.Vocab at 0x2c14ab5eeb8>,
#  'حنا': <gensim.models.keyedvectors.Vocab at 0x2c14ab5eef0>,
#  'كاذبة': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ef28>,
#  'ناهض': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ef60>,
#  'مطر': <gensim.models.keyedvectors.Vocab at 0x2c14ab5ef98>,
#  'غروب': <gensim.models.keyedvectors.Vocab at 0x2c14ab5efd0>,
#  'ممثلة': <gensim.models.keyedvectors.Vocab at 0x2c14ab63048>,
#  'بالمدعو': <gensim.models.keyedvectors.Vocab at 0x2c14ab63080>,
#  'عطا': <gensim.models.keyedvectors.Vocab at 0x2c14ab630b8>,
#  'القادر': <gensim.models.keyedvectors.Vocab at 0x2c14ab630f0>,
#  'اقدام': <gensim.models.keyedvectors.Vocab at 0x2c14ab63128>,
#  'تشهير': <gensim.models.keyedvectors.Vocab at 0x2c14ab63160>,
#  'امل': <gensim.models.keyedvectors.Vocab at 0x2c14ab63198>,
#  'رامز': <gensim.models.keyedvectors.Vocab at 0x2c14ab631d0>,
#  'الاشرفية': <gensim.models.keyedvectors.Vocab at 0x2c14ab63208>,
#  'الزين': <gensim.models.keyedvectors.Vocab at 0x2c14ab63240>,
#  'ميسا': <gensim.models.keyedvectors.Vocab at 0x2c14ab63278>,
#  'صادر': <gensim.models.keyedvectors.Vocab at 0x2c14ab632b0>,
#  'وارطان': <gensim.models.keyedvectors.Vocab at 0x2c14ab632e8>,
#  'مارديريان': <gensim.models.keyedvectors.Vocab at 0x2c14ab63320>,
#  'باتريك': <gensim.models.keyedvectors.Vocab at 0x2c14ab63358>,
#  'تركهم': <gensim.models.keyedvectors.Vocab at 0x2c14ab63390>,
#  'غازي': <gensim.models.keyedvectors.Vocab at 0x2c14ab633c8>,
#  'فيليب': <gensim.models.keyedvectors.Vocab at 0x2c14ab63400>,
#  'هاني': <gensim.models.keyedvectors.Vocab at 0x2c14ab63438>,
#  'سمير': <gensim.models.keyedvectors.Vocab at 0x2c14ab63470>,
#  'شعيب': <gensim.models.keyedvectors.Vocab at 0x2c14ab634a8>,
#  'العزيز': <gensim.models.keyedvectors.Vocab at 0x2c14ab634e0>,
#  'اول': <gensim.models.keyedvectors.Vocab at 0x2c14ab63518>,
#  'حسام': <gensim.models.keyedvectors.Vocab at 0x2c14ab63550>,
#  'صادرة': <gensim.models.keyedvectors.Vocab at 0x2c14ab63588>,
#  'كمال': <gensim.models.keyedvectors.Vocab at 0x2c14ab635c0>,
#  'جريس': <gensim.models.keyedvectors.Vocab at 0x2c14ab635f8>,
#  'بوجود': <gensim.models.keyedvectors.Vocab at 0x2c14ab63630>,
#  'بحقه': <gensim.models.keyedvectors.Vocab at 0x2c14ab63668>,
#  'الفرار': <gensim.models.keyedvectors.Vocab at 0x2c14ab636a0>,
#  'ابرازه': <gensim.models.keyedvectors.Vocab at 0x2c14ab636d8>,
#  'وجوب': <gensim.models.keyedvectors.Vocab at 0x2c14ab63710>,
#  'مراجعة': <gensim.models.keyedvectors.Vocab at 0x2c14ab63748>,
#  'الشرطة': <gensim.models.keyedvectors.Vocab at 0x2c14ab63780>,
#  'ساريا': <gensim.models.keyedvectors.Vocab at 0x2c14ab637b8>,
#  'ليلى': <gensim.models.keyedvectors.Vocab at 0x2c14ab637f0>,
#  'المال': <gensim.models.keyedvectors.Vocab at 0x2c14ab63828>,
#  'محفظتها': <gensim.models.keyedvectors.Vocab at 0x2c14ab63860>,
#  'رلى': <gensim.models.keyedvectors.Vocab at 0x2c14ab63898>,
#  'ايليا': <gensim.models.keyedvectors.Vocab at 0x2c14ab638d0>,
#  'مشهور': <gensim.models.keyedvectors.Vocab at 0x2c14ab63908>,
#  'رانيا': <gensim.models.keyedvectors.Vocab at 0x2c14ab63940>,
#  'زهير': <gensim.models.keyedvectors.Vocab at 0x2c14ab63978>,
#  'العاملة': <gensim.models.keyedvectors.Vocab at 0x2c14ab639b0>,
#  'الخدمة': <gensim.models.keyedvectors.Vocab at 0x2c14ab639e8>,
#  'المنزلية': <gensim.models.keyedvectors.Vocab at 0x2c14ab63a20>,
#  'اثيوبية': <gensim.models.keyedvectors.Vocab at 0x2c14ab63a58>,
#  'طه': <gensim.models.keyedvectors.Vocab at 0x2c14ab63a90>,
#  'صبح': <gensim.models.keyedvectors.Vocab at 0x2c14ab63ac8>,
#  'توقيفهم': <gensim.models.keyedvectors.Vocab at 0x2c14ab63b00>,
#  'دفتر': <gensim.models.keyedvectors.Vocab at 0x2c14ab63b38>,
#  'لف': <gensim.models.keyedvectors.Vocab at 0x2c14ab63b70>,
#  'الحليم': <gensim.models.keyedvectors.Vocab at 0x2c14ab63ba8>,
#  'الانظمة': <gensim.models.keyedvectors.Vocab at 0x2c14ab63be0>,
#  'ياسين': <gensim.models.keyedvectors.Vocab at 0x2c14ab63c18>,
#  'فريد': <gensim.models.keyedvectors.Vocab at 0x2c14ab63c50>,
#  'تعميم': <gensim.models.keyedvectors.Vocab at 0x2c14ab63c88>,
#  'بحث': <gensim.models.keyedvectors.Vocab at 0x2c14ab63cc0>,
#  'تحري': <gensim.models.keyedvectors.Vocab at 0x2c14ab63cf8>,
#  'لمدة': <gensim.models.keyedvectors.Vocab at 0x2c14ab63d30>,
#  'شهر': <gensim.models.keyedvectors.Vocab at 0x2c14ab63d68>,
#  'الالفي': <gensim.models.keyedvectors.Vocab at 0x2c14ab63da0>,
#  'جاد': <gensim.models.keyedvectors.Vocab at 0x2c14ab63dd8>,
#  'ضيا': <gensim.models.keyedvectors.Vocab at 0x2c14ab63e10>,
#  'خصوصية': <gensim.models.keyedvectors.Vocab at 0x2c14ab63e48>,
#  'جويا': <gensim.models.keyedvectors.Vocab at 0x2c14ab63e80>,
#  'رضا': <gensim.models.keyedvectors.Vocab at 0x2c14ab63eb8>,
#  'عبدالله': <gensim.models.keyedvectors.Vocab at 0x2c14ab63ef0>,
#  'قحطان': <gensim.models.keyedvectors.Vocab at 0x2c14ab63f28>,
#  'الشمري': <gensim.models.keyedvectors.Vocab at 0x2c14ab63f60>,
#  'بيع': <gensim.models.keyedvectors.Vocab at 0x2c14ab63f98>,
#  'جر': <gensim.models.keyedvectors.Vocab at 0x2c14ab63fd0>,
#  'هويته': <gensim.models.keyedvectors.Vocab at 0x2c14ab67048>,
#  'رسول': <gensim.models.keyedvectors.Vocab at 0x2c14ab67080>,
#  'ترمه': <gensim.models.keyedvectors.Vocab at 0x2c14ab670b8>,
#  'الشب': <gensim.models.keyedvectors.Vocab at 0x2c14ab670f0>,
#  'ديانا': <gensim.models.keyedvectors.Vocab at 0x2c14ab67128>,
#  'لمى': <gensim.models.keyedvectors.Vocab at 0x2c14ab67160>,
#  'شلهوب': <gensim.models.keyedvectors.Vocab at 0x2c14ab67198>,
#  'اليات': <gensim.models.keyedvectors.Vocab at 0x2c14ab671d0>,
#  'موضوع': <gensim.models.keyedvectors.Vocab at 0x2c14ab67208>,
#  'منيمنة': <gensim.models.keyedvectors.Vocab at 0x2c14ab67240>,
#  'اسامة': <gensim.models.keyedvectors.Vocab at 0x2c14ab67278>,
#  'فرحات': <gensim.models.keyedvectors.Vocab at 0x2c14ab672b0>,
#  'مجهولين': <gensim.models.keyedvectors.Vocab at 0x2c14ab672e8>,
#  'سباق': <gensim.models.keyedvectors.Vocab at 0x2c14ab67320>,
#  'الخيل': <gensim.models.keyedvectors.Vocab at 0x2c14ab67358>,
#  'نور': <gensim.models.keyedvectors.Vocab at 0x2c14ab67390>,
#  'جمعة': <gensim.models.keyedvectors.Vocab at 0x2c14ab673c8>,
#  'هوندا': <gensim.models.keyedvectors.Vocab at 0x2c14ab67400>,
#  'ب': <gensim.models.keyedvectors.Vocab at 0x2c14ab67438>,
#  'الاسمر': <gensim.models.keyedvectors.Vocab at 0x2c14ab67470>,
#  'جباعي': <gensim.models.keyedvectors.Vocab at 0x2c14ab674a8>,
#  'افترا': <gensim.models.keyedvectors.Vocab at 0x2c14ab674e0>,
#  'العرب': <gensim.models.keyedvectors.Vocab at 0x2c14ab67518>,
#  'شحاده': <gensim.models.keyedvectors.Vocab at 0x2c14ab67550>,
#  'القاصر': <gensim.models.keyedvectors.Vocab at 0x2c14ab67588>,
#  'لحيازة': <gensim.models.keyedvectors.Vocab at 0x2c14ab675c0>,
#  'سندات': <gensim.models.keyedvectors.Vocab at 0x2c14ab675f8>,
#  'تسليم': <gensim.models.keyedvectors.Vocab at 0x2c14ab67630>,
#  'عطوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab67668>,
#  'زكريا': <gensim.models.keyedvectors.Vocab at 0x2c14ab676a0>,
#  'خضر': <gensim.models.keyedvectors.Vocab at 0x2c14ab676d8>,
#  'خياط': <gensim.models.keyedvectors.Vocab at 0x2c14ab67710>,
#  'يعمل': <gensim.models.keyedvectors.Vocab at 0x2c14ab67748>,
#  'يحي': <gensim.models.keyedvectors.Vocab at 0x2c14ab67780>,
#  'تنفيذه': <gensim.models.keyedvectors.Vocab at 0x2c14ab677b8>,
#  'فصيلة': <gensim.models.keyedvectors.Vocab at 0x2c14ab677f0>,
#  'طويل': <gensim.models.keyedvectors.Vocab at 0x2c14ab67828>,
#  'الطيونة': <gensim.models.keyedvectors.Vocab at 0x2c14ab67860>,
#  'حمدان': <gensim.models.keyedvectors.Vocab at 0x2c14ab67898>,
#  'المنفردة': <gensim.models.keyedvectors.Vocab at 0x2c14ab678d0>,
#  'شتم': <gensim.models.keyedvectors.Vocab at 0x2c14ab67908>,
#  'ماري': <gensim.models.keyedvectors.Vocab at 0x2c14ab67940>,
#  'نمر': <gensim.models.keyedvectors.Vocab at 0x2c14ab67978>,
#  'طراد': <gensim.models.keyedvectors.Vocab at 0x2c14ab679b0>,
#  'شمعون': <gensim.models.keyedvectors.Vocab at 0x2c14ab679e8>,
#  'باكير': <gensim.models.keyedvectors.Vocab at 0x2c14ab67a20>,
#  'عملة': <gensim.models.keyedvectors.Vocab at 0x2c14ab67a58>,
#  'عمار': <gensim.models.keyedvectors.Vocab at 0x2c14ab67a90>,
#  'ام': <gensim.models.keyedvectors.Vocab at 0x2c14ab67ac8>,
#  'بحوزته': <gensim.models.keyedvectors.Vocab at 0x2c14ab67b00>,
#  'كوكايين': <gensim.models.keyedvectors.Vocab at 0x2c14ab67b38>,
#  'كشلي': <gensim.models.keyedvectors.Vocab at 0x2c14ab67b70>,
#  'عيسى': <gensim.models.keyedvectors.Vocab at 0x2c14ab67ba8>,
#  'هرا': <gensim.models.keyedvectors.Vocab at 0x2c14ab67be0>,
#  'صلاح': <gensim.models.keyedvectors.Vocab at 0x2c14ab67c18>,
#  'تزوير': <gensim.models.keyedvectors.Vocab at 0x2c14ab67c50>,
#  'عمومية': <gensim.models.keyedvectors.Vocab at 0x2c14ab67c88>,
#  'شريف': <gensim.models.keyedvectors.Vocab at 0x2c14ab67cc0>,
#  'برقية': <gensim.models.keyedvectors.Vocab at 0x2c14ab67cf8>,
#  'سلامه': <gensim.models.keyedvectors.Vocab at 0x2c14ab67d30>,
#  'رواد': <gensim.models.keyedvectors.Vocab at 0x2c14ab67d68>,
#  'شكر': <gensim.models.keyedvectors.Vocab at 0x2c14ab67da0>,
#  'نعنوع': <gensim.models.keyedvectors.Vocab at 0x2c14ab67dd8>,
#  'وقوف': <gensim.models.keyedvectors.Vocab at 0x2c14ab67e10>,
#  'ممنوع': <gensim.models.keyedvectors.Vocab at 0x2c14ab67e48>,
#  'للنشل': <gensim.models.keyedvectors.Vocab at 0x2c14ab67e80>,
#  'جمركية': <gensim.models.keyedvectors.Vocab at 0x2c14ab67eb8>,
#  'ماجد': <gensim.models.keyedvectors.Vocab at 0x2c14ab67ef0>,
#  'اللوحات': <gensim.models.keyedvectors.Vocab at 0x2c14ab67f28>,
#  'طحان': <gensim.models.keyedvectors.Vocab at 0x2c14ab67f60>,
#  'هلال': <gensim.models.keyedvectors.Vocab at 0x2c14ab67f98>,
#  'طفيلي': <gensim.models.keyedvectors.Vocab at 0x2c14ab67fd0>,
#  'كو': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a048>,
#  'بشخص': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a080>,
#  'نحاس': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a0b8>,
#  'ببيان': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a0f0>,
#  'التراجع': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a128>,
#  'الادعا': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a160>,
#  'شعبان': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a198>,
#  'هاتفه': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a1d0>,
#  'ملاعب': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a208>,
#  'حرش': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a240>,
#  'متزن': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a278>,
#  'عفيف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a2b0>,
#  'بيضون': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a2e8>,
#  'جاسم': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a320>,
#  'زين': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a358>,
#  'جو': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a390>,
#  'ناصيف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a3c8>,
#  'قيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a400>,
#  'باشلكوى': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a438>,
#  'نهى': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a470>,
#  'اللبان': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a4a8>,
#  'حسني': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a4e0>,
#  'نصب': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a518>,
#  'المتحف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a550>,
#  'جوزاف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a588>,
#  'سكاف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a5c0>,
#  'رغبتها': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a5f8>,
#  'تعهد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a630>,
#  'حدث': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a668>,
#  'عبير': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a6a0>,
#  'عيتاني': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a6d8>,
#  'الاخير': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a710>,
#  'الصدم': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a748>,
#  'الشتم': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a780>,
#  'تركهما': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a7b8>,
#  'ميلاد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a7f0>,
#  'قزحيا': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a828>,
#  'الحايك': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a860>,
#  'فقيه': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a898>,
#  'الثاني': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a8d0>,
#  'فياض': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a908>,
#  'مارون': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a940>,
#  'نعمة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a978>,
#  'زغرتا': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a9b0>,
#  'غانم': <gensim.models.keyedvectors.Vocab at 0x2c14ab6a9e8>,
#  'عوالي': <gensim.models.keyedvectors.Vocab at 0x2c14ab6aa20>,
#  'تكسير': <gensim.models.keyedvectors.Vocab at 0x2c14ab6aa58>,
#  'مرسيدس': <gensim.models.keyedvectors.Vocab at 0x2c14ab6aa90>,
#  'ج': <gensim.models.keyedvectors.Vocab at 0x2c14ab6aac8>,
#  'لمع': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ab00>,
#  'نعمه': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ab38>,
#  'الاملاك': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ab70>,
#  'الخاصة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6aba8>,
#  'تخريب': <gensim.models.keyedvectors.Vocab at 0x2c14ab6abe0>,
#  'التحرش': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ac18>,
#  'منهما': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ac50>,
#  'الكريم': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ac88>,
#  'سلوم': <gensim.models.keyedvectors.Vocab at 0x2c14ab6acc0>,
#  'جود': <gensim.models.keyedvectors.Vocab at 0x2c14ab6acf8>,
#  'جواز': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ad30>,
#  'سفر': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ad68>,
#  'عاد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ada0>,
#  'ندى': <gensim.models.keyedvectors.Vocab at 0x2c14ab6add8>,
#  'بداخلها': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ae10>,
#  'المستندات': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ae48>,
#  'وال': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ae80>,
#  'المواد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6aeb8>,
#  'المتدرجة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6aef0>,
#  'غنوة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6af28>,
#  'كسر': <gensim.models.keyedvectors.Vocab at 0x2c14ab6af60>,
#  'درويش': <gensim.models.keyedvectors.Vocab at 0x2c14ab6af98>,
#  'كمية': <gensim.models.keyedvectors.Vocab at 0x2c14ab6afd0>,
#  'خير': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d048>,
#  'بزي': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d080>,
#  'كارلوس': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d0b8>,
#  'مسعد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d0f0>,
#  'رالف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d128>,
#  'الممور': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d160>,
#  'راد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d198>,
#  'لضبط': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d1d0>,
#  'تسطير': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d208>,
#  'لاحضار': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d240>,
#  'الفحص': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d278>,
#  'المخبري': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d2b0>,
#  'نظير': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d2e8>,
#  'مكتوم': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d320>,
#  'القيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d358>,
#  'مزور': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d390>,
#  'الدرس': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d3c8>,
#  'بندقية': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d400>,
#  'حربية': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d438>,
#  'طهماز': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d470>,
#  'العابدين': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d4a8>,
#  'ياماها': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d4e0>,
#  'عقيل': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d518>,
#  'فاروق': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d550>,
#  'وكيلته': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d588>,
#  'والدته': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d5c0>,
#  'تسجيلها': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d5f8>,
#  'الاولى': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d630>,
#  'المجند': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d668>,
#  'عبود': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d6a0>,
#  'جميل': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d6d8>,
#  'لوجود': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d710>,
#  'الهوية': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d748>,
#  'المقداد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d780>,
#  'الباقي': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d7b8>,
#  'جان': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d7f0>,
#  'اخذ': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d828>,
#  'العريف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d860>,
#  'بعدم': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d898>,
#  'الضرب': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d8d0>,
#  'اميون': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d908>,
#  'مازن': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d940>,
#  'كهربا': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d978>,
#  'مذكرة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d9b0>,
#  'منفذة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6d9e8>,
#  'شحيتلي': <gensim.models.keyedvectors.Vocab at 0x2c14ab6da20>,
#  'ميشال': <gensim.models.keyedvectors.Vocab at 0x2c14ab6da58>,
#  'الغول': <gensim.models.keyedvectors.Vocab at 0x2c14ab6da90>,
#  'لقيامه': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dac8>,
#  'المتن': <gensim.models.keyedvectors.Vocab at 0x2c14ab6db00>,
#  'خرق': <gensim.models.keyedvectors.Vocab at 0x2c14ab6db38>,
#  'قانون': <gensim.models.keyedvectors.Vocab at 0x2c14ab6db70>,
#  'الاجانب': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dba8>,
#  'نصرالله': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dbe0>,
#  'المدعة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dc18>,
#  'بديع': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dc50>,
#  'شرف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dc88>,
#  'حداد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dcc0>,
#  'عادة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dcf8>,
#  'للمدعو': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dd30>,
#  'زوين': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dd68>,
#  'عساكر': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dda0>,
#  'حقيبتها': <gensim.models.keyedvectors.Vocab at 0x2c14ab6ddd8>,
#  'رولان': <gensim.models.keyedvectors.Vocab at 0x2c14ab6de10>,
#  'راشد': <gensim.models.keyedvectors.Vocab at 0x2c14ab6de48>,
#  'جوزف': <gensim.models.keyedvectors.Vocab at 0x2c14ab6de80>,
#  'بشارة': <gensim.models.keyedvectors.Vocab at 0x2c14ab6deb8>,
#  'بالقتل': <gensim.models.keyedvectors.Vocab at 0x2c14ab6def0>,
#  'تحقير': <gensim.models.keyedvectors.Vocab at 0x2c14ab6df28>,
#  'بشير': <gensim.models.keyedvectors.Vocab at 0x2c14ab6df60>,
#  'دانيال': <gensim.models.keyedvectors.Vocab at 0x2c14ab6df98>,
#  'انطوان': <gensim.models.keyedvectors.Vocab at 0x2c14ab6dfd0>,
#  'محسن': <gensim.models.keyedvectors.Vocab at 0x2c14ab71048>,
#  'ابي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71080>,
#  'بالاسدعا': <gensim.models.keyedvectors.Vocab at 0x2c14ab710b8>,
#  'جنان': <gensim.models.keyedvectors.Vocab at 0x2c14ab710f0>,
#  'ملص': <gensim.models.keyedvectors.Vocab at 0x2c14ab71128>,
#  'عربيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab71160>,
#  'الكشف': <gensim.models.keyedvectors.Vocab at 0x2c14ab71198>,
#  'كونها': <gensim.models.keyedvectors.Vocab at 0x2c14ab711d0>,
#  'محجوزة': <gensim.models.keyedvectors.Vocab at 0x2c14ab71208>,
#  'مفرزة': <gensim.models.keyedvectors.Vocab at 0x2c14ab71240>,
#  'رياض': <gensim.models.keyedvectors.Vocab at 0x2c14ab71278>,
#  'موسى': <gensim.models.keyedvectors.Vocab at 0x2c14ab712b0>,
#  'دهدو': <gensim.models.keyedvectors.Vocab at 0x2c14ab712e8>,
#  'ادلبي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71320>,
#  'تحر': <gensim.models.keyedvectors.Vocab at 0x2c14ab71358>,
#  'حرفوش': <gensim.models.keyedvectors.Vocab at 0x2c14ab71390>,
#  'تراجعها': <gensim.models.keyedvectors.Vocab at 0x2c14ab713c8>,
#  'اسماعيلات': <gensim.models.keyedvectors.Vocab at 0x2c14ab71400>,
#  'المعلم': <gensim.models.keyedvectors.Vocab at 0x2c14ab71438>,
#  'تهجم': <gensim.models.keyedvectors.Vocab at 0x2c14ab71470>,
#  'ووضع': <gensim.models.keyedvectors.Vocab at 0x2c14ab714a8>,
#  'الجهاز': <gensim.models.keyedvectors.Vocab at 0x2c14ab714e0>,
#  'الخليوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71518>,
#  'المراقبة': <gensim.models.keyedvectors.Vocab at 0x2c14ab71550>,
#  'حصول': <gensim.models.keyedvectors.Vocab at 0x2c14ab71588>,
#  'اشكال': <gensim.models.keyedvectors.Vocab at 0x2c14ab715c0>,
#  'مفتوح': <gensim.models.keyedvectors.Vocab at 0x2c14ab715f8>,
#  'حال': <gensim.models.keyedvectors.Vocab at 0x2c14ab71630>,
#  'تعدي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71668>,
#  'سيارات': <gensim.models.keyedvectors.Vocab at 0x2c14ab716a0>,
#  'البغدادي': <gensim.models.keyedvectors.Vocab at 0x2c14ab716d8>,
#  'مختار': <gensim.models.keyedvectors.Vocab at 0x2c14ab71710>,
#  'العمري': <gensim.models.keyedvectors.Vocab at 0x2c14ab71748>,
#  'هرموش': <gensim.models.keyedvectors.Vocab at 0x2c14ab71780>,
#  'المستدعية': <gensim.models.keyedvectors.Vocab at 0x2c14ab717b8>,
#  'رعد': <gensim.models.keyedvectors.Vocab at 0x2c14ab717f0>,
#  'الشيخ': <gensim.models.keyedvectors.Vocab at 0x2c14ab71828>,
#  'جهاز': <gensim.models.keyedvectors.Vocab at 0x2c14ab71860>,
#  'ممدوح': <gensim.models.keyedvectors.Vocab at 0x2c14ab71898>,
#  'للاشتباه': <gensim.models.keyedvectors.Vocab at 0x2c14ab718d0>,
#  'بتعاطي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71908>,
#  'الطفيلي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71940>,
#  'الرضا': <gensim.models.keyedvectors.Vocab at 0x2c14ab71978>,
#  'الساتر': <gensim.models.keyedvectors.Vocab at 0x2c14ab719b0>,
#  'حبات': <gensim.models.keyedvectors.Vocab at 0x2c14ab719e8>,
#  'البستاني': <gensim.models.keyedvectors.Vocab at 0x2c14ab71a20>,
#  'شارل': <gensim.models.keyedvectors.Vocab at 0x2c14ab71a58>,
#  'عبيد': <gensim.models.keyedvectors.Vocab at 0x2c14ab71a90>,
#  'المزود': <gensim.models.keyedvectors.Vocab at 0x2c14ab71ac8>,
#  'باقي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71b00>,
#  'الموسوري': <gensim.models.keyedvectors.Vocab at 0x2c14ab71b38>,
#  'بطريقة': <gensim.models.keyedvectors.Vocab at 0x2c14ab71b70>,
#  'مجهولة': <gensim.models.keyedvectors.Vocab at 0x2c14ab71ba8>,
#  'استخدام': <gensim.models.keyedvectors.Vocab at 0x2c14ab71be0>,
#  'للمدعوة': <gensim.models.keyedvectors.Vocab at 0x2c14ab71c18>,
#  'ميرا': <gensim.models.keyedvectors.Vocab at 0x2c14ab71c50>,
#  'برجاوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71c88>,
#  'مهند': <gensim.models.keyedvectors.Vocab at 0x2c14ab71cc0>,
#  'ملا': <gensim.models.keyedvectors.Vocab at 0x2c14ab71cf8>,
#  'اديب': <gensim.models.keyedvectors.Vocab at 0x2c14ab71d30>,
#  'فاديا': <gensim.models.keyedvectors.Vocab at 0x2c14ab71d68>,
#  'مدة': <gensim.models.keyedvectors.Vocab at 0x2c14ab71da0>,
#  'اليو': <gensim.models.keyedvectors.Vocab at 0x2c14ab71dd8>,
#  'المديرية': <gensim.models.keyedvectors.Vocab at 0x2c14ab71e10>,
#  'للامن': <gensim.models.keyedvectors.Vocab at 0x2c14ab71e48>,
#  'ناديا': <gensim.models.keyedvectors.Vocab at 0x2c14ab71e80>,
#  'زوجها': <gensim.models.keyedvectors.Vocab at 0x2c14ab71eb8>,
#  'البدوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71ef0>,
#  'ظاظا': <gensim.models.keyedvectors.Vocab at 0x2c14ab71f28>,
#  'عساف': <gensim.models.keyedvectors.Vocab at 0x2c14ab71f60>,
#  'زكي': <gensim.models.keyedvectors.Vocab at 0x2c14ab71f98>,
#  'بكار': <gensim.models.keyedvectors.Vocab at 0x2c14ab71fd0>,
#  'جمعية': <gensim.models.keyedvectors.Vocab at 0x2c14ab75048>,
#  'كفى': <gensim.models.keyedvectors.Vocab at 0x2c14ab75080>,
#  'بدر': <gensim.models.keyedvectors.Vocab at 0x2c14ab750b8>,
#  'التعرض': <gensim.models.keyedvectors.Vocab at 0x2c14ab750f0>,
#  'او': <gensim.models.keyedvectors.Vocab at 0x2c14ab75128>,
#  'زوجته': <gensim.models.keyedvectors.Vocab at 0x2c14ab75160>,
#  'وكيل': <gensim.models.keyedvectors.Vocab at 0x2c14ab75198>,
#  'الجهة': <gensim.models.keyedvectors.Vocab at 0x2c14ab751d0>,
#  'بدوي': <gensim.models.keyedvectors.Vocab at 0x2c14ab75208>,
#  'عون': <gensim.models.keyedvectors.Vocab at 0x2c14ab75240>,
#  'المتدرج': <gensim.models.keyedvectors.Vocab at 0x2c14ab75278>,
#  'مرعي': <gensim.models.keyedvectors.Vocab at 0x2c14ab752b0>,
#  'بالمفوض': <gensim.models.keyedvectors.Vocab at 0x2c14ab752e8>,
#  'بالتوقيع': <gensim.models.keyedvectors.Vocab at 0x2c14ab75320>,
#  'المفوض': <gensim.models.keyedvectors.Vocab at 0x2c14ab75358>,
#  'الشركة': <gensim.models.keyedvectors.Vocab at 0x2c14ab75390>,
#  'بنك': <gensim.models.keyedvectors.Vocab at 0x2c14ab753c8>,
#  'المشرق': <gensim.models.keyedvectors.Vocab at 0x2c14ab75400>,
#  'نسرين': <gensim.models.keyedvectors.Vocab at 0x2c14ab75438>,
#  'حمزة': <gensim.models.keyedvectors.Vocab at 0x2c14ab75470>,
#  'الرحيم': <gensim.models.keyedvectors.Vocab at 0x2c14ab754a8>,
#  'ملحم': <gensim.models.keyedvectors.Vocab at 0x2c14ab754e0>,
#  'سمعان': <gensim.models.keyedvectors.Vocab at 0x2c14ab75518>,
#  'فادي': <gensim.models.keyedvectors.Vocab at 0x2c14ab75550>,
#  'حجازي': <gensim.models.keyedvectors.Vocab at 0x2c14ab75588>,
#  'ليندا': <gensim.models.keyedvectors.Vocab at 0x2c14ab755c0>,
#  'دلباني': <gensim.models.keyedvectors.Vocab at 0x2c14ab755f8>,
#  'باساتدعا': <gensim.models.keyedvectors.Vocab at 0x2c14ab75630>,
#  'مسروقة': <gensim.models.keyedvectors.Vocab at 0x2c14ab75668>,
#  'مرسال': <gensim.models.keyedvectors.Vocab at 0x2c14ab756a0>,
#  'الاطرش': <gensim.models.keyedvectors.Vocab at 0x2c14ab756d8>,
#  'مالية': <gensim.models.keyedvectors.Vocab at 0x2c14ab75710>,
#  'كيا': <gensim.models.keyedvectors.Vocab at 0x2c14ab75748>,
#  'بجرك': <gensim.models.keyedvectors.Vocab at 0x2c14ab75780>,
#  'فحص': <gensim.models.keyedvectors.Vocab at 0x2c14ab757b8>,
#  'اكرم': <gensim.models.keyedvectors.Vocab at 0x2c14ab757f0>,
#  'مصيطف': <gensim.models.keyedvectors.Vocab at 0x2c14ab75828>,
#  'يوما': <gensim.models.keyedvectors.Vocab at 0x2c14ab75860>,
#  'غلاييني': <gensim.models.keyedvectors.Vocab at 0x2c14ab75898>,
#  'بيك': <gensim.models.keyedvectors.Vocab at 0x2c14ab758d0>,
#  'ازعاج': <gensim.models.keyedvectors.Vocab at 0x2c14ab75908>,
#  ...}

# %%
from itertools import islice
list(islice(word2vec_vectors.wv.vocab, 130, 150))
# Out:
# ['كامل',
#  'المدعى',
#  'النبطية',
#  'خالد',
#  'عودة',
#  'بالشكوى',
#  'المقدمة',
#  'مالك',
#  'المصري',
#  'وكيله',
#  'المحامي',
#  'عدنان',
#  'الشعار',
#  'عليهما',
#  'كريم',
#  'عز',
#  'لبنانيان',
#  'شك',
#  'رصيد',
#  'سامي']
